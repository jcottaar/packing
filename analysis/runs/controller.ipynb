# %%
import sys
import os
sys.path.insert(0, os.path.join(os.getcwd(), '../../core'))
import kaggle_support as kgs
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import clear_output
import time
import multiprocess as mp
import copy
# Out:
# vast

# %% [markdown]
# ## Configuration

# %%
DO_CHECK = False

# User inputs
N_TREES_LIST = [x.item() for x in np.arange(60,201,2)]  # List of N_trees to run
N_PROCESSES = 2 if kgs.env=='local' else 3  # Maximum concurrent processes
DIAGNOSTIC_INTERVAL = 120  # Seconds between diagnostic updates
SEED_LIST = [140,141]  # Base seed for reproducibility

# Derived inputs (edit manually to customize seeds per task)
N_TREES_SEED_LIST = [(N, SEED) for N in N_TREES_LIST for SEED in SEED_LIST ]
print(N_TREES_SEED_LIST)

# Set up checkpoint/log directory
CHECKPOINT_DIR = 'controller_runs/' if not DO_CHECK else 'check_runs/'
os.makedirs(kgs.temp_dir + CHECKPOINT_DIR, exist_ok=True)
print(f"Using checkpoint directory: {CHECKPOINT_DIR}")

# Create base runner configuration
import pack_ga3
import pack_runner

base_runner = pack_ga3.baseline_symmetry_180_tesselated()
#base_runner.n_generations = 500
base_runner.ga.ga_base.initializer.ref_sol_crystal_type = 'Close under'
# base_runner.ga.ga_base.initializer.ref_sol_axis1_offset = None
# base_runner.ga.ga_base.initializer.ref_sol_axis2_offset = 'set!'
# base_runner.ga.stop_check_generations_scale = 10

base_runner.ga.do_legalize = True
base_runner.use_atomic_save = True  # Enable atomic saves for multiprocess safety

base_runner.diagnostic_plot = False  # Disabled in subprocess
if DO_CHECK:
    base_runner.n_generations = 1000
# Out:
# [(60, 140), (62, 140), (64, 140), (66, 140), (68, 140), (70, 140), (72, 140), (74, 140), (76, 140), (78, 140), (80, 140), (82, 140), (84, 140), (86, 140), (88, 140), (90, 140), (92, 140), (94, 140), (96, 140), (98, 140), (100, 140), (102, 140), (104, 140), (106, 140), (108, 140), (110, 140), (112, 140), (114, 140), (116, 140), (118, 140), (120, 140), (122, 140), (124, 140), (126, 140), (128, 140), (130, 140), (132, 140), (134, 140), (136, 140), (138, 140), (140, 140), (142, 140), (144, 140), (146, 140), (148, 140), (150, 140), (152, 140), (154, 140), (156, 140), (158, 140), (160, 140), (162, 140), (164, 140), (166, 140), (168, 140), (170, 140), (172, 140), (174, 140), (176, 140), (178, 140), (180, 140), (182, 140), (184, 140), (186, 140), (188, 140), (190, 140), (192, 140), (194, 140), (196, 140), (198, 140), (200, 140), (60, 141), (62, 141), (64, 141), (66, 141), (68, 141), (70, 141), (72, 141), (74, 141), (76, 141), (78, 141), (80, 141), (82, 141), (84, 141), (86, 141), (88, 141), (90, 141), (92, 141), (94, 141), (96, 141), (98, 141), (100, 141), (102, 141), (104, 141), (106, 141), (108, 141), (110, 141), (112, 141), (114, 141), (116, 141), (118, 141), (120, 141), (122, 141), (124, 141), (126, 141), (128, 141), (130, 141), (132, 141), (134, 141), (136, 141), (138, 141), (140, 141), (142, 141), (144, 141), (146, 141), (148, 141), (150, 141), (152, 141), (154, 141), (156, 141), (158, 141), (160, 141), (162, 141), (164, 141), (166, 141), (168, 141), (170, 141), (172, 141), (174, 141), (176, 141), (178, 141), (180, 141), (182, 141), (184, 141), (186, 141), (188, 141), (190, 141), (192, 141), (194, 141), (196, 141), (198, 141), (200, 141), (60, 142), (62, 142), (64, 142), (66, 142), (68, 142), (70, 142), (72, 142), (74, 142), (76, 142), (78, 142), (80, 142), (82, 142), (84, 142), (86, 142), (88, 142), (90, 142), (92, 142), (94, 142), (96, 142), (98, 142), (100, 142), (102, 142), (104, 142), (106, 142), (108, 142), (110, 142), (112, 142), (114, 142), (116, 142), (118, 142), (120, 142), (122, 142), (124, 142), (126, 142), (128, 142), (130, 142), (132, 142), (134, 142), (136, 142), (138, 142), (140, 142), (142, 142), (144, 142), (146, 142), (148, 142), (150, 142), (152, 142), (154, 142), (156, 142), (158, 142), (160, 142), (162, 142), (164, 142), (166, 142), (168, 142), (170, 142), (172, 142), (174, 142), (176, 142), (178, 142), (180, 142), (182, 142), (184, 142), (186, 142), (188, 142), (190, 142), (192, 142), (194, 142), (196, 142), (198, 142), (200, 142), (60, 143), (62, 143), (64, 143), (66, 143), (68, 143), (70, 143), (72, 143), (74, 143), (76, 143), (78, 143), (80, 143), (82, 143), (84, 143), (86, 143), (88, 143), (90, 143), (92, 143), (94, 143), (96, 143), (98, 143), (100, 143), (102, 143), (104, 143), (106, 143), (108, 143), (110, 143), (112, 143), (114, 143), (116, 143), (118, 143), (120, 143), (122, 143), (124, 143), (126, 143), (128, 143), (130, 143), (132, 143), (134, 143), (136, 143), (138, 143), (140, 143), (142, 143), (144, 143), (146, 143), (148, 143), (150, 143), (152, 143), (154, 143), (156, 143), (158, 143), (160, 143), (162, 143), (164, 143), (166, 143), (168, 143), (170, 143), (172, 143), (174, 143), (176, 143), (178, 143), (180, 143), (182, 143), (184, 143), (186, 143), (188, 143), (190, 143), (192, 143), (194, 143), (196, 143), (198, 143), (200, 143)]
# Using checkpoint directory: controller_runs/

# %% [markdown]
# ## Worker Function

# %%
def worker_function(N_trees, seed, base_runner_pickled, checkpoint_dir):
    """
    Worker process that runs GA for a specific N_trees.
    Runs in subprocess - output redirected to log file.
    """
    import sys
    import os
    sys.path.insert(0, os.path.join(os.getcwd(), '../../core'))
    import kaggle_support as kgs
    import copy
    import numpy as np
    
    # Redirect stdout/stderr to log file
    log_path = kgs.temp_dir + checkpoint_dir + f'ga_N{N_trees}_seed{seed}.log'
    log_file = open(log_path, 'a')
    sys.stdout = log_file
    sys.stderr = log_file
    
    print(f"\n{'='*60}")
    print(f"Starting worker: N_trees={N_trees}, seed={seed}")
    print(f"{'='*60}\n")
    
    try:
        # Unpickle base runner and configure
        import dill
        runner = dill.loads(base_runner_pickled)
        runner.seed = seed
        runner.filename = checkpoint_dir + f'ga_N{N_trees}_seed{seed}'

        skip_lists = kgs.dill_load(kgs.code_dir + 'skip_list.pickle')

        if seed%2==0:
           runner.ga.ga_base.initializer.ref_sol_axis2_offset = lambda r:0.
           #if N_trees in skip_lists[0]:
           #    raise ValueError(f"Skipping N_trees={N_trees} for seed={seed} as per skip list.")
        else:
           runner.ga.ga_base.initializer.ref_sol_axis2_offset = lambda r:0.5
           #if N_trees in skip_lists[1]:
           #    raise ValueError(f"Skipping N_trees={N_trees} for seed={seed} as per skip list.")
           
        #if N_trees>=190:
        #    runner.n_generations = 1000
        # if N_trees in [58,60,62,78]:
        #     runner.ga.ga_base.initializer.ref_sol_axis2_offset = 0.
        # else:
        #     assert N_trees in [74,76]
        #     runner.ga.ga_base.initializer.ref_sol_axis2_offset = 0.5

        # scores = {58:  (0.34414092),
        #      60:  (0.34393105),
        #      62:  (0.34281883),
        #      74:  (0.34060055),
        #      76:  (0.34060344),
        #      78:  (0.34023234)}
        # runner.ga.target_score = scores[N_trees]

        # if seed>94:
        #     runner.ga.ga_base.initializer.new_tree_placer = True
        #     runner.ga.ga_base.initializer.base_solution.edge_spacer = kgs.EdgeSpacerBasic(dist_x = 0.5, dist_y = 0.5)
        # if seed>96:
        #     runner.ga.ga_base.initializer.new_tree_placer = True
        #     runner.ga.ga_base.initializer.base_solution.edge_spacer = kgs.EdgeSpacerBasic(dist_x = 0.75, dist_y = 0.5)
        
        # Configure for this N_trees
        runner.ga.ga_base.N_trees_to_do = N_trees
        
        # Check for existing checkpoint
        checkpoint_path =  kgs.temp_dir + runner.filename + '.pickle'
        if os.path.isfile(checkpoint_path):
            print(f"Loading checkpoint: {checkpoint_path}")
            runner = kgs.dill_load(checkpoint_path)
        
        # Run with atomic saves (enabled via use_atomic_save flag)
        runner.run()
        
        print(f"\nCompleted: N_trees={N_trees}, seed={seed}, final generation={runner._current_generation}")
        
    except Exception as e:
        import traceback
        print(f"\nERROR in worker N_trees={N_trees}, seed={seed}:")
        traceback.print_exc()
    finally:
        log_file.close()

# %% [markdown]
# ## Process Manager

# %%
class ProcessManager:
    """Manages pool of worker processes."""
    
    def __init__(self, N_trees_seed_list, n_processes, base_runner, checkpoint_dir):
        self.N_trees_seed_list = list(N_trees_seed_list)
        self.n_processes = n_processes
        self.checkpoint_dir = checkpoint_dir
        self.base_runner_pickled = kgs.dill.dumps(base_runner)
        
        self.pending_tasks = list(self.N_trees_seed_list)
        self.running = {}  # {Process: (N_trees, seed)}
        self.completed = set()  # Set of (N_trees, seed) tuples
        self.errored = {}  # {(N_trees, seed): exit_code}
        self.last_start_time = 0  # Track last process start time
    
    @staticmethod
    def _format_task(N_trees, seed):
        return f"N_trees={N_trees}, seed={seed}"
        
    def start_process(self, N_trees, seed):
        """Start a new worker process, or mark done if done file exists."""
        # Check if done file already exists
        filename = f'ga_N{N_trees}_seed{seed}'
        done_path = kgs.temp_dir + self.checkpoint_dir + f'done/{filename}_done.pickle'
        
        if os.path.isfile(done_path):
            # Done file exists, just mark it as completed without starting process
            self.completed.add((N_trees, seed))
            print(f"Skipping {self._format_task(N_trees, seed)} - already done (found {done_path})")
            return
        
        # No done file, start the process normally
        p = mp.Process(target=worker_function, 
                      args=(N_trees, seed, self.base_runner_pickled, self.checkpoint_dir))
        p.start()
        self.running[p] = (N_trees, seed)
        self.last_start_time = time.time()
        print(f"Started process for {self._format_task(N_trees, seed)} (PID: {p.pid})")
        
    def update(self):
        """Check for completed processes and start new ones."""
        # Check running processes
        for p in list(self.running.keys()):
            if not p.is_alive():
                N_trees, seed = self.running[p]
                p.join()
                del self.running[p]
                if p.exitcode == 0:
                    self.completed.add((N_trees, seed))
                    print(f"Process completed: {self._format_task(N_trees, seed)}")
                else:
                    self.errored[(N_trees, seed)] = p.exitcode
                    print(f"Process FAILED: {self._format_task(N_trees, seed)} (exit code: {p.exitcode})")
        
        # Start new processes if slots available
        while len(self.running) < self.n_processes and self.pending_tasks:
            # Stagger startup: wait 5 seconds after last start
            time_since_last_start = time.time() - self.last_start_time
            if time_since_last_start < 5.0:
                time.sleep(5.0 - time_since_last_start)
            
            N_trees, seed = self.pending_tasks.pop(0)
            self.start_process(N_trees, seed)
    
    def get_status(self, task):
        """Get status of a specific (N_trees, seed) value."""
        N_trees, seed = task
        if task in self.errored:
            return f"ERROR (exit {self.errored[task]})"
        if task in self.completed:
            return "DONE"
        for p, (nt, sd) in self.running.items():
            if (nt, sd) == task:
                return "RUNNING"
        for pending_task in self.pending_tasks:
            if pending_task == task:
                return "PENDING"
        return "UNKNOWN"
    
    def is_complete(self):
        """Check if all tasks are done."""
        return len(self.pending_tasks) == 0 and len(self.running) == 0
    
    def status(self):
        """Return status string."""
        return (f"Running: {len(self.running)}, "
                f"Pending: {len(self.pending_tasks)}, "
                f"Completed: {len(self.completed)}, "
                f"Errored: {len(self.errored)}")

# %% [markdown]
# ## Diagnostic Display

# %%
def display_diagnostics(N_trees_seed_list, checkpoint_dir, manager):
    """
    Load all runner pickles and display diagnostic plots.
    Handles missing/corrupted files gracefully.
    """
    
    # First, load all pickle files before clearing display
    runners = {}
    status_info = {}  # Store status and error messages
    
    for N_trees, seed in N_trees_seed_list:
        task = (N_trees, seed)
        status = manager.get_status(task)
        filename = f'ga_N{N_trees}_seed{seed}'
        task_label = f"N={N_trees}, seed={seed}"
        
        # If process is DONE, load from done directory
        if status == "DONE":
            done_path = kgs.temp_dir + checkpoint_dir + f'done/{filename}_done.pickle'
            
            if os.path.isfile(done_path):
                try:
                    runner = kgs.dill_load(done_path)
                    
                    # Store info for later display (no diagnostic plots for done processes)
                    best_costs = [[round(float(x), 6) for x in s[-1].flatten()] 
                                  for s in runner.ga.best_costs_per_generation]
                    status_info[task] = {
                        'status': status,
                        'type': 'done',
                        'message': f"{task_label} [{status:8s}]: Gen {runner._current_generation}/{runner.n_generations} | Best: {best_costs}"
                    }
                except Exception as e:
                    status_info[task] = {
                        'status': 'MISSING',
                        'type': 'error',
                        'message': f"{task_label} [MISSING ]: Done file exists but failed to load - {str(e)[:50]}"
                    }
            else:
                status_info[task] = {
                    'status': 'MISSING',
                    'type': 'missing',
                    'message': f"{task_label} [MISSING ]"
                }
        else:
            # For ongoing processes, load checkpoint and prepare for diagnostic plots
            pickle_path = kgs.temp_dir + checkpoint_dir + filename + '.pickle'
            
            if os.path.isfile(pickle_path):
                try:
                    runner = kgs.dill_load(pickle_path)
                    if status == "RUNNING":
                        runners[task] = runner  # Only add to runners for diagnostic plots
                    
                    # Store info for later display
                    best_costs = [[round(float(x), 6) for x in s[-1].flatten()] 
                                  for s in runner.ga.best_costs_per_generation]
                    status_info[task] = {
                        'status': status,
                        'type': 'loaded',
                        'message': f"{task_label} [{status:8s}]: Gen {runner._current_generation}/{runner.n_generations} | Best: {best_costs}"
                    }
                except Exception as e:
                    status_info[task] = {
                        'status': status,
                        'type': 'error',
                        'message': f"{task_label} [{status:8s}]: Error loading pickle - {str(e)[:50]}"
                    }
            else:
                status_info[task] = {
                    'status': status,
                    'type': 'missing',
                    'message': f"{task_label} [{status:8s}]: No checkpoint found"
                }
    
    # Now clear output and display everything
    clear_output(wait=True)
    
    print(f"{'='*60}")
    print(f"Diagnostics Update - {time.strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"{'='*60}\n")
    
    # Print all status messages
    for task in N_trees_seed_list:
        print(status_info[task]['message'])
    
    print(f"\n{'='*60}\n")
    
    # Display diagnostic plots ONLY for ongoing processes (runners dict only contains those)
    for (N_trees, seed), runner in runners.items():
        try:
            runner.ga.diagnostic_plots(runner._current_generation - 1, None)            
            #plt.suptitle(f"N_trees={N_trees} (Gen {runner._current_generation})")
            #plt.show()
        except Exception as e:
            print(f"Error displaying diagnostics for N={N_trees}, seed={seed}: {e}")

    plt.close('all')  # Close figures to prevent accumulation

# %% [markdown]
# ## Main Controller Loop

# %%
# Initialize process manager
manager = ProcessManager(N_TREES_SEED_LIST, N_PROCESSES, base_runner, CHECKPOINT_DIR)

task_labels = [f"(N={N}, seed={seed})" for N, seed in N_TREES_SEED_LIST]
print(f"Starting controller for tasks: {task_labels}")
print(f"Max concurrent processes: {N_PROCESSES}")
print(f"Diagnostic interval: {DIAGNOSTIC_INTERVAL}s\n")

last_diagnostic_time = 0

try:
    while not manager.is_complete():
        # Update process pool
        manager.update()
        
        # Display diagnostics periodically
        current_time = time.time()
        if current_time - last_diagnostic_time >= DIAGNOSTIC_INTERVAL:
            display_diagnostics(N_TREES_SEED_LIST, CHECKPOINT_DIR, manager)
            print(f"\nStatus: {manager.status()}\n")
            last_diagnostic_time = current_time
        
        # Sleep briefly to avoid busy-waiting
        time.sleep(1)
    
    # Final update
    print("\n" + "="*60)
    print("All processes completed!")
    print("="*60 + "\n")
    display_diagnostics(N_TREES_SEED_LIST, CHECKPOINT_DIR, manager)
    
except KeyboardInterrupt:
    print("\n\nInterrupted by user!")
    print("Terminating running processes...")
    for p in manager.running.keys():
        p.terminate()
        p.join()
    print("Cleanup complete.")
# Out:
# ============================================================
# Diagnostics Update - 2026-01-19 22:25:06
# ============================================================
#
# N=60, seed=140 [RUNNING ]: Gen 250/60000 | Best: [[0.346826, 3.3e-05]]
# N=62, seed=140 [RUNNING ]: Gen 250/60000 | Best: [[0.347499, 2.4e-05]]
# N=64, seed=140 [RUNNING ]: Gen 200/60000 | Best: [[0.349315, 1.7e-05]]
# N=66, seed=140 [PENDING ]: No checkpoint found
# N=68, seed=140 [PENDING ]: No checkpoint found
# N=70, seed=140 [PENDING ]: No checkpoint found
# N=72, seed=140 [PENDING ]: No checkpoint found
# N=74, seed=140 [PENDING ]: No checkpoint found
# N=76, seed=140 [PENDING ]: No checkpoint found
# N=78, seed=140 [PENDING ]: No checkpoint found
# N=80, seed=140 [PENDING ]: No checkpoint found
# N=82, seed=140 [PENDING ]: No checkpoint found
# N=84, seed=140 [PENDING ]: No checkpoint found
# N=86, seed=140 [PENDING ]: No checkpoint found
# N=88, seed=140 [PENDING ]: No checkpoint found
# N=90, seed=140 [PENDING ]: No checkpoint found
# N=92, seed=140 [PENDING ]: No checkpoint found
# N=94, seed=140 [PENDING ]: No checkpoint found
# N=96, seed=140 [PENDING ]: No checkpoint found
# N=98, seed=140 [PENDING ]: No checkpoint found
# N=100, seed=140 [PENDING ]: No checkpoint found
# N=102, seed=140 [PENDING ]: No checkpoint found
# N=104, seed=140 [PENDING ]: No checkpoint found
# N=106, seed=140 [PENDING ]: No checkpoint found
# N=108, seed=140 [PENDING ]: No checkpoint found
# N=110, seed=140 [PENDING ]: No checkpoint found
# N=112, seed=140 [PENDING ]: No checkpoint found
# N=114, seed=140 [PENDING ]: No checkpoint found
# N=116, seed=140 [PENDING ]: No checkpoint found
# N=118, seed=140 [PENDING ]: No checkpoint found
# N=120, seed=140 [PENDING ]: No checkpoint found
# N=122, seed=140 [PENDING ]: No checkpoint found
# N=124, seed=140 [PENDING ]: No checkpoint found
# N=126, seed=140 [PENDING ]: No checkpoint found
# N=128, seed=140 [PENDING ]: No checkpoint found
# N=130, seed=140 [PENDING ]: No checkpoint found
# N=132, seed=140 [PENDING ]: No checkpoint found
# N=134, seed=140 [PENDING ]: No checkpoint found
# N=136, seed=140 [PENDING ]: No checkpoint found
# N=138, seed=140 [PENDING ]: No checkpoint found
# N=140, seed=140 [PENDING ]: No checkpoint found
# N=142, seed=140 [PENDING ]: No checkpoint found
# N=144, seed=140 [PENDING ]: No checkpoint found
# N=146, seed=140 [PENDING ]: No checkpoint found
# N=148, seed=140 [PENDING ]: No checkpoint found
# N=150, seed=140 [PENDING ]: No checkpoint found
# N=152, seed=140 [PENDING ]: No checkpoint found
# N=154, seed=140 [PENDING ]: No checkpoint found
# N=156, seed=140 [PENDING ]: No checkpoint found
# N=158, seed=140 [PENDING ]: No checkpoint found
# N=160, seed=140 [PENDING ]: No checkpoint found
# N=162, seed=140 [PENDING ]: No checkpoint found
# N=164, seed=140 [PENDING ]: No checkpoint found
# N=166, seed=140 [PENDING ]: No checkpoint found
# N=168, seed=140 [PENDING ]: No checkpoint found
# N=170, seed=140 [PENDING ]: No checkpoint found
# N=172, seed=140 [PENDING ]: No checkpoint found
# N=174, seed=140 [PENDING ]: No checkpoint found
# N=176, seed=140 [PENDING ]: No checkpoint found
# N=178, seed=140 [PENDING ]: No checkpoint found
# N=180, seed=140 [PENDING ]: No checkpoint found
# N=182, seed=140 [PENDING ]: No checkpoint found
# N=184, seed=140 [PENDING ]: No checkpoint found
# N=186, seed=140 [PENDING ]: No checkpoint found
# N=188, seed=140 [PENDING ]: No checkpoint found
# N=190, seed=140 [PENDING ]: No checkpoint found
# N=192, seed=140 [PENDING ]: No checkpoint found
# N=194, seed=140 [PENDING ]: No checkpoint found
# N=196, seed=140 [PENDING ]: No checkpoint found
# N=198, seed=140 [PENDING ]: No checkpoint found
# N=200, seed=140 [PENDING ]: No checkpoint found
# N=60, seed=141 [PENDING ]: No checkpoint found
# N=62, seed=141 [PENDING ]: No checkpoint found
# N=64, seed=141 [PENDING ]: No checkpoint found
# N=66, seed=141 [PENDING ]: No checkpoint found
# N=68, seed=141 [PENDING ]: No checkpoint found
# N=70, seed=141 [PENDING ]: No checkpoint found
# N=72, seed=141 [PENDING ]: No checkpoint found
# N=74, seed=141 [PENDING ]: No checkpoint found
# N=76, seed=141 [PENDING ]: No checkpoint found
# N=78, seed=141 [PENDING ]: No checkpoint found
# N=80, seed=141 [PENDING ]: No checkpoint found
# N=82, seed=141 [PENDING ]: No checkpoint found
# N=84, seed=141 [PENDING ]: No checkpoint found
# N=86, seed=141 [PENDING ]: No checkpoint found
# N=88, seed=141 [PENDING ]: No checkpoint found
# N=90, seed=141 [PENDING ]: No checkpoint found
# N=92, seed=141 [PENDING ]: No checkpoint found
# N=94, seed=141 [PENDING ]: No checkpoint found
# N=96, seed=141 [PENDING ]: No checkpoint found
# N=98, seed=141 [PENDING ]: No checkpoint found
# N=100, seed=141 [PENDING ]: No checkpoint found
# N=102, seed=141 [PENDING ]: No checkpoint found
# N=104, seed=141 [PENDING ]: No checkpoint found
# N=106, seed=141 [PENDING ]: No checkpoint found
# N=108, seed=141 [PENDING ]: No checkpoint found
# N=110, seed=141 [PENDING ]: No checkpoint found
# N=112, seed=141 [PENDING ]: No checkpoint found
# N=114, seed=141 [PENDING ]: No checkpoint found
# N=116, seed=141 [PENDING ]: No checkpoint found
# N=118, seed=141 [PENDING ]: No checkpoint found
# N=120, seed=141 [PENDING ]: No checkpoint found
# N=122, seed=141 [PENDING ]: No checkpoint found
# N=124, seed=141 [PENDING ]: No checkpoint found
# N=126, seed=141 [PENDING ]: No checkpoint found
# N=128, seed=141 [PENDING ]: No checkpoint found
# N=130, seed=141 [PENDING ]: No checkpoint found
# N=132, seed=141 [PENDING ]: No checkpoint found
# N=134, seed=141 [PENDING ]: No checkpoint found
# N=136, seed=141 [PENDING ]: No checkpoint found
# N=138, seed=141 [PENDING ]: No checkpoint found
# N=140, seed=141 [PENDING ]: No checkpoint found
# N=142, seed=141 [PENDING ]: No checkpoint found
# N=144, seed=141 [PENDING ]: No checkpoint found
# N=146, seed=141 [PENDING ]: No checkpoint found
# N=148, seed=141 [PENDING ]: No checkpoint found
# N=150, seed=141 [PENDING ]: No checkpoint found
# N=152, seed=141 [PENDING ]: No checkpoint found
# N=154, seed=141 [PENDING ]: No checkpoint found
# N=156, seed=141 [PENDING ]: No checkpoint found
# N=158, seed=141 [PENDING ]: No checkpoint found
# N=160, seed=141 [PENDING ]: No checkpoint found
# N=162, seed=141 [PENDING ]: No checkpoint found
# N=164, seed=141 [PENDING ]: No checkpoint found
# N=166, seed=141 [PENDING ]: No checkpoint found
# N=168, seed=141 [PENDING ]: No checkpoint found
# N=170, seed=141 [PENDING ]: No checkpoint found
# N=172, seed=141 [PENDING ]: No checkpoint found
# N=174, seed=141 [PENDING ]: No checkpoint found
# N=176, seed=141 [PENDING ]: No checkpoint found
# N=178, seed=141 [PENDING ]: No checkpoint found
# N=180, seed=141 [PENDING ]: No checkpoint found
# N=182, seed=141 [PENDING ]: No checkpoint found
# N=184, seed=141 [PENDING ]: No checkpoint found
# N=186, seed=141 [PENDING ]: No checkpoint found
# N=188, seed=141 [PENDING ]: No checkpoint found
# N=190, seed=141 [PENDING ]: No checkpoint found
# N=192, seed=141 [PENDING ]: No checkpoint found
# N=194, seed=141 [PENDING ]: No checkpoint found
# N=196, seed=141 [PENDING ]: No checkpoint found
# N=198, seed=141 [PENDING ]: No checkpoint found
# N=200, seed=141 [PENDING ]: No checkpoint found
# N=60, seed=142 [PENDING ]: No checkpoint found
# N=62, seed=142 [PENDING ]: No checkpoint found
# N=64, seed=142 [PENDING ]: No checkpoint found
# N=66, seed=142 [PENDING ]: No checkpoint found
# N=68, seed=142 [PENDING ]: No checkpoint found
# N=70, seed=142 [PENDING ]: No checkpoint found
# N=72, seed=142 [PENDING ]: No checkpoint found
# N=74, seed=142 [PENDING ]: No checkpoint found
# N=76, seed=142 [PENDING ]: No checkpoint found
# N=78, seed=142 [PENDING ]: No checkpoint found
# N=80, seed=142 [PENDING ]: No checkpoint found
# N=82, seed=142 [PENDING ]: No checkpoint found
# N=84, seed=142 [PENDING ]: No checkpoint found
# N=86, seed=142 [PENDING ]: No checkpoint found
# N=88, seed=142 [PENDING ]: No checkpoint found
# N=90, seed=142 [PENDING ]: No checkpoint found
# N=92, seed=142 [PENDING ]: No checkpoint found
# N=94, seed=142 [PENDING ]: No checkpoint found
# N=96, seed=142 [PENDING ]: No checkpoint found
# N=98, seed=142 [PENDING ]: No checkpoint found
# N=100, seed=142 [PENDING ]: No checkpoint found
# N=102, seed=142 [PENDING ]: No checkpoint found
# N=104, seed=142 [PENDING ]: No checkpoint found
# N=106, seed=142 [PENDING ]: No checkpoint found
# N=108, seed=142 [PENDING ]: No checkpoint found
# N=110, seed=142 [PENDING ]: No checkpoint found
# N=112, seed=142 [PENDING ]: No checkpoint found
# N=114, seed=142 [PENDING ]: No checkpoint found
# N=116, seed=142 [PENDING ]: No checkpoint found
# N=118, seed=142 [PENDING ]: No checkpoint found
# N=120, seed=142 [PENDING ]: No checkpoint found
# N=122, seed=142 [PENDING ]: No checkpoint found
# N=124, seed=142 [PENDING ]: No checkpoint found
# N=126, seed=142 [PENDING ]: No checkpoint found
# N=128, seed=142 [PENDING ]: No checkpoint found
# N=130, seed=142 [PENDING ]: No checkpoint found
# N=132, seed=142 [PENDING ]: No checkpoint found
# N=134, seed=142 [PENDING ]: No checkpoint found
# N=136, seed=142 [PENDING ]: No checkpoint found
# N=138, seed=142 [PENDING ]: No checkpoint found
# N=140, seed=142 [PENDING ]: No checkpoint found
# N=142, seed=142 [PENDING ]: No checkpoint found
# N=144, seed=142 [PENDING ]: No checkpoint found
# N=146, seed=142 [PENDING ]: No checkpoint found
# N=148, seed=142 [PENDING ]: No checkpoint found
# N=150, seed=142 [PENDING ]: No checkpoint found
# N=152, seed=142 [PENDING ]: No checkpoint found
# N=154, seed=142 [PENDING ]: No checkpoint found
# N=156, seed=142 [PENDING ]: No checkpoint found
# N=158, seed=142 [PENDING ]: No checkpoint found
# N=160, seed=142 [PENDING ]: No checkpoint found
# N=162, seed=142 [PENDING ]: No checkpoint found
# N=164, seed=142 [PENDING ]: No checkpoint found
# N=166, seed=142 [PENDING ]: No checkpoint found
# N=168, seed=142 [PENDING ]: No checkpoint found
# N=170, seed=142 [PENDING ]: No checkpoint found
# N=172, seed=142 [PENDING ]: No checkpoint found
# N=174, seed=142 [PENDING ]: No checkpoint found
# N=176, seed=142 [PENDING ]: No checkpoint found
# N=178, seed=142 [PENDING ]: No checkpoint found
# N=180, seed=142 [PENDING ]: No checkpoint found
# N=182, seed=142 [PENDING ]: No checkpoint found
# N=184, seed=142 [PENDING ]: No checkpoint found
# N=186, seed=142 [PENDING ]: No checkpoint found
# N=188, seed=142 [PENDING ]: No checkpoint found
# N=190, seed=142 [PENDING ]: No checkpoint found
# N=192, seed=142 [PENDING ]: No checkpoint found
# N=194, seed=142 [PENDING ]: No checkpoint found
# N=196, seed=142 [PENDING ]: No checkpoint found
# N=198, seed=142 [PENDING ]: No checkpoint found
# N=200, seed=142 [PENDING ]: No checkpoint found
# N=60, seed=143 [PENDING ]: No checkpoint found
# N=62, seed=143 [PENDING ]: No checkpoint found
# N=64, seed=143 [PENDING ]: No checkpoint found
# N=66, seed=143 [PENDING ]: No checkpoint found
# N=68, seed=143 [PENDING ]: No checkpoint found
# N=70, seed=143 [PENDING ]: No checkpoint found
# N=72, seed=143 [PENDING ]: No checkpoint found
# N=74, seed=143 [PENDING ]: No checkpoint found
# N=76, seed=143 [PENDING ]: No checkpoint found
# N=78, seed=143 [PENDING ]: No checkpoint found
# N=80, seed=143 [PENDING ]: No checkpoint found
# N=82, seed=143 [PENDING ]: No checkpoint found
# N=84, seed=143 [PENDING ]: No checkpoint found
# N=86, seed=143 [PENDING ]: No checkpoint found
# N=88, seed=143 [PENDING ]: No checkpoint found
# N=90, seed=143 [PENDING ]: No checkpoint found
# N=92, seed=143 [PENDING ]: No checkpoint found
# N=94, seed=143 [PENDING ]: No checkpoint found
# N=96, seed=143 [PENDING ]: No checkpoint found
# N=98, seed=143 [PENDING ]: No checkpoint found
# N=100, seed=143 [PENDING ]: No checkpoint found
# N=102, seed=143 [PENDING ]: No checkpoint found
# N=104, seed=143 [PENDING ]: No checkpoint found
# N=106, seed=143 [PENDING ]: No checkpoint found
# N=108, seed=143 [PENDING ]: No checkpoint found
# N=110, seed=143 [PENDING ]: No checkpoint found
# N=112, seed=143 [PENDING ]: No checkpoint found
# N=114, seed=143 [PENDING ]: No checkpoint found
# N=116, seed=143 [PENDING ]: No checkpoint found
# N=118, seed=143 [PENDING ]: No checkpoint found
# N=120, seed=143 [PENDING ]: No checkpoint found
# N=122, seed=143 [PENDING ]: No checkpoint found
# N=124, seed=143 [PENDING ]: No checkpoint found
# N=126, seed=143 [PENDING ]: No checkpoint found
# N=128, seed=143 [PENDING ]: No checkpoint found
# N=130, seed=143 [PENDING ]: No checkpoint found
# N=132, seed=143 [PENDING ]: No checkpoint found
# N=134, seed=143 [PENDING ]: No checkpoint found
# N=136, seed=143 [PENDING ]: No checkpoint found
# N=138, seed=143 [PENDING ]: No checkpoint found
# N=140, seed=143 [PENDING ]: No checkpoint found
# N=142, seed=143 [PENDING ]: No checkpoint found
# N=144, seed=143 [PENDING ]: No checkpoint found
# N=146, seed=143 [PENDING ]: No checkpoint found
# N=148, seed=143 [PENDING ]: No checkpoint found
# N=150, seed=143 [PENDING ]: No checkpoint found
# N=152, seed=143 [PENDING ]: No checkpoint found
# N=154, seed=143 [PENDING ]: No checkpoint found
# N=156, seed=143 [PENDING ]: No checkpoint found
# N=158, seed=143 [PENDING ]: No checkpoint found
# N=160, seed=143 [PENDING ]: No checkpoint found
# N=162, seed=143 [PENDING ]: No checkpoint found
# N=164, seed=143 [PENDING ]: No checkpoint found
# N=166, seed=143 [PENDING ]: No checkpoint found
# N=168, seed=143 [PENDING ]: No checkpoint found
# N=170, seed=143 [PENDING ]: No checkpoint found
# N=172, seed=143 [PENDING ]: No checkpoint found
# N=174, seed=143 [PENDING ]: No checkpoint found
# N=176, seed=143 [PENDING ]: No checkpoint found
# N=178, seed=143 [PENDING ]: No checkpoint found
# N=180, seed=143 [PENDING ]: No checkpoint found
# N=182, seed=143 [PENDING ]: No checkpoint found
# N=184, seed=143 [PENDING ]: No checkpoint found
# N=186, seed=143 [PENDING ]: No checkpoint found
# N=188, seed=143 [PENDING ]: No checkpoint found
# N=190, seed=143 [PENDING ]: No checkpoint found
# N=192, seed=143 [PENDING ]: No checkpoint found
# N=194, seed=143 [PENDING ]: No checkpoint found
# N=196, seed=143 [PENDING ]: No checkpoint found
# N=198, seed=143 [PENDING ]: No checkpoint found
# N=200, seed=143 [PENDING ]: No checkpoint found
#
# ============================================================
# Status: Running: 3, Pending: 281, Completed: 0, Errored: 0

# %% [markdown]
# ## Post-Processing

# %%
# Load all completed runners for analysis
completed_runners = {}

for N_trees, seed in N_TREES_SEED_LIST:
    filename = f'ga_N{N_trees}_seed{seed}'
    pickle_path = kgs.temp_dir + CHECKPOINT_DIR + filename + '.pickle'
    
    if os.path.isfile(pickle_path):
        try:
            runner = kgs.dill_load(pickle_path)
            completed_runners[(N_trees, seed)] = runner
            print(f"Loaded N={N_trees}, seed={seed}: {runner._current_generation} generations")
        except Exception as e:
            print(f"Failed to load N={N_trees}, seed={seed}: {e}")

print(f"\nTotal loaded: {len(completed_runners)} runners")

# %%
# Extract best solutions
import pack_vis_sol

for (N_trees, seed), runner in completed_runners.items():
    best_costs = [[float(x) for x in s[-1].flatten()] 
                  for s in runner.ga.best_costs_per_generation]
    print(f"\nN={N_trees}, seed={seed}: Best costs = {best_costs}")
    
    # Visualize best solution
    # (Adjust based on your GA structure - GAMulti vs single GA)
    try:
        plt.figure()
        pack_vis_sol.pack_vis_sol(runner.ga.champions[-1].phenotype)
        plt.title(f"N={N_trees}, seed={seed}, Cost={runner.ga.champions[-1].fitness[0]}")
    except Exception as e:
        print(f"Could not visualize N={N_trees}, seed={seed}: {e}")
