# %%
import sys
import os
sys.path.insert(0, os.path.join(os.getcwd(), '../../core'))
import kaggle_support as kgs
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import clear_output
import time
import multiprocess as mp
import copy
# Out:
# local
# WARNING: CUDA MPS not active

# %% [markdown]
# ## Configuration

# %%
DO_CHECK = False

# User inputs
N_TREES_LIST = [33,34,35,36]+list(np.arange(50,101)) if not DO_CHECK else [34,35,36,37]  # List of N_trees to run
N_PROCESSES = 3 if kgs.env=='local' else 8  # Maximum concurrent processes
DIAGNOSTIC_INTERVAL = 120  # Seconds between diagnostic updates
SEED_BASE = 85  # Base seed for reproducibility

# Set up checkpoint/log directory
CHECKPOINT_DIR = 'controller_runs/' if not DO_CHECK else 'check_runs/'
os.makedirs(kgs.temp_dir + CHECKPOINT_DIR, exist_ok=True)
print(f"Using checkpoint directory: {CHECKPOINT_DIR}")

# Create base runner configuration
import pack_ga3
import pack_runner

base_runner = pack_ga3.baseline()

base_runner.ga.do_legalize = True
base_runner.use_atomic_save = True  # Enable atomic saves for multiprocess safety

base_runner.diagnostic_plot = False  # Disabled in subprocessbase_runner.save_every = 1
if DO_CHECK:
    base_runner.n_generations = 1000
# Out:
# Using checkpoint directory: controller_runs/

# %% [markdown]
# ## Worker Function

# %%
def worker_function(N_trees, seed, base_runner_pickled, checkpoint_dir):
    """
    Worker process that runs GA for a specific N_trees.
    Runs in subprocess - output redirected to log file.
    """
    import sys
    import os
    sys.path.insert(0, os.path.join(os.getcwd(), '../../core'))
    import kaggle_support as kgs
    import copy
    
    # Redirect stdout/stderr to log file
    log_path = kgs.temp_dir + checkpoint_dir + f'ga_N{N_trees}_seed{seed}.log'
    log_file = open(log_path, 'a')
    sys.stdout = log_file
    sys.stderr = log_file
    
    print(f"\n{'='*60}")
    print(f"Starting worker: N_trees={N_trees}, seed={seed}")
    print(f"{'='*60}\n")
    
    try:
        # Unpickle base runner and configure
        import dill
        runner = dill.loads(base_runner_pickled)
        runner.seed = seed
        runner.filename = checkpoint_dir + f'ga_N{N_trees}_seed{seed}'
        
        # Configure for this N_trees
        runner.ga.ga_base.N_trees_to_do = N_trees
        
        # Check for existing checkpoint
        checkpoint_path =  kgs.temp_dir + runner.filename + '.pickle'
        if os.path.isfile(checkpoint_path):
            print(f"Loading checkpoint: {checkpoint_path}")
            runner = kgs.dill_load(checkpoint_path)
        
        # Run with atomic saves (enabled via use_atomic_save flag)
        runner.run()
        
        print(f"\nCompleted: N_trees={N_trees}, final generation={runner._current_generation}")
        
    except Exception as e:
        import traceback
        print(f"\nERROR in worker N_trees={N_trees}:")
        traceback.print_exc()
    finally:
        log_file.close()

# %% [markdown]
# ## Process Manager

# %%
class ProcessManager:
    """Manages pool of worker processes."""
    
    def __init__(self, N_trees_list, n_processes, base_runner, checkpoint_dir):
        self.N_trees_list = list(N_trees_list)
        self.n_processes = n_processes
        self.checkpoint_dir = checkpoint_dir
        self.base_runner_pickled = kgs.dill.dumps(base_runner)
        
        self.pending_tasks = [(N, SEED_BASE) for N in N_trees_list]
        self.running = {}  # {Process: (N_trees, seed)}
        self.completed = set()  # Set of N_trees values
        self.errored = {}  # {N_trees: exit_code}
        self.last_start_time = 0  # Track last process start time
        
    def start_process(self, N_trees, seed):
        """Start a new worker process."""
        p = mp.Process(target=worker_function, 
                      args=(N_trees, seed, self.base_runner_pickled, self.checkpoint_dir))
        p.start()
        self.running[p] = (N_trees, seed)
        self.last_start_time = time.time()
        print(f"Started process for N_trees={N_trees} (PID: {p.pid})")
        
    def update(self):
        """Check for completed processes and start new ones."""
        # Check running processes
        for p in list(self.running.keys()):
            if not p.is_alive():
                N_trees, seed = self.running[p]
                p.join()
                del self.running[p]
                if p.exitcode == 0:
                    self.completed.add(N_trees)
                    print(f"Process completed: N_trees={N_trees}")
                else:
                    self.errored[N_trees] = p.exitcode
                    print(f"Process FAILED: N_trees={N_trees} (exit code: {p.exitcode})")
        
        # Start new processes if slots available
        while len(self.running) < self.n_processes and self.pending_tasks:
            # Stagger startup: wait 5 seconds after last start
            time_since_last_start = time.time() - self.last_start_time
            if time_since_last_start < 5.0:
                time.sleep(5.0 - time_since_last_start)
            
            N_trees, seed = self.pending_tasks.pop(0)
            self.start_process(N_trees, seed)
    
    def get_status(self, N_trees):
        """Get status of a specific N_trees value."""
        if N_trees in self.errored:
            return f"ERROR (exit {self.errored[N_trees]})"
        if N_trees in self.completed:
            return "DONE"
        for p, (nt, seed) in self.running.items():
            if nt == N_trees:
                return "RUNNING"
        for nt, seed in self.pending_tasks:
            if nt == N_trees:
                return "PENDING"
        return "UNKNOWN"
    
    def is_complete(self):
        """Check if all tasks are done."""
        return len(self.pending_tasks) == 0 and len(self.running) == 0
    
    def status(self):
        """Return status string."""
        return (f"Running: {len(self.running)}, "
                f"Pending: {len(self.pending_tasks)}, "
                f"Completed: {len(self.completed)}, "
                f"Errored: {len(self.errored)}")

# %% [markdown]
# ## Diagnostic Display

# %%
def display_diagnostics(N_trees_list, checkpoint_dir, manager):
    """
    Load all runner pickles and display diagnostic plots.
    Handles missing/corrupted files gracefully.
    """
    
    # First, load all pickle files before clearing display
    runners = {}
    status_info = {}  # Store status and error messages
    
    for N_trees in N_trees_list:
        status = manager.get_status(N_trees)
        filename = f'ga_N{N_trees}_seed{SEED_BASE}'
        pickle_path = kgs.temp_dir + checkpoint_dir + filename + '.pickle'
        
        if os.path.isfile(pickle_path):
            try:
                runner = kgs.dill_load(pickle_path)
                runners[N_trees] = runner
                
                # Store info for later display
                best_costs = [[round(float(x), 6) for x in s[-1].flatten()] 
                              for s in runner.ga.best_costs_per_generation]
                status_info[N_trees] = {
                    'status': status,
                    'type': 'loaded',
                    'message': f"N={N_trees} [{status:8s}]: Gen {runner._current_generation}/{runner.n_generations} | Best: {best_costs}"
                }
            except Exception as e:
                status_info[N_trees] = {
                    'status': status,
                    'type': 'error',
                    'message': f"N={N_trees} [{status:8s}]: Error loading pickle - {str(e)[:50]}"
                }
        else:
            status_info[N_trees] = {
                'status': status,
                'type': 'missing',
                'message': f"N={N_trees} [{status:8s}]: No checkpoint found"
            }
    
    # Now clear output and display everything
    clear_output(wait=True)
    
    print(f"{'='*60}")
    print(f"Diagnostics Update - {time.strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"{'='*60}\n")
    
    # Print all status messages
    for N_trees in N_trees_list:
        print(status_info[N_trees]['message'])
    
    print(f"\n{'='*60}\n")
    
    # Display diagnostic plots for each runner
    for N_trees, runner in runners.items():
        try:
            runner.ga.diagnostic_plots(runner._current_generation - 1, None)            
            #plt.suptitle(f"N_trees={N_trees} (Gen {runner._current_generation})")
            #plt.show()
        except Exception as e:
            print(f"Error displaying diagnostics for N={N_trees}: {e}")

    plt.close('all')  # Close figures to prevent accumulation

# %% [markdown]
# ## Main Controller Loop

# %%
# Initialize process manager
manager = ProcessManager(N_TREES_LIST, N_PROCESSES, base_runner, CHECKPOINT_DIR)

print(f"Starting controller for N_trees={N_TREES_LIST}")
print(f"Max concurrent processes: {N_PROCESSES}")
print(f"Diagnostic interval: {DIAGNOSTIC_INTERVAL}s\n")

last_diagnostic_time = 0

try:
    while not manager.is_complete():
        # Update process pool
        manager.update()
        
        # Display diagnostics periodically
        current_time = time.time()
        if current_time - last_diagnostic_time >= DIAGNOSTIC_INTERVAL:
            display_diagnostics(N_TREES_LIST, CHECKPOINT_DIR, manager)
            print(f"\nStatus: {manager.status()}\n")
            last_diagnostic_time = current_time
        
        # Sleep briefly to avoid busy-waiting
        time.sleep(1)
    
    # Final update
    print("\n" + "="*60)
    print("All processes completed!")
    print("="*60 + "\n")
    display_diagnostics(N_TREES_LIST, CHECKPOINT_DIR, manager)
    
except KeyboardInterrupt:
    print("\n\nInterrupted by user!")
    print("Terminating running processes...")
    for p in manager.running.keys():
        p.terminate()
        p.join()
    print("Cleanup complete.")
# Out:
# ============================================================
# Diagnostics Update - 2025-12-27 20:15:52
# ============================================================
#
# N=1 [RUNNING ]: No checkpoint found
# N=2 [RUNNING ]: No checkpoint found
# N=3 [RUNNING ]: No checkpoint found
# N=4 [PENDING ]: No checkpoint found
# N=5 [PENDING ]: No checkpoint found
# N=6 [PENDING ]: No checkpoint found
# N=7 [PENDING ]: No checkpoint found
# N=8 [PENDING ]: No checkpoint found
# N=9 [PENDING ]: No checkpoint found
# N=10 [PENDING ]: No checkpoint found
# N=11 [PENDING ]: No checkpoint found
# N=12 [PENDING ]: No checkpoint found
# N=13 [PENDING ]: No checkpoint found
# N=14 [PENDING ]: No checkpoint found
# N=15 [PENDING ]: No checkpoint found
# N=16 [PENDING ]: No checkpoint found
# N=17 [PENDING ]: No checkpoint found
# N=18 [PENDING ]: No checkpoint found
# N=19 [PENDING ]: No checkpoint found
# N=20 [PENDING ]: No checkpoint found
# N=21 [PENDING ]: No checkpoint found
# N=22 [PENDING ]: No checkpoint found
# N=23 [PENDING ]: No checkpoint found
# N=24 [PENDING ]: No checkpoint found
# N=25 [PENDING ]: No checkpoint found
# N=26 [PENDING ]: No checkpoint found
# N=27 [PENDING ]: No checkpoint found
# N=28 [PENDING ]: No checkpoint found
# N=29 [PENDING ]: No checkpoint found
# N=30 [PENDING ]: No checkpoint found
# N=31 [PENDING ]: No checkpoint found
# N=32 [PENDING ]: No checkpoint found
# N=33 [PENDING ]: No checkpoint found
# N=34 [PENDING ]: No checkpoint found
# N=35 [PENDING ]: No checkpoint found
# N=36 [PENDING ]: No checkpoint found
# N=37 [PENDING ]: No checkpoint found
# N=38 [PENDING ]: No checkpoint found
# N=39 [PENDING ]: No checkpoint found
# N=40 [PENDING ]: No checkpoint found
# N=41 [PENDING ]: No checkpoint found
# N=42 [PENDING ]: No checkpoint found
# N=43 [PENDING ]: No checkpoint found
# N=44 [PENDING ]: No checkpoint found
# N=45 [PENDING ]: No checkpoint found
# N=46 [PENDING ]: No checkpoint found
# N=47 [PENDING ]: No checkpoint found
# N=48 [PENDING ]: No checkpoint found
# N=49 [PENDING ]: No checkpoint found
# N=50 [PENDING ]: No checkpoint found
# N=51 [PENDING ]: No checkpoint found
# N=52 [PENDING ]: No checkpoint found
# N=53 [PENDING ]: No checkpoint found
# N=54 [PENDING ]: No checkpoint found
# N=55 [PENDING ]: No checkpoint found
# N=56 [PENDING ]: No checkpoint found
# N=57 [PENDING ]: No checkpoint found
# N=58 [PENDING ]: No checkpoint found
# N=59 [PENDING ]: No checkpoint found
# N=60 [PENDING ]: No checkpoint found
# N=61 [PENDING ]: No checkpoint found
# N=62 [PENDING ]: No checkpoint found
# N=63 [PENDING ]: No checkpoint found
# N=64 [PENDING ]: No checkpoint found
# N=65 [PENDING ]: No checkpoint found
# N=66 [PENDING ]: No checkpoint found
# N=67 [PENDING ]: No checkpoint found
# N=68 [PENDING ]: No checkpoint found
# N=69 [PENDING ]: No checkpoint found
# N=70 [PENDING ]: No checkpoint found
# N=71 [PENDING ]: No checkpoint found
# N=72 [PENDING ]: No checkpoint found
# N=73 [PENDING ]: No checkpoint found
# N=74 [PENDING ]: No checkpoint found
# N=75 [PENDING ]: No checkpoint found
# N=76 [PENDING ]: No checkpoint found
# N=77 [PENDING ]: No checkpoint found
# N=78 [PENDING ]: No checkpoint found
# N=79 [PENDING ]: No checkpoint found
# N=80 [PENDING ]: No checkpoint found
# N=81 [PENDING ]: No checkpoint found
# N=82 [PENDING ]: No checkpoint found
# N=83 [PENDING ]: No checkpoint found
# N=84 [PENDING ]: No checkpoint found
# N=85 [PENDING ]: No checkpoint found
# N=86 [PENDING ]: No checkpoint found
# N=87 [PENDING ]: No checkpoint found
# N=88 [PENDING ]: No checkpoint found
# N=89 [PENDING ]: No checkpoint found
# N=90 [PENDING ]: No checkpoint found
# N=91 [PENDING ]: No checkpoint found
# N=92 [PENDING ]: No checkpoint found
# N=93 [PENDING ]: No checkpoint found
# N=94 [PENDING ]: No checkpoint found
# N=95 [PENDING ]: No checkpoint found
# N=96 [PENDING ]: No checkpoint found
# N=97 [PENDING ]: No checkpoint found
# N=98 [PENDING ]: No checkpoint found
# N=99 [PENDING ]: No checkpoint found
# N=100 [PENDING ]: No checkpoint found
# N=101 [PENDING ]: No checkpoint found
# N=102 [PENDING ]: No checkpoint found
# N=103 [PENDING ]: No checkpoint found
# N=104 [PENDING ]: No checkpoint found
# N=105 [PENDING ]: No checkpoint found
# N=106 [PENDING ]: No checkpoint found
# N=107 [PENDING ]: No checkpoint found
# N=108 [PENDING ]: No checkpoint found
# N=109 [PENDING ]: No checkpoint found
# N=110 [PENDING ]: No checkpoint found
# N=111 [PENDING ]: No checkpoint found
# N=112 [PENDING ]: No checkpoint found
# N=113 [PENDING ]: No checkpoint found
# N=114 [PENDING ]: No checkpoint found
# N=115 [PENDING ]: No checkpoint found
# N=116 [PENDING ]: No checkpoint found
# N=117 [PENDING ]: No checkpoint found
# N=118 [PENDING ]: No checkpoint found
# N=119 [PENDING ]: No checkpoint found
# N=120 [PENDING ]: No checkpoint found
# N=121 [PENDING ]: No checkpoint found
# N=122 [PENDING ]: No checkpoint found
# N=123 [PENDING ]: No checkpoint found
# N=124 [PENDING ]: No checkpoint found
# N=125 [PENDING ]: No checkpoint found
# N=126 [PENDING ]: No checkpoint found
# N=127 [PENDING ]: No checkpoint found
# N=128 [PENDING ]: No checkpoint found
# N=129 [PENDING ]: No checkpoint found
# N=130 [PENDING ]: No checkpoint found
# N=131 [PENDING ]: No checkpoint found
# N=132 [PENDING ]: No checkpoint found
# N=133 [PENDING ]: No checkpoint found
# N=134 [PENDING ]: No checkpoint found
# N=135 [PENDING ]: No checkpoint found
# N=136 [PENDING ]: No checkpoint found
# N=137 [PENDING ]: No checkpoint found
# N=138 [PENDING ]: No checkpoint found
# N=139 [PENDING ]: No checkpoint found
# N=140 [PENDING ]: No checkpoint found
# N=141 [PENDING ]: No checkpoint found
# N=142 [PENDING ]: No checkpoint found
# N=143 [PENDING ]: No checkpoint found
# N=144 [PENDING ]: No checkpoint found
# N=145 [PENDING ]: No checkpoint found
# N=146 [PENDING ]: No checkpoint found
# N=147 [PENDING ]: No checkpoint found
# N=148 [PENDING ]: No checkpoint found
# N=149 [PENDING ]: No checkpoint found
# N=150 [PENDING ]: No checkpoint found
# N=151 [PENDING ]: No checkpoint found
# N=152 [PENDING ]: No checkpoint found
# N=153 [PENDING ]: No checkpoint found
# N=154 [PENDING ]: No checkpoint found
# N=155 [PENDING ]: No checkpoint found
# N=156 [PENDING ]: No checkpoint found
# N=157 [PENDING ]: No checkpoint found
# N=158 [PENDING ]: No checkpoint found
# N=159 [PENDING ]: No checkpoint found
# N=160 [PENDING ]: No checkpoint found
# N=161 [PENDING ]: No checkpoint found
# N=162 [PENDING ]: No checkpoint found
# N=163 [PENDING ]: No checkpoint found
# N=164 [PENDING ]: No checkpoint found
# N=165 [PENDING ]: No checkpoint found
# N=166 [PENDING ]: No checkpoint found
# N=167 [PENDING ]: No checkpoint found
# N=168 [PENDING ]: No checkpoint found
# N=169 [PENDING ]: No checkpoint found
# N=170 [PENDING ]: No checkpoint found
# N=171 [PENDING ]: No checkpoint found
# N=172 [PENDING ]: No checkpoint found
# N=173 [PENDING ]: No checkpoint found
# N=174 [PENDING ]: No checkpoint found
# N=175 [PENDING ]: No checkpoint found
# N=176 [PENDING ]: No checkpoint found
# N=177 [PENDING ]: No checkpoint found
# N=178 [PENDING ]: No checkpoint found
# N=179 [PENDING ]: No checkpoint found
# N=180 [PENDING ]: No checkpoint found
# N=181 [PENDING ]: No checkpoint found
# N=182 [PENDING ]: No checkpoint found
# N=183 [PENDING ]: No checkpoint found
# N=184 [PENDING ]: No checkpoint found
# N=185 [PENDING ]: No checkpoint found
# N=186 [PENDING ]: No checkpoint found
# N=187 [PENDING ]: No checkpoint found
# N=188 [PENDING ]: No checkpoint found
# N=189 [PENDING ]: No checkpoint found
# N=190 [PENDING ]: No checkpoint found
# N=191 [PENDING ]: No checkpoint found
# N=192 [PENDING ]: No checkpoint found
# N=193 [PENDING ]: No checkpoint found
# N=194 [PENDING ]: No checkpoint found
# N=195 [PENDING ]: No checkpoint found
# N=196 [PENDING ]: No checkpoint found
# N=197 [PENDING ]: No checkpoint found
# N=198 [PENDING ]: No checkpoint found
# N=199 [PENDING ]: No checkpoint found
#
# ============================================================
#
#
# Status: Running: 3, Pending: 196, Completed: 0, Errored: 0
#
# local
# WARNING: CUDA MPS not active

# %% [markdown]
# ## Post-Processing

# %%
# Load all completed runners for analysis
completed_runners = {}

for N_trees in N_TREES_LIST:
    filename = f'ga_N{N_trees}_seed{SEED_BASE}'
    pickle_path = kgs.temp_dir + CHECKPOINT_DIR + filename + '.pickle'
    
    if os.path.isfile(pickle_path):
        try:
            runner = kgs.dill_load(pickle_path)
            completed_runners[N_trees] = runner
            print(f"Loaded N={N_trees}: {runner._current_generation} generations")
        except Exception as e:
            print(f"Failed to load N={N_trees}: {e}")

print(f"\nTotal loaded: {len(completed_runners)} runners")
# Out:
# Loaded N=1: 13 generations
# Loaded N=2: 15 generations
# Loaded N=3: 15 generations
# Loaded N=4: 24 generations
# Loaded N=5: 22 generations
#
# Total loaded: 5 runners

# %%
# Extract best solutions
import pack_vis_sol

for N_trees, runner in completed_runners.items():
    best_costs = [[float(x) for x in s[-1].flatten()] 
                  for s in runner.ga.best_costs_per_generation]
    print(f"\nN={N_trees}: Best costs = {best_costs}")
    
    # Visualize best solution
    # (Adjust based on your GA structure - GAMulti vs single GA)
    try:
        plt.figure()
        pack_vis_sol.pack_vis_sol(runner.ga.champions[-1].phenotype)
        plt.title(f"N={N_trees}, Cost={runner.ga.champions[-1].fitness[0]}")
    except Exception as e:
        print(f"Could not visualize N={N_trees}: {e}")
# Out:
# N=1: Best costs = [[0.6595302820205688, 4.04965504685606e-07]]
#
# N=2: Best costs = [[0.44976481795310974, 5.501923396877828e-07]]
#
# N=3: Best costs = [[0.433534175157547, 1.259788405150175e-06]]
#
# N=4: Best costs = [[0.415526807308197, 1.8709821461015963e-06]]
#
# N=5: Best costs = [[0.41583356261253357, 1.6261394648608984e-06]]
