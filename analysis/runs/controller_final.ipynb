# %%
import sys
import os
sys.path.insert(0, os.path.join(os.getcwd(), '../../core'))
import kaggle_support as kgs
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import clear_output
import time
import multiprocess as mp
import copy
# Out:
# vast

# %% [markdown]
# ## Configuration

# %%
DO_CHECK = False

# User inputs
#N_TREES_LIST = [x.item() for x in np.arange(137,163,2)]  # List of N_trees to run
N_PROCESSES = 1 if kgs.env=='local' else 4  # Maximum concurrent processes
DIAGNOSTIC_INTERVAL = 120  # Seconds between diagnostic updates
SEED_LIST = [130,131]  # Base seed for reproducibility

# Derived inputs (edit manually to customize seeds per task)
N_TREES_SEED_LIST = [(N.item(), 130) for N in np.arange(25,201,2)] + [(N.item(), 131) for N in np.arange(25,201,2)] + \
                     [(N.item(), s.item()) for s in np.arange(132,140) for N in np.arange(25,101,2)] + \
                     [(N.item(), s.item()) for s in np.arange(300,302) for N in np.arange(24,201,2)] + \
                     [(N.item(), s.item()) for s in np.arange(302,304) for N in np.arange(25,201,2)] 

print(N_TREES_SEED_LIST)

# Set up checkpoint/log directory
CHECKPOINT_DIR = 'controller_runs/' if not DO_CHECK else 'check_runs/'
os.makedirs(kgs.temp_dir + CHECKPOINT_DIR, exist_ok=True)
print(f"Using checkpoint directory: {CHECKPOINT_DIR}")

# Create base runner configuration
import pack_ga3
import pack_runner

base_runner = None
#base_runner.n_generations = 500
# base_runner.ga.ga_base.initializer.ref_sol_crystal_type = 'Perfect dimer'
# base_runner.ga.ga_base.initializer.ref_sol_axis1_offset = None
# base_runner.ga.ga_base.initializer.ref_sol_axis2_offset = 'set!'
# base_runner.ga.stop_check_generations_scale = 10

#base_runner.ga.do_legalize = True
#base_runner.use_atomic_save = True  # Enable atomic saves for multiprocess safety

#base_runner.diagnostic_plot = False  # Disabled in subprocess
# Out:
# [(25, 130), (27, 130), (29, 130), (31, 130), (33, 130), (35, 130), (37, 130), (39, 130), (41, 130), (43, 130), (45, 130), (47, 130), (49, 130), (51, 130), (53, 130), (55, 130), (57, 130), (59, 130), (61, 130), (63, 130), (65, 130), (67, 130), (69, 130), (71, 130), (73, 130), (75, 130), (77, 130), (79, 130), (81, 130), (83, 130), (85, 130), (87, 130), (89, 130), (91, 130), (93, 130), (95, 130), (97, 130), (99, 130), (101, 130), (103, 130), (105, 130), (107, 130), (109, 130), (111, 130), (113, 130), (115, 130), (117, 130), (119, 130), (121, 130), (123, 130), (125, 130), (127, 130), (129, 130), (131, 130), (133, 130), (135, 130), (137, 130), (139, 130), (141, 130), (143, 130), (145, 130), (147, 130), (149, 130), (151, 130), (153, 130), (155, 130), (157, 130), (159, 130), (161, 130), (163, 130), (165, 130), (167, 130), (169, 130), (171, 130), (173, 130), (175, 130), (177, 130), (179, 130), (181, 130), (183, 130), (185, 130), (187, 130), (189, 130), (191, 130), (193, 130), (195, 130), (197, 130), (199, 130), (25, 131), (27, 131), (29, 131), (31, 131), (33, 131), (35, 131), (37, 131), (39, 131), (41, 131), (43, 131), (45, 131), (47, 131), (49, 131), (51, 131), (53, 131), (55, 131), (57, 131), (59, 131), (61, 131), (63, 131), (65, 131), (67, 131), (69, 131), (71, 131), (73, 131), (75, 131), (77, 131), (79, 131), (81, 131), (83, 131), (85, 131), (87, 131), (89, 131), (91, 131), (93, 131), (95, 131), (97, 131), (99, 131), (101, 131), (103, 131), (105, 131), (107, 131), (109, 131), (111, 131), (113, 131), (115, 131), (117, 131), (119, 131), (121, 131), (123, 131), (125, 131), (127, 131), (129, 131), (131, 131), (133, 131), (135, 131), (137, 131), (139, 131), (141, 131), (143, 131), (145, 131), (147, 131), (149, 131), (151, 131), (153, 131), (155, 131), (157, 131), (159, 131), (161, 131), (163, 131), (165, 131), (167, 131), (169, 131), (171, 131), (173, 131), (175, 131), (177, 131), (179, 131), (181, 131), (183, 131), (185, 131), (187, 131), (189, 131), (191, 131), (193, 131), (195, 131), (197, 131), (199, 131), (25, 132), (27, 132), (29, 132), (31, 132), (33, 132), (35, 132), (37, 132), (39, 132), (41, 132), (43, 132), (45, 132), (47, 132), (49, 132), (51, 132), (53, 132), (55, 132), (57, 132), (59, 132), (61, 132), (63, 132), (65, 132), (67, 132), (69, 132), (71, 132), (73, 132), (75, 132), (77, 132), (79, 132), (81, 132), (83, 132), (85, 132), (87, 132), (89, 132), (91, 132), (93, 132), (95, 132), (97, 132), (99, 132), (25, 133), (27, 133), (29, 133), (31, 133), (33, 133), (35, 133), (37, 133), (39, 133), (41, 133), (43, 133), (45, 133), (47, 133), (49, 133), (51, 133), (53, 133), (55, 133), (57, 133), (59, 133), (61, 133), (63, 133), (65, 133), (67, 133), (69, 133), (71, 133), (73, 133), (75, 133), (77, 133), (79, 133), (81, 133), (83, 133), (85, 133), (87, 133), (89, 133), (91, 133), (93, 133), (95, 133), (97, 133), (99, 133), (25, 134), (27, 134), (29, 134), (31, 134), (33, 134), (35, 134), (37, 134), (39, 134), (41, 134), (43, 134), (45, 134), (47, 134), (49, 134), (51, 134), (53, 134), (55, 134), (57, 134), (59, 134), (61, 134), (63, 134), (65, 134), (67, 134), (69, 134), (71, 134), (73, 134), (75, 134), (77, 134), (79, 134), (81, 134), (83, 134), (85, 134), (87, 134), (89, 134), (91, 134), (93, 134), (95, 134), (97, 134), (99, 134), (25, 135), (27, 135), (29, 135), (31, 135), (33, 135), (35, 135), (37, 135), (39, 135), (41, 135), (43, 135), (45, 135), (47, 135), (49, 135), (51, 135), (53, 135), (55, 135), (57, 135), (59, 135), (61, 135), (63, 135), (65, 135), (67, 135), (69, 135), (71, 135), (73, 135), (75, 135), (77, 135), (79, 135), (81, 135), (83, 135), (85, 135), (87, 135), (89, 135), (91, 135), (93, 135), (95, 135), (97, 135), (99, 135), (25, 136), (27, 136), (29, 136), (31, 136), (33, 136), (35, 136), (37, 136), (39, 136), (41, 136), (43, 136), (45, 136), (47, 136), (49, 136), (51, 136), (53, 136), (55, 136), (57, 136), (59, 136), (61, 136), (63, 136), (65, 136), (67, 136), (69, 136), (71, 136), (73, 136), (75, 136), (77,  ...
# Using checkpoint directory: controller_runs/

# %% [markdown]
# ## Worker Function

# %%
def worker_function(N_trees, seed, base_runner_pickled, checkpoint_dir):
    """
    Worker process that runs GA for a specific N_trees.
    Runs in subprocess - output redirected to log file.
    """
    import sys
    import os
    sys.path.insert(0, os.path.join(os.getcwd(), '../../core'))
    import kaggle_support as kgs
    import copy
    import numpy as np
    import pack_ga3
    
    # Redirect stdout/stderr to log file
    log_path = kgs.temp_dir + checkpoint_dir + f'ga_N{N_trees}_seed{seed}.log'
    log_file = open(log_path, 'a')
    sys.stdout = log_file
    sys.stderr = log_file
    
    print(f"\n{'='*60}")
    print(f"Starting worker: N_trees={N_trees}, seed={seed}")
    print(f"{'='*60}\n")
    
    try:
        # Unpickle base runner and configure
        import dill
        #runner = dill.loads(base_runner_pickled)
        if N_trees%2==0:
            runner = pack_ga3.baseline_symmetry_180_tesselated()
            skip_lists = kgs.dill_load(kgs.code_dir + 'skip_list.pickle')

            if seed%2==0:
                runner.ga.ga_base.initializer.ref_sol_axis2_offset = lambda r:0.
                if N_trees in skip_lists[0]:
                    raise ValueError(f"Skipping N_trees={N_trees} for seed={seed} as per skip list.")
            else:
                runner.ga.ga_base.initializer.ref_sol_axis2_offset = lambda r:0.5
                if N_trees in skip_lists[1]:
                    raise ValueError(f"Skipping N_trees={N_trees} for seed={seed} as per skip list.")
        else:
            runner = pack_ga3.baseline_tesselated()
            ref_sols = kgs.dill_load(kgs.code_dir + '../res/sols_standardized.pickle')
            runner.ga.ga_base.initializer.ref_sol_crystal_type = None
            

            if seed%2==0:
                runner.ga.ga_base.initializer.ref_sol = ref_sols[N_trees-2]
            else:
                runner.ga.ga_base.initializer.ref_sol = ref_sols[N_trees]
            assert runner.ga.ga_base.initializer.ref_sol is not None      
        runner.ga.do_legalize = True
        runner.use_atomic_save = True  # Enable atomic saves for multiprocess safety
        runner.diagnostic_plot = False  # Disabled in subprocess
        runner.seed = seed
        runner.filename = checkpoint_dir + f'ga_N{N_trees}_seed{seed}'

        
           
        #if N_trees>=190:
        #    runner.n_generations = 1000
        # if N_trees in [58,60,62,78]:
        #     runner.ga.ga_base.initializer.ref_sol_axis2_offset = 0.
        # else:
        #     assert N_trees in [74,76]
        #     runner.ga.ga_base.initializer.ref_sol_axis2_offset = 0.5

        # scores = {58:  (0.34414092),
        #      60:  (0.34393105),
        #      62:  (0.34281883),
        #      74:  (0.34060055),
        #      76:  (0.34060344),
        #      78:  (0.34023234)}
        # runner.ga.target_score = scores[N_trees]

        # if seed>94:
        #     runner.ga.ga_base.initializer.new_tree_placer = True
        #     runner.ga.ga_base.initializer.base_solution.edge_spacer = kgs.EdgeSpacerBasic(dist_x = 0.5, dist_y = 0.5)
        # if seed>96:
        #     runner.ga.ga_base.initializer.new_tree_placer = True
        #     runner.ga.ga_base.initializer.base_solution.edge_spacer = kgs.EdgeSpacerBasic(dist_x = 0.75, dist_y = 0.5)
        
        # Configure for this N_trees
        runner.ga.ga_base.N_trees_to_do = N_trees
        
        # Check for existing checkpoint
        checkpoint_path =  kgs.temp_dir + runner.filename + '.pickle'
        if os.path.isfile(checkpoint_path):
            print(f"Loading checkpoint: {checkpoint_path}")
            runner = kgs.dill_load(checkpoint_path)
        
        # Run with atomic saves (enabled via use_atomic_save flag)
        runner.run()
        
        print(f"\nCompleted: N_trees={N_trees}, seed={seed}, final generation={runner._current_generation}")
        
    except Exception as e:
        import traceback
        print(f"\nERROR in worker N_trees={N_trees}, seed={seed}:")
        traceback.print_exc()
    finally:
        log_file.close()

# %% [markdown]
# ## Process Manager

# %%
class ProcessManager:
    """Manages pool of worker processes."""
    
    def __init__(self, N_trees_seed_list, n_processes, base_runner, checkpoint_dir):
        self.N_trees_seed_list = list(N_trees_seed_list)
        self.n_processes = n_processes
        self.checkpoint_dir = checkpoint_dir
        self.base_runner_pickled = kgs.dill.dumps(base_runner)
        
        self.pending_tasks = list(self.N_trees_seed_list)
        self.running = {}  # {Process: (N_trees, seed)}
        self.completed = set()  # Set of (N_trees, seed) tuples
        self.errored = {}  # {(N_trees, seed): exit_code}
        self.last_start_time = 0  # Track last process start time
    
    @staticmethod
    def _format_task(N_trees, seed):
        return f"N_trees={N_trees}, seed={seed}"
        
    def start_process(self, N_trees, seed):
        """Start a new worker process, or mark done if done file exists."""
        # Check if done file already exists
        filename = f'ga_N{N_trees}_seed{seed}'
        done_path = kgs.temp_dir + self.checkpoint_dir + f'done/{filename}_done.pickle'
        
        if os.path.isfile(done_path):
            # Done file exists, just mark it as completed without starting process
            self.completed.add((N_trees, seed))
            print(f"Skipping {self._format_task(N_trees, seed)} - already done (found {done_path})")
            return
        
        # No done file, start the process normally
        p = mp.Process(target=worker_function, 
                      args=(N_trees, seed, self.base_runner_pickled, self.checkpoint_dir))
        p.start()
        self.running[p] = (N_trees, seed)
        self.last_start_time = time.time()
        print(f"Started process for {self._format_task(N_trees, seed)} (PID: {p.pid})")
        
    def update(self):
        """Check for completed processes and start new ones."""
        # Check running processes
        for p in list(self.running.keys()):
            if not p.is_alive():
                N_trees, seed = self.running[p]
                p.join()
                del self.running[p]
                if p.exitcode == 0:
                    self.completed.add((N_trees, seed))
                    print(f"Process completed: {self._format_task(N_trees, seed)}")
                else:
                    self.errored[(N_trees, seed)] = p.exitcode
                    print(f"Process FAILED: {self._format_task(N_trees, seed)} (exit code: {p.exitcode})")
        
        # Start new processes if slots available
        while len(self.running) < self.n_processes and self.pending_tasks:
            # Stagger startup: wait 5 seconds after last start
            time_since_last_start = time.time() - self.last_start_time
            if time_since_last_start < 5.0:
                time.sleep(5.0 - time_since_last_start)
            
            N_trees, seed = self.pending_tasks.pop(0)
            self.start_process(N_trees, seed)
    
    def get_status(self, task):
        """Get status of a specific (N_trees, seed) value."""
        N_trees, seed = task
        if task in self.errored:
            return f"ERROR (exit {self.errored[task]})"
        if task in self.completed:
            return "DONE"
        for p, (nt, sd) in self.running.items():
            if (nt, sd) == task:
                return "RUNNING"
        for pending_task in self.pending_tasks:
            if pending_task == task:
                return "PENDING"
        return "UNKNOWN"
    
    def is_complete(self):
        """Check if all tasks are done."""
        return len(self.pending_tasks) == 0 and len(self.running) == 0
    
    def status(self):
        """Return status string."""
        return (f"Running: {len(self.running)}, "
                f"Pending: {len(self.pending_tasks)}, "
                f"Completed: {len(self.completed)}, "
                f"Errored: {len(self.errored)}")

# %% [markdown]
# ## Diagnostic Display

# %%
def display_diagnostics(N_trees_seed_list, checkpoint_dir, manager):
    """
    Load all runner pickles and display diagnostic plots.
    Handles missing/corrupted files gracefully.
    """
    
    # First, load all pickle files before clearing display
    runners = {}
    status_info = {}  # Store status and error messages
    
    for N_trees, seed in N_trees_seed_list:
        task = (N_trees, seed)
        status = manager.get_status(task)
        filename = f'ga_N{N_trees}_seed{seed}'
        task_label = f"N={N_trees}, seed={seed}"
        
        # If process is DONE, load from done directory
        if status == "DONE":
            done_path = kgs.temp_dir + checkpoint_dir + f'done/{filename}_done.pickle'
            
            if os.path.isfile(done_path):
                try:
                    runner = kgs.dill_load(done_path)
                    
                    # Store info for later display (no diagnostic plots for done processes)
                    best_costs = [[round(float(x), 6) for x in s[-1].flatten()] 
                                  for s in runner.ga.best_costs_per_generation]
                    status_info[task] = {
                        'status': status,
                        'type': 'done',
                        'message': f"{task_label} [{status:8s}]: Gen {runner._current_generation}/{runner.n_generations} | Best: {best_costs}"
                    }
                except Exception as e:
                    status_info[task] = {
                        'status': 'MISSING',
                        'type': 'error',
                        'message': f"{task_label} [MISSING ]: Done file exists but failed to load - {str(e)[:50]}"
                    }
            else:
                status_info[task] = {
                    'status': 'MISSING',
                    'type': 'missing',
                    'message': f"{task_label} [MISSING ]"
                }
        else:
            # For ongoing processes, load checkpoint and prepare for diagnostic plots
            pickle_path = kgs.temp_dir + checkpoint_dir + filename + '.pickle'
            
            if os.path.isfile(pickle_path):
                try:
                    runner = kgs.dill_load(pickle_path)
                    if status == "RUNNING":
                        runners[task] = runner  # Only add to runners for diagnostic plots
                    
                    # Store info for later display
                    best_costs = [[round(float(x), 6) for x in s[-1].flatten()] 
                                  for s in runner.ga.best_costs_per_generation]
                    status_info[task] = {
                        'status': status,
                        'type': 'loaded',
                        'message': f"{task_label} [{status:8s}]: Gen {runner._current_generation}/{runner.n_generations} | Best: {best_costs}"
                    }
                except Exception as e:
                    status_info[task] = {
                        'status': status,
                        'type': 'error',
                        'message': f"{task_label} [{status:8s}]: Error loading pickle - {str(e)[:50]}"
                    }
            else:
                status_info[task] = {
                    'status': status,
                    'type': 'missing',
                    'message': f"{task_label} [{status:8s}]: No checkpoint found"
                }
    
    # Now clear output and display everything
    clear_output(wait=True)
    
    print(f"{'='*60}")
    print(f"Diagnostics Update - {time.strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"{'='*60}\n")
    
    # Print all status messages
    for task in N_trees_seed_list:
        print(status_info[task]['message'])
    
    print(f"\n{'='*60}\n")
    
    # Display diagnostic plots ONLY for ongoing processes (runners dict only contains those)
    for (N_trees, seed), runner in runners.items():
        try:
            runner.ga.diagnostic_plots(runner._current_generation - 1, None)            
            #plt.suptitle(f"N_trees={N_trees} (Gen {runner._current_generation})")
            #plt.show()
        except Exception as e:
            print(f"Error displaying diagnostics for N={N_trees}, seed={seed}: {e}")

    plt.close('all')  # Close figures to prevent accumulation

# %% [markdown]
# ## Main Controller Loop

# %%
# Initialize process manager
manager = ProcessManager(N_TREES_SEED_LIST, N_PROCESSES, base_runner, CHECKPOINT_DIR)

task_labels = [f"(N={N}, seed={seed})" for N, seed in N_TREES_SEED_LIST]
print(f"Starting controller for tasks: {task_labels}")
print(f"Max concurrent processes: {N_PROCESSES}")
print(f"Diagnostic interval: {DIAGNOSTIC_INTERVAL}s\n")

last_diagnostic_time = 0

try:
    while not manager.is_complete():
        # Update process pool
        manager.update()
        
        # Display diagnostics periodically
        current_time = time.time()
        if current_time - last_diagnostic_time >= DIAGNOSTIC_INTERVAL:
            display_diagnostics(N_TREES_SEED_LIST, CHECKPOINT_DIR, manager)
            print(f"\nStatus: {manager.status()}\n")
            last_diagnostic_time = current_time
        
        # Sleep briefly to avoid busy-waiting
        time.sleep(1)
    
    # Final update
    print("\n" + "="*60)
    print("All processes completed!")
    print("="*60 + "\n")
    display_diagnostics(N_TREES_SEED_LIST, CHECKPOINT_DIR, manager)
    
except KeyboardInterrupt:
    print("\n\nInterrupted by user!")
    print("Terminating running processes...")
    for p in manager.running.keys():
        p.terminate()
        p.join()
    print("Cleanup complete.")
# Out:
# ============================================================
# Diagnostics Update - 2026-01-22 19:28:53
# ============================================================
#
# N=25, seed=130 [DONE    ]: Gen 604/60000 | Best: [[0.358062, 7e-06]]
# N=27, seed=130 [DONE    ]: Gen 696/60000 | Best: [[0.35647, 1e-05]]
# N=29, seed=130 [DONE    ]: Gen 1140/60000 | Best: [[0.355045, 1.2e-05]]
# N=31, seed=130 [DONE    ]: Gen 751/60000 | Best: [[0.352258, 1.1e-05]]
# N=33, seed=130 [DONE    ]: Gen 806/60000 | Best: [[0.355984, 1.4e-05]]
# N=35, seed=130 [DONE    ]: Gen 854/60000 | Best: [[0.353409, 1.8e-05]]
# N=37, seed=130 [DONE    ]: Gen 788/60000 | Best: [[0.349806, 1.4e-05]]
# N=39, seed=130 [DONE    ]: Gen 1214/60000 | Best: [[0.350403, 2.3e-05]]
# N=41, seed=130 [DONE    ]: Gen 1081/60000 | Best: [[0.35144, 1.5e-05]]
# N=43, seed=130 [DONE    ]: Gen 1025/60000 | Best: [[0.349914, 2.1e-05]]
# N=45, seed=130 [DONE    ]: Gen 1053/60000 | Best: [[0.348068, 2.2e-05]]
# N=47, seed=130 [DONE    ]: Gen 1443/60000 | Best: [[0.34739, 2.1e-05]]
# N=49, seed=130 [DONE    ]: Gen 2228/60000 | Best: [[0.348249, 1.8e-05]]
# N=51, seed=130 [DONE    ]: Gen 1388/60000 | Best: [[0.346905, 1.6e-05]]
# N=53, seed=130 [DONE    ]: Gen 1157/60000 | Best: [[0.345225, 1.5e-05]]
# N=55, seed=130 [DONE    ]: Gen 1226/60000 | Best: [[0.343581, 3.1e-05]]
# N=57, seed=130 [DONE    ]: Gen 1867/60000 | Best: [[0.344561, 2.9e-05]]
# N=59, seed=130 [DONE    ]: Gen 1383/60000 | Best: [[0.344083, 2.5e-05]]
# N=61, seed=130 [DONE    ]: Gen 1732/60000 | Best: [[0.343628, 3.2e-05]]
# N=63, seed=130 [DONE    ]: Gen 1376/60000 | Best: [[0.343938, 1.9e-05]]
# N=65, seed=130 [DONE    ]: Gen 1458/60000 | Best: [[0.342413, 3.7e-05]]
# N=67, seed=130 [DONE    ]: Gen 1425/60000 | Best: [[0.341652, 1.9e-05]]
# N=69, seed=130 [DONE    ]: Gen 2384/60000 | Best: [[0.340167, 2.1e-05]]
# N=71, seed=130 [DONE    ]: Gen 1708/60000 | Best: [[0.341284, 1.8e-05]]
# N=73, seed=130 [DONE    ]: Gen 2604/60000 | Best: [[0.34094, 3.1e-05]]
# N=75, seed=130 [DONE    ]: Gen 1765/60000 | Best: [[0.340978, 3.8e-05]]
# N=77, seed=130 [DONE    ]: Gen 1805/60000 | Best: [[0.341029, 2.5e-05]]
# N=79, seed=130 [DONE    ]: Gen 2578/60000 | Best: [[0.338879, 4.4e-05]]
# N=81, seed=130 [DONE    ]: Gen 1935/60000 | Best: [[0.339319, 4e-05]]
# N=83, seed=130 [DONE    ]: Gen 1972/60000 | Best: [[0.337932, 3.9e-05]]
# N=85, seed=130 [DONE    ]: Gen 1819/60000 | Best: [[0.338763, 2.8e-05]]
# N=87, seed=130 [DONE    ]: Gen 1943/60000 | Best: [[0.337761, 3.3e-05]]
# N=89, seed=130 [DONE    ]: Gen 2653/60000 | Best: [[0.337508, 5.3e-05]]
# N=91, seed=130 [DONE    ]: Gen 2153/60000 | Best: [[0.337629, 3e-05]]
# N=93, seed=130 [DONE    ]: Gen 2387/60000 | Best: [[0.337758, 2.8e-05]]
# N=95, seed=130 [DONE    ]: Gen 2137/60000 | Best: [[0.337525, 3.6e-05]]
# N=97, seed=130 [DONE    ]: Gen 2193/60000 | Best: [[0.335466, 2.9e-05]]
# N=99, seed=130 [DONE    ]: Gen 2979/60000 | Best: [[0.335249, 5.4e-05]]
# N=101, seed=130 [DONE    ]: Gen 2224/60000 | Best: [[0.335773, 4.3e-05]]
# N=103, seed=130 [DONE    ]: Gen 2532/60000 | Best: [[0.335567, 3.7e-05]]
# N=105, seed=130 [DONE    ]: Gen 2552/60000 | Best: [[0.336102, 5.1e-05]]
# N=107, seed=130 [DONE    ]: Gen 2546/60000 | Best: [[0.33591, 5.9e-05]]
# N=109, seed=130 [DONE    ]: Gen 3414/60000 | Best: [[0.335722, 4.7e-05]]
# N=111, seed=130 [DONE    ]: Gen 2752/60000 | Best: [[0.33664, 2.8e-05]]
# N=113, seed=130 [DONE    ]: Gen 2543/60000 | Best: [[0.334995, 5.5e-05]]
# N=115, seed=130 [DONE    ]: Gen 2902/60000 | Best: [[0.33336, 5.4e-05]]
# N=117, seed=130 [DONE    ]: Gen 2569/60000 | Best: [[0.333924, 4.2e-05]]
# N=119, seed=130 [DONE    ]: Gen 2862/60000 | Best: [[0.3323, 6.7e-05]]
# N=121, seed=130 [DONE    ]: Gen 2773/60000 | Best: [[0.333599, 3.3e-05]]
# N=123, seed=130 [DONE    ]: Gen 3831/60000 | Best: [[0.333078, 6.7e-05]]
# N=125, seed=130 [DONE    ]: Gen 3193/60000 | Best: [[0.333655, 6.6e-05]]
# N=127, seed=130 [DONE    ]: Gen 4182/60000 | Best: [[0.333872, 5.4e-05]]
# N=129, seed=130 [DONE    ]: Gen 3463/60000 | Best: [[0.333728, 6.9e-05]]
# N=131, seed=130 [DONE    ]: Gen 4496/60000 | Best: [[0.334683, 5.6e-05]]
# N=133, seed=130 [DONE    ]: Gen 3472/60000 | Best: [[0.334177, 4.3e-05]]
# N=135, seed=130 [DONE    ]: Gen 4668/60000 | Best: [[0.331853, 3.8e-05]]
# N=137, seed=130 [DONE    ]: Gen 3487/60000 | Best: [[0.33172, 4.1e-05]]
# N=139, seed=130 [DONE    ]: Gen 3699/60000 | Best: [[0.332682, 5.3e-05]]
# N=141, seed=130 [DONE    ]: Gen 4946/60000 | Best: [[0.331462, 5.1e-05]]
# N=143, seed=130 [DONE    ]: Gen 3441/60000 | Best: [[0.332068, 7.1e-05]]
# N=145, seed=130 [DONE    ]: Gen 3222/60000 | Best: [[0.33158, 4.9e-05]]
# N=147, seed=130 [DONE    ]: Gen 7624/60000 | Best: [[0.332919, 4.3e-05]]
# N=149, seed=130 [DONE    ]: Gen 3324/60000 | Best: [[0.332439, 4.5e-05]]
# N=151, seed=130 [DONE    ]: Gen 4543/60000 | Best: [[0.331596, 9.4e-05]]
# N=153, seed=130 [DONE    ]: Gen 4401/60000 | Best: [[0.331847, 6.6e-05]]
# N=155, seed=130 [DONE    ]: Gen 6976/60000 | Best: [[0.330646, 8.1e-05]]
# N=157, seed=130 [DONE    ]: Gen 4080/60000 | Best: [[0.330536, 4.7e-05]]
# N=159, seed=130 [DONE    ]: Gen 5166/60000 | Best: [[0.329705, 9.6e-05]]
# N=161, seed=130 [DONE    ]: Gen 4554/60000 | Best: [[0.330327, 7.7e-05]]
# N=163, seed=130 [DONE    ]: Gen 6510/60000 | Best: [[0.329862, 4.9e-05]]
# N=165, seed=130 [DONE    ]: Gen 4298/60000 | Best: [[0.330489, 7.9e-05]]
# N=167, seed=130 [DONE    ]: Gen 4355/60000 | Best: [[0.330391, 4.4e-05]]
# N=169, seed=130 [DONE    ]: Gen 4067/60000 | Best: [[0.331022, 8e-05]]
# N=171, seed=130 [DONE    ]: Gen 7061/60000 | Best: [[0.3302, 7.9e-05]]
# N=173, seed=130 [DONE    ]: Gen 4768/60000 | Best: [[0.330106, 4.6e-05]]
# N=175, seed=130 [DONE    ]: Gen 4665/60000 | Best: [[0.330378, 6.7e-05]]
# N=177, seed=130 [DONE    ]: Gen 6527/60000 | Best: [[0.330652, 7.2e-05]]
# N=179, seed=130 [DONE    ]: Gen 5275/60000 | Best: [[0.328747, 0.000103]]
# N=181, seed=130 [DONE    ]: Gen 5146/60000 | Best: [[0.328661, 5.4e-05]]
# N=183, seed=130 [DONE    ]: Gen 6705/60000 | Best: [[0.328213, 5.3e-05]]
# N=185, seed=130 [DONE    ]: Gen 4418/60000 | Best: [[0.328129, 8.8e-05]]
# N=187, seed=130 [DONE    ]: Gen 6205/60000 | Best: [[0.328046, 7.7e-05]]
# N=189, seed=130 [DONE    ]: Gen 7021/60000 | Best: [[0.327964, 0.000105]]
# N=191, seed=130 [DONE    ]: Gen 8695/60000 | Best: [[0.327884, 0.000111]]
# N=193, seed=130 [RUNNING ]: Gen 5600/60000 | Best: [[0.328892, 0.00012]]
# N=195, seed=130 [DONE    ]: Gen 4536/60000 | Best: [[0.329543, 5e-05]]
# N=197, seed=130 [DONE    ]: Gen 5038/60000 | Best: [[0.329102, 6e-05]]
# N=199, seed=130 [DONE    ]: Gen 4840/60000 | Best: [[0.328299, 5.5e-05]]
# N=25, seed=131 [DONE    ]: Gen 1291/60000 | Best: [[0.358062, 1.3e-05]]
# N=27, seed=131 [DONE    ]: Gen 676/60000 | Best: [[0.357226, 1e-05]]
# N=29, seed=131 [DONE    ]: Gen 638/60000 | Best: [[0.355045, 1.1e-05]]
# N=31, seed=131 [DONE    ]: Gen 794/60000 | Best: [[0.354891, 1.1e-05]]
# N=33, seed=131 [DONE    ]: Gen 802/60000 | Best: [[0.352972, 1.7e-05]]
# N=35, seed=131 [DONE    ]: Gen 834/60000 | Best: [[0.353033, 2.2e-05]]
# N=37, seed=131 [DONE    ]: Gen 823/60000 | Best: [[0.349806, 1.4e-05]]
# N=39, seed=131 [DONE    ]: Gen 990/60000 | Best: [[0.34928, 1.6e-05]]
# N=41, seed=131 [DONE    ]: Gen 1600/60000 | Best: [[0.350316, 2.2e-05]]
# N=43, seed=131 [DONE    ]: Gen 1053/60000 | Best: [[0.349167, 2.1e-05]]
# N=45, seed=131 [DONE    ]: Gen 1403/60000 | Best: [[0.348068, 1.4e-05]]
# N=47, seed=131 [DONE    ]: Gen 1087/60000 | Best: [[0.348136, 1.7e-05]]
# N=49, seed=131 [DONE    ]: Gen 1663/60000 | Best: [[0.34713, 2.6e-05]]
# N=51, seed=131 [DONE    ]: Gen 1114/60000 | Best: [[0.346532, 1.4e-05]]
# N=53, seed=131 [DONE    ]: Gen 1153/60000 | Best: [[0.345597, 1.8e-05]]
# N=55, seed=131 [DONE    ]: Gen 1194/60000 | Best: [[0.343581, 3.2e-05]]
# N=57, seed=131 [DONE    ]: Gen 1344/60000 | Best: [[0.343077, 3.3e-05]]
# N=59, seed=131 [DONE    ]: Gen 1422/60000 | Best: [[0.342971, 2e-05]]
# N=61, seed=131 [DONE    ]: Gen 1435/60000 | Best: [[0.344741, 2.1e-05]]
# N=63, seed=131 [DONE    ]: Gen 1354/60000 | Best: [[0.344309, 1.8e-05]]
# N=65, seed=131 [DONE    ]: Gen 1799/60000 | Best: [[0.342784, 2.5e-05]]
# N=67, seed=131 [DONE    ]: Gen 1717/60000 | Best: [[0.340544, 4e-05]]
# N=69, seed=131 [DONE    ]: Gen 1515/60000 | Best: [[0.341644, 1.9e-05]]
# N=71, seed=131 [DONE    ]: Gen 1922/60000 | Best: [[0.340546, 3.3e-05]]
# N=73, seed=131 [DONE    ]: Gen 1701/60000 | Best: [[0.341679, 1.8e-05]]
# N=75, seed=131 [DONE    ]: Gen 2004/60000 | Best: [[0.340978, 4e-05]]
# N=77, seed=131 [DONE    ]: Gen 1801/60000 | Best: [[0.339922, 3.7e-05]]
# N=79, seed=131 [DONE    ]: Gen 2226/60000 | Best: [[0.339984, 3.6e-05]]
# N=81, seed=131 [DONE    ]: Gen 1750/60000 | Best: [[0.33895, 3.8e-05]]
# N=83, seed=131 [DONE    ]: Gen 2445/60000 | Best: [[0.337932, 4e-05]]
# N=85, seed=131 [DONE    ]: Gen 1946/60000 | Best: [[0.338027, 3.9e-05]]
# N=87, seed=131 [DONE    ]: Gen 1824/60000 | Best: [[0.338497, 3.3e-05]]
# N=89, seed=131 [DONE    ]: Gen 3634/60000 | Best: [[0.337508, 4.2e-05]]
# N=91, seed=131 [DONE    ]: Gen 2339/60000 | Best: [[0.337629, 3.9e-05]]
# N=93, seed=131 [DONE    ]: Gen 2158/60000 | Best: [[0.338493, 4.1e-05]]
# N=95, seed=131 [DONE    ]: Gen 4966/60000 | Best: [[0.336057, 4.2e-05]]
# N=97, seed=131 [DONE    ]: Gen 2403/60000 | Best: [[0.335832, 3.6e-05]]
# N=99, seed=131 [DONE    ]: Gen 2424/60000 | Best: [[0.335982, 3.1e-05]]
# N=101, seed=131 [DONE    ]: Gen 2374/60000 | Best: [[0.33504, 5.9e-05]]
# N=103, seed=131 [DONE    ]: Gen 2234/60000 | Best: [[0.335567, 3.6e-05]]
# N=105, seed=131 [DONE    ]: Gen 3178/60000 | Best: [[0.335003, 6.8e-05]]
# N=107, seed=131 [DONE    ]: Gen 4443/60000 | Best: [[0.33591, 4.3e-05]]
# N=109, seed=131 [DONE    ]: Gen 2489/60000 | Best: [[0.336088, 3.2e-05]]
# N=111, seed=131 [DONE    ]: Gen 3690/60000 | Best: [[0.336273, 5.8e-05]]
# N=113, seed=131 [DONE    ]: Gen 2609/60000 | Best: [[0.334995, 5.2e-05]]
# N=115, seed=131 [DONE    ]: Gen 2561/60000 | Best: [[0.334091, 3.1e-05]]
# N=117, seed=131 [DONE    ]: Gen 2697/60000 | Best: [[0.332099, 4.3e-05]]
# N=119, seed=131 [DONE    ]: Gen 2875/60000 | Best: [[0.333395, 6.2e-05]]
# N=121, seed=131 [DONE    ]: Gen 3333/60000 | Best: [[0.332504, 5.2e-05]]
# N=123, seed=131 [DONE    ]: Gen 3201/60000 | Best: [[0.333078, 7e-05]]
# N=125, seed=131 [DONE    ]: Gen 2889/60000 | Best: [[0.334386, 3.7e-05]]
# N=127, seed=131 [DONE    ]: Gen 2916/60000 | Best: [[0.333872, 6.1e-05]]
# N=129, seed=131 [DONE    ]: Gen 3316/60000 | Best: [[0.333728, 5.4e-05]]
# N=131, seed=131 [DONE    ]: Gen 3314/60000 | Best: [[0.335049, 6.7e-05]]
# N=133, seed=131 [DONE    ]: Gen 3083/60000 | Best: [[0.331987, 6.3e-05]]
# N=135, seed=131 [DONE    ]: Gen 3279/60000 | Best: [[0.331853, 5.1e-05]]
# N=137, seed=131 [DONE    ]: Gen 3238/60000 | Best: [[0.332084, 4.4e-05]]
# N=139, seed=131 [DONE    ]: Gen 3356/60000 | Best: [[0.331225, 4.7e-05]]
# N=141, seed=131 [DONE    ]: Gen 3616/60000 | Best: [[0.33292, 4e-05]]
# N=143, seed=131 [DONE    ]: Gen 5560/60000 | Best: [[0.33134, 7.3e-05]]
# N=145, seed=131 [DONE    ]: Gen 3404/60000 | Best: [[0.33158, 5.1e-05]]
# N=147, seed=131 [DONE    ]: Gen 3344/60000 | Best: [[0.332919, 3.8e-05]]
# N=149, seed=131 [DONE    ]: Gen 3525/60000 | Best: [[0.332074, 4.9e-05]]
# N=151, seed=131 [DONE    ]: Gen 3613/60000 | Best: [[0.33196, 6.9e-05]]
# N=153, seed=131 [RUNNING ]: Gen 6350/60000 | Best: [[0.331483, 6.1e-05]]
# N=155, seed=131 [RUNNING ]: Gen 1500/60000 | Best: [[0.330646, 8.7e-05]]
# N=157, seed=131 [RUNNING ]: Gen 1450/60000 | Best: [[0.331264, 7.3e-05]]
# N=159, seed=131 [PENDING ]: Gen 900/60000 | Best: [[0.329705, 7.2e-05]]
# N=161, seed=131 [PENDING ]: No checkpoint found
# N=163, seed=131 [PENDING ]: No checkpoint found
# N=165, seed=131 [PENDING ]: No checkpoint found
# N=167, seed=131 [PENDING ]: Gen 2700/60000 | Best: [[0.330755, 8.9e-05]]
# N=169, seed=131 [PENDING ]: Gen 2600/60000 | Best: [[0.330659, 7.2e-05]]
# N=171, seed=131 [PENDING ]: Gen 2000/60000 | Best: [[0.3302, 8.3e-05]]
# N=173, seed=131 [PENDING ]: Gen 150/60000 | Best: [[0.339253, 5.1e-05]]
# N=175, seed=131 [PENDING ]: No checkpoint found
# N=177, seed=131 [PENDING ]: No checkpoint found
# N=179, seed=131 [PENDING ]: No checkpoint found
# N=181, seed=131 [PENDING ]: No checkpoint found
# N=183, seed=131 [PENDING ]: No checkpoint found
# N=185, seed=131 [PENDING ]: No checkpoint found
# N=187, seed=131 [PENDING ]: Gen 2400/60000 | Best: [[0.328409, 5e-05]]
# N=189, seed=131 [PENDING ]: Gen 1200/60000 | Best: [[0.327602, 8.9e-05]]
# N=191, seed=131 [PENDING ]: Gen 200/60000 | Best: [[0.335533, 8.7e-05]]
# N=193, seed=131 [PENDING ]: No checkpoint found
# N=195, seed=131 [PENDING ]: No checkpoint found
# N=197, seed=131 [PENDING ]: No checkpoint found
# N=199, seed=131 [PENDING ]: No checkpoint found
# N=25, seed=132 [PENDING ]: No checkpoint found
# N=27, seed=132 [PENDING ]: No checkpoint found
# N=29, seed=132 [PENDING ]: No checkpoint found
# N=31, seed=132 [PENDING ]: No checkpoint found
# N=33, seed=132 [PENDING ]: No checkpoint found
# N=35, seed=132 [PENDING ]: No checkpoint found
# N=37, seed=132 [PENDING ]: No checkpoint found
# N=39, seed=132 [PENDING ]: No checkpoint found
# N=41, seed=132 [PENDING ]: No checkpoint found
# N=43, seed=132 [PENDING ]: No checkpoint found
# N=45, seed=132 [PENDING ]: No checkpoint found
# N=47, seed=132 [PENDING ]: No checkpoint found
# N=49, seed=132 [PENDING ]: No checkpoint found
# N=51, seed=132 [PENDING ]: No checkpoint found
# N=53, seed=132 [PENDING ]: No checkpoint found
# N=55, seed=132 [PENDING ]: No checkpoint found
# N=57, seed=132 [PENDING ]: No checkpoint found
# N=59, seed=132 [PENDING ]: No checkpoint found
# N=61, seed=132 [PENDING ]: No checkpoint found
# N=63, seed=132 [PENDING ]: No checkpoint found
# N=65, seed=132 [PENDING ]: No checkpoint found
# N=67, seed=132 [PENDING ]: No checkpoint found
# N=69, seed=132 [PENDING ]: No checkpoint found
# N=71, seed=132 [PENDING ]: No checkpoint found
# N=73, seed=132 [PENDING ]: No checkpoint found
# N=75, seed=132 [PENDING ]: No checkpoint found
# N=77, seed=132 [PENDING ]: No checkpoint found
# N=79, seed=132 [PENDING ]: No checkpoint found
# N=81, seed=132 [PENDING ]: No checkpoint found
# N=83, seed=132 [PENDING ]: No checkpoint found
# N=85, seed=132 [PENDING ]: No checkpoint found
# N=87, seed=132 [PENDING ]: No checkpoint found
# N=89, seed=132 [PENDING ]: No checkpoint found
# N=91, seed=132 [PENDING ]: No checkpoint found
# N=93, seed=132 [PENDING ]: No checkpoint found
# N=95, seed=132 [PENDING ]: No checkpoint found
# N=97, seed=132 [PENDING ]: No checkpoint found
# N=99, seed=132 [PENDING ]: No checkpoint found
# N=25, seed=133 [PENDING ]: No checkpoint found
# N=27, seed=133 [PENDING ]: No checkpoint found
# N=29, seed=133 [PENDING ]: No checkpoint found
# N=31, seed=133 [PENDING ]: No checkpoint found
# N=33, seed=133 [PENDING ]: No checkpoint found
# N=35, seed=133 [PENDING ]: No checkpoint found
# N=37, seed=133 [PENDING ]: No checkpoint found
# N=39, seed=133 [PENDING ]: No checkpoint found
# N=41, seed=133 [PENDING ]: No checkpoint found
# N=43, seed=133 [PENDING ]: No checkpoint found
# N=45, seed=133 [PENDING ]: No checkpoint found
# N=47, seed=133 [PENDING ]: No checkpoint found
# N=49, seed=133 [PENDING ]: No checkpoint found
# N=51, seed=133 [PENDING ]: No checkpoint found
# N=53, seed=133 [PENDING ]: No checkpoint found
# N=55, seed=133 [PENDING ]: No checkpoint found
# N=57, seed=133 [PENDING ]: No checkpoint found
# N=59, seed=133 [PENDING ]: No checkpoint found
# N=61, seed=133 [PENDING ]: No checkpoint found
# N=63, seed=133 [PENDING ]: No checkpoint found
# N=65, seed=133 [PENDING ]: No checkpoint found
# N=67, seed=133 [PENDING ]: No checkpoint found
# N=69, seed=133 [PENDING ]: No checkpoint found
# N=71, seed=133 [PENDING ]: No checkpoint found
# N=73, seed=133 [PENDING ]: No checkpoint found
# N=75, seed=133 [PENDING ]: No checkpoint found
# N=77, seed=133 [PENDING ]: No checkpoint found
# N=79, seed=133 [PENDING ]: No checkpoint found
# N=81, seed=133 [PENDING ]: No checkpoint found
# N=83, seed=133 [PENDING ]: No checkpoint found
# N=85, seed=133 [PENDING ]: No checkpoint found
# N=87, seed=133 [PENDING ]: No checkpoint found
# N=89, seed=133 [PENDING ]: No checkpoint found
# N=91, seed=133 [PENDING ]: No checkpoint found
# N=93, seed=133 [PENDING ]: No checkpoint found
# N=95, seed=133 [PENDING ]: No checkpoint found
# N=97, seed=133 [PENDING ]: No checkpoint found
# N=99, seed=133 [PENDING ]: No checkpoint found
# N=25, seed=134 [PENDING ]: No checkpoint found
# N=27, seed=134 [PENDING ]: No checkpoint found
# N=29, seed=134 [PENDING ]: No checkpoint found
# N=31, seed=134 [PENDING ]: No checkpoint found
# N=33, seed=134 [PENDING ]: No checkpoint found
# N=35, seed=134 [PENDING ]: No checkpoint found
# N=37, seed=134 [PENDING ]: No checkpoint found
# N=39, seed=134 [PENDING ]: No checkpoint found
# N=41, seed=134 [PENDING ]: No checkpoint found
# N=43, seed=134 [PENDING ]: No checkpoint found
# N=45, seed=134 [PENDING ]: No checkpoint found
# N=47, seed=134 [PENDING ]: No checkpoint found
# N=49, seed=134 [PENDING ]: No checkpoint found
# N=51, seed=134 [PENDING ]: No checkpoint found
# N=53, seed=134 [PENDING ]: No checkpoint found
# N=55, seed=134 [PENDING ]: No checkpoint found
# N=57, seed=134 [PENDING ]: No checkpoint found
# N=59, seed=134 [PENDING ]: No checkpoint found
# N=61, seed=134 [PENDING ]: No checkpoint found
# N=63, seed=134 [PENDING ]: No checkpoint found
# N=65, seed=134 [PENDING ]: No checkpoint found
# N=67, seed=134 [PENDING ]: No checkpoint found
# N=69, seed=134 [PENDING ]: No checkpoint found
# N=71, seed=134 [PENDING ]: No checkpoint found
# N=73, seed=134 [PENDING ]: No checkpoint found
# N=75, seed=134 [PENDING ]: No checkpoint found
# N=77, seed=134 [PENDING ]: No checkpoint found
# N=79, seed=134 [PENDING ]: No checkpoint found
# N=81, seed=134 [PENDING ]: No checkpoint found
# N=83, seed=134 [PENDING ]: No checkpoint found
# N=85, seed=134 [PENDING ]: No checkpoint found
# N=87, seed=134 [PENDING ]: No checkpoint found
# N=89, seed=134 [PENDING ]: No checkpoint found
# N=91, seed=134 [PENDING ]: No checkpoint found
# N=93, seed=134 [PENDING ]: No checkpoint found
# N=95, seed=134 [PENDING ]: No checkpoint found
# N=97, seed=134 [PENDING ]: No checkpoint found
# N=99, seed=134 [PENDING ]: No checkpoint found
# N=25, seed=135 [PENDING ]: No checkpoint found
# N=27, seed=135 [PENDING ]: No checkpoint found
# N=29, seed=135 [PENDING ]: No checkpoint found
# N=31, seed=135 [PENDING ]: No checkpoint found
# N=33, seed=135 [PENDING ]: No checkpoint found
# N=35, seed=135 [PENDING ]: No checkpoint found
# N=37, seed=135 [PENDING ]: No checkpoint found
# N=39, seed=135 [PENDING ]: No checkpoint found
# N=41, seed=135 [PENDING ]: No checkpoint found
# N=43, seed=135 [PENDING ]: No checkpoint found
# N=45, seed=135 [PENDING ]: No checkpoint found
# N=47, seed=135 [PENDING ]: No checkpoint found
# N=49, seed=135 [PENDING ]: No checkpoint found
# N=51, seed=135 [PENDING ]: No checkpoint found
# N=53, seed=135 [PENDING ]: No checkpoint found
# N=55, seed=135 [PENDING ]: No checkpoint found
# N=57, seed=135 [PENDING ]: No checkpoint found
# N=59, seed=135 [PENDING ]: No checkpoint found
# N=61, seed=135 [PENDING ]: No checkpoint found
# N=63, seed=135 [PENDING ]: No checkpoint found
# N=65, seed=135 [PENDING ]: No checkpoint found
# N=67, seed=135 [PENDING ]: No checkpoint found
# N=69, seed=135 [PENDING ]: No checkpoint found
# N=71, seed=135 [PENDING ]: No checkpoint found
# N=73, seed=135 [PENDING ]: No checkpoint found
# N=75, seed=135 [PENDING ]: No checkpoint found
# N=77, seed=135 [PENDING ]: No checkpoint found
# N=79, seed=135 [PENDING ]: No checkpoint found
# N=81, seed=135 [PENDING ]: No checkpoint found
# N=83, seed=135 [PENDING ]: No checkpoint found
# N=85, seed=135 [PENDING ]: No checkpoint found
# N=87, seed=135 [PENDING ]: No checkpoint found
# N=89, seed=135 [PENDING ]: No checkpoint found
# N=91, seed=135 [PENDING ]: No checkpoint found
# N=93, seed=135 [PENDING ]: No checkpoint found
# N=95, seed=135 [PENDING ]: No checkpoint found
# N=97, seed=135 [PENDING ]: No checkpoint found
# N=99, seed=135 [PENDING ]: No checkpoint found
# N=25, seed=136 [PENDING ]: No checkpoint found
# N=27, seed=136 [PENDING ]: No checkpoint found
# N=29, seed=136 [PENDING ]: No checkpoint found
# N=31, seed=136 [PENDING ]: No checkpoint found
# N=33, seed=136 [PENDING ]: No checkpoint found
# N=35, seed=136 [PENDING ]: No checkpoint found
# N=37, seed=136 [PENDING ]: No checkpoint found
# N=39, seed=136 [PENDING ]: No checkpoint found
# N=41, seed=136 [PENDING ]: No checkpoint found
# N=43, seed=136 [PENDING ]: No checkpoint found
# N=45, seed=136 [PENDING ]: No checkpoint found
# N=47, seed=136 [PENDING ]: No checkpoint found
# N=49, seed=136 [PENDING ]: No checkpoint found
# N=51, seed=136 [PENDING ]: No checkpoint found
# N=53, seed=136 [PENDING ]: No checkpoint found
# N=55, seed=136 [PENDING ]: No checkpoint found
# N=57, seed=136 [PENDING ]: No checkpoint found
# N=59, seed=136 [PENDING ]: No checkpoint found
# N=61, seed=136 [PENDING ]: No checkpoint found
# N=63, seed=136 [PENDING ]: No checkpoint found
# N=65, seed=136 [PENDING ]: No checkpoint found
# N=67, seed=136 [PENDING ]: No checkpoint found
# N=69, seed=136 [PENDING ]: No checkpoint found
# N=71, seed=136 [PENDING ]: No checkpoint found
# N=73, seed=136 [PENDING ]: No checkpoint found
# N=75, seed=136 [PENDING ]: No checkpoint found
# N=77, seed=136 [PENDING ]: No checkpoint found
# N=79, seed=136 [PENDING ]: No checkpoint found
# N=81, seed=136 [PENDING ]: No checkpoint found
# N=83, seed=136 [PENDING ]: No checkpoint found
# N=85, seed=136 [PENDING ]: No checkpoint found
# N=87, seed=136 [PENDING ]: No checkpoint found
# N=89, seed=136 [PENDING ]: No checkpoint found
# N=91, seed=136 [PENDING ]: No checkpoint found
# N=93, seed=136 [PENDING ]: No checkpoint found
# N=95, seed=136 [PENDING ]: No checkpoint found
# N=97, seed=136 [PENDING ]: No checkpoint found
# N=99, seed=136 [PENDING ]: No checkpoint found
# N=25, seed=137 [PENDING ]: No checkpoint found
# N=27, seed=137 [PENDING ]: No checkpoint found
# N=29, seed=137 [PENDING ]: No checkpoint found
# N=31, seed=137 [PENDING ]: No checkpoint found
# N=33, seed=137 [PENDING ]: No checkpoint found
# N=35, seed=137 [PENDING ]: No checkpoint found
# N=37, seed=137 [PENDING ]: No checkpoint found
# N=39, seed=137 [PENDING ]: No checkpoint found
# N=41, seed=137 [PENDING ]: No checkpoint found
# N=43, seed=137 [PENDING ]: No checkpoint found
# N=45, seed=137 [PENDING ]: No checkpoint found
# N=47, seed=137 [PENDING ]: No checkpoint found
# N=49, seed=137 [PENDING ]: No checkpoint found
# N=51, seed=137 [PENDING ]: No checkpoint found
# N=53, seed=137 [PENDING ]: No checkpoint found
# N=55, seed=137 [PENDING ]: No checkpoint found
# N=57, seed=137 [PENDING ]: No checkpoint found
# N=59, seed=137 [PENDING ]: No checkpoint found
# N=61, seed=137 [PENDING ]: No checkpoint found
# N=63, seed=137 [PENDING ]: No checkpoint found
# N=65, seed=137 [PENDING ]: No checkpoint found
# N=67, seed=137 [PENDING ]: No checkpoint found
# N=69, seed=137 [PENDING ]: No checkpoint found
# N=71, seed=137 [PENDING ]: No checkpoint found
# N=73, seed=137 [PENDING ]: No checkpoint found
# N=75, seed=137 [PENDING ]: No checkpoint found
# N=77, seed=137 [PENDING ]: No checkpoint found
# N=79, seed=137 [PENDING ]: No checkpoint found
# N=81, seed=137 [PENDING ]: No checkpoint found
# N=83, seed=137 [PENDING ]: No checkpoint found
# N=85, seed=137 [PENDING ]: No checkpoint found
# N=87, seed=137 [PENDING ]: No checkpoint found
# N=89, seed=137 [PENDING ]: No checkpoint found
# N=91, seed=137 [PENDING ]: No checkpoint found
# N=93, seed=137 [PENDING ]: No checkpoint found
# N=95, seed=137 [PENDING ]: No checkpoint found
# N=97, seed=137 [PENDING ]: No checkpoint found
# N=99, seed=137 [PENDING ]: No checkpoint found
# N=25, seed=138 [PENDING ]: No checkpoint found
# N=27, seed=138 [PENDING ]: No checkpoint found
# N=29, seed=138 [PENDING ]: No checkpoint found
# N=31, seed=138 [PENDING ]: No checkpoint found
# N=33, seed=138 [PENDING ]: No checkpoint found
# N=35, seed=138 [PENDING ]: No checkpoint found
# N=37, seed=138 [PENDING ]: No checkpoint found
# N=39, seed=138 [PENDING ]: No checkpoint found
# N=41, seed=138 [PENDING ]: No checkpoint found
# N=43, seed=138 [PENDING ]: No checkpoint found
# N=45, seed=138 [PENDING ]: No checkpoint found
# N=47, seed=138 [PENDING ]: No checkpoint found
# N=49, seed=138 [PENDING ]: No checkpoint found
# N=51, seed=138 [PENDING ]: No checkpoint found
# N=53, seed=138 [PENDING ]: No checkpoint found
# N=55, seed=138 [PENDING ]: No checkpoint found
# N=57, seed=138 [PENDING ]: No checkpoint found
# N=59, seed=138 [PENDING ]: No checkpoint found
# N=61, seed=138 [PENDING ]: No checkpoint found
# N=63, seed=138 [PENDING ]: No checkpoint found
# N=65, seed=138 [PENDING ]: No checkpoint found
# N=67, seed=138 [PENDING ]: No checkpoint found
# N=69, seed=138 [PENDING ]: No checkpoint found
# N=71, seed=138 [PENDING ]: No checkpoint found
# N=73, seed=138 [PENDING ]: No checkpoint found
# N=75, seed=138 [PENDING ]: No checkpoint found
# N=77, seed=138 [PENDING ]: No checkpoint found
# N=79, seed=138 [PENDING ]: No checkpoint found
# N=81, seed=138 [PENDING ]: No checkpoint found
# N=83, seed=138 [PENDING ]: No checkpoint found
# N=85, seed=138 [PENDING ]: No checkpoint found
# N=87, seed=138 [PENDING ]: No checkpoint found
# N=89, seed=138 [PENDING ]: No checkpoint found
# N=91, seed=138 [PENDING ]: No checkpoint found
# N=93, seed=138 [PENDING ]: No checkpoint found
# N=95, seed=138 [PENDING ]: No checkpoint found
# N=97, seed=138 [PENDING ]: No checkpoint found
# N=99, seed=138 [PENDING ]: No checkpoint found
# N=25, seed=139 [PENDING ]: No checkpoint found
# N=27, seed=139 [PENDING ]: No checkpoint found
# N=29, seed=139 [PENDING ]: No checkpoint found
# N=31, seed=139 [PENDING ]: No checkpoint found
# N=33, seed=139 [PENDING ]: No checkpoint found
# N=35, seed=139 [PENDING ]: No checkpoint found
# N=37, seed=139 [PENDING ]: No checkpoint found
# N=39, seed=139 [PENDING ]: No checkpoint found
# N=41, seed=139 [PENDING ]: No checkpoint found
# N=43, seed=139 [PENDING ]: No checkpoint found
# N=45, seed=139 [PENDING ]: No checkpoint found
# N=47, seed=139 [PENDING ]: No checkpoint found
# N=49, seed=139 [PENDING ]: No checkpoint found
# N=51, seed=139 [PENDING ]: No checkpoint found
# N=53, seed=139 [PENDING ]: No checkpoint found
# N=55, seed=139 [PENDING ]: No checkpoint found
# N=57, seed=139 [PENDING ]: No checkpoint found
# N=59, seed=139 [PENDING ]: No checkpoint found
# N=61, seed=139 [PENDING ]: No checkpoint found
# N=63, seed=139 [PENDING ]: No checkpoint found
# N=65, seed=139 [PENDING ]: No checkpoint found
# N=67, seed=139 [PENDING ]: No checkpoint found
# N=69, seed=139 [PENDING ]: No checkpoint found
# N=71, seed=139 [PENDING ]: No checkpoint found
# N=73, seed=139 [PENDING ]: No checkpoint found
# N=75, seed=139 [PENDING ]: No checkpoint found
# N=77, seed=139 [PENDING ]: No checkpoint found
# N=79, seed=139 [PENDING ]: No checkpoint found
# N=81, seed=139 [PENDING ]: No checkpoint found
# N=83, seed=139 [PENDING ]: No checkpoint found
# N=85, seed=139 [PENDING ]: No checkpoint found
# N=87, seed=139 [PENDING ]: No checkpoint found
# N=89, seed=139 [PENDING ]: No checkpoint found
# N=91, seed=139 [PENDING ]: No checkpoint found
# N=93, seed=139 [PENDING ]: No checkpoint found
# N=95, seed=139 [PENDING ]: No checkpoint found
# N=97, seed=139 [PENDING ]: No checkpoint found
# N=99, seed=139 [PENDING ]: No checkpoint found
# N=24, seed=300 [PENDING ]: No checkpoint found
# N=26, seed=300 [PENDING ]: No checkpoint found
# N=28, seed=300 [PENDING ]: No checkpoint found
# N=30, seed=300 [PENDING ]: No checkpoint found
# N=32, seed=300 [PENDING ]: No checkpoint found
# N=34, seed=300 [PENDING ]: No checkpoint found
# N=36, seed=300 [PENDING ]: No checkpoint found
# N=38, seed=300 [PENDING ]: No checkpoint found
# N=40, seed=300 [PENDING ]: No checkpoint found
# N=42, seed=300 [PENDING ]: No checkpoint found
# N=44, seed=300 [PENDING ]: No checkpoint found
# N=46, seed=300 [PENDING ]: No checkpoint found
# N=48, seed=300 [PENDING ]: No checkpoint found
# N=50, seed=300 [PENDING ]: No checkpoint found
# N=52, seed=300 [PENDING ]: No checkpoint found
# N=54, seed=300 [PENDING ]: No checkpoint found
# N=56, seed=300 [PENDING ]: No checkpoint found
# N=58, seed=300 [PENDING ]: No checkpoint found
# N=60, seed=300 [PENDING ]: No checkpoint found
# N=62, seed=300 [PENDING ]: No checkpoint found
# N=64, seed=300 [PENDING ]: No checkpoint found
# N=66, seed=300 [PENDING ]: No checkpoint found
# N=68, seed=300 [PENDING ]: No checkpoint found
# N=70, seed=300 [PENDING ]: No checkpoint found
# N=72, seed=300 [PENDING ]: No checkpoint found
# N=74, seed=300 [PENDING ]: No checkpoint found
# N=76, seed=300 [PENDING ]: No checkpoint found
# N=78, seed=300 [PENDING ]: No checkpoint found
# N=80, seed=300 [PENDING ]: No checkpoint found
# N=82, seed=300 [PENDING ]: No checkpoint found
# N=84, seed=300 [PENDING ]: No checkpoint found
# N=86, seed=300 [PENDING ]: No checkpoint found
# N=88, seed=300 [PENDING ]: No checkpoint found
# N=90, seed=300 [PENDING ]: No checkpoint found
# N=92, seed=300 [PENDING ]: No checkpoint found
# N=94, seed=300 [PENDING ]: No checkpoint found
# N=96, seed=300 [PENDING ]: No checkpoint found
# N=98, seed=300 [PENDING ]: No checkpoint found
# N=100, seed=300 [PENDING ]: No checkpoint found
# N=102, seed=300 [PENDING ]: No checkpoint found
# N=104, seed=300 [PENDING ]: No checkpoint found
# N=106, seed=300 [PENDING ]: No checkpoint found
# N=108, seed=300 [PENDING ]: No checkpoint found
# N=110, seed=300 [PENDING ]: No checkpoint found
# N=112, seed=300 [PENDING ]: No checkpoint found
# N=114, seed=300 [PENDING ]: No checkpoint found
# N=116, seed=300 [PENDING ]: No checkpoint found
# N=118, seed=300 [PENDING ]: No checkpoint found
# N=120, seed=300 [PENDING ]: No checkpoint found
# N=122, seed=300 [PENDING ]: No checkpoint found
# N=124, seed=300 [PENDING ]: No checkpoint found
# N=126, seed=300 [PENDING ]: No checkpoint found
# N=128, seed=300 [PENDING ]: No checkpoint found
# N=130, seed=300 [PENDING ]: No checkpoint found
# N=132, seed=300 [PENDING ]: No checkpoint found
# N=134, seed=300 [PENDING ]: No checkpoint found
# N=136, seed=300 [PENDING ]: No checkpoint found
# N=138, seed=300 [PENDING ]: No checkpoint found
# N=140, seed=300 [PENDING ]: No checkpoint found
# N=142, seed=300 [PENDING ]: No checkpoint found
# N=144, seed=300 [PENDING ]: No checkpoint found
# N=146, seed=300 [PENDING ]: No checkpoint found
# N=148, seed=300 [PENDING ]: No checkpoint found
# N=150, seed=300 [PENDING ]: No checkpoint found
# N=152, seed=300 [PENDING ]: No checkpoint found
# N=154, seed=300 [PENDING ]: No checkpoint found
# N=156, seed=300 [PENDING ]: No checkpoint found
# N=158, seed=300 [PENDING ]: No checkpoint found
# N=160, seed=300 [PENDING ]: No checkpoint found
# N=162, seed=300 [PENDING ]: No checkpoint found
# N=164, seed=300 [PENDING ]: No checkpoint found
# N=166, seed=300 [PENDING ]: No checkpoint found
# N=168, seed=300 [PENDING ]: No checkpoint found
# N=170, seed=300 [PENDING ]: No checkpoint found
# N=172, seed=300 [PENDING ]: No checkpoint found
# N=174, seed=300 [PENDING ]: No checkpoint found
# N=176, seed=300 [PENDING ]: No checkpoint found
# N=178, seed=300 [PENDING ]: No checkpoint found
# N=180, seed=300 [PENDING ]: No checkpoint found
# N=182, seed=300 [PENDING ]: No checkpoint found
# N=184, seed=300 [PENDING ]: No checkpoint found
# N=186, seed=300 [PENDING ]: No checkpoint found
# N=188, seed=300 [PENDING ]: No checkpoint found
# N=190, seed=300 [PENDING ]: No checkpoint found
# N=192, seed=300 [PENDING ]: No checkpoint found
# N=194, seed=300 [PENDING ]: No checkpoint found
# N=196, seed=300 [PENDING ]: No checkpoint found
# N=198, seed=300 [PENDING ]: No checkpoint found
# N=200, seed=300 [PENDING ]: No checkpoint found
# N=24, seed=301 [PENDING ]: No checkpoint found
# N=26, seed=301 [PENDING ]: No checkpoint found
# N=28, seed=301 [PENDING ]: No checkpoint found
# N=30, seed=301 [PENDING ]: No checkpoint found
# N=32, seed=301 [PENDING ]: No checkpoint found
# N=34, seed=301 [PENDING ]: No checkpoint found
# N=36, seed=301 [PENDING ]: No checkpoint found
# N=38, seed=301 [PENDING ]: No checkpoint found
# N=40, seed=301 [PENDING ]: No checkpoint found
# N=42, seed=301 [PENDING ]: No checkpoint found
# N=44, seed=301 [PENDING ]: No checkpoint found
# N=46, seed=301 [PENDING ]: No checkpoint found
# N=48, seed=301 [PENDING ]: No checkpoint found
# N=50, seed=301 [PENDING ]: No checkpoint found
# N=52, seed=301 [PENDING ]: No checkpoint found
# N=54, seed=301 [PENDING ]: No checkpoint found
# N=56, seed=301 [PENDING ]: No checkpoint found
# N=58, seed=301 [PENDING ]: No checkpoint found
# N=60, seed=301 [PENDING ]: No checkpoint found
# N=62, seed=301 [PENDING ]: No checkpoint found
# N=64, seed=301 [PENDING ]: No checkpoint found
# N=66, seed=301 [PENDING ]: No checkpoint found
# N=68, seed=301 [PENDING ]: No checkpoint found
# N=70, seed=301 [PENDING ]: No checkpoint found
# N=72, seed=301 [PENDING ]: No checkpoint found
# N=74, seed=301 [PENDING ]: No checkpoint found
# N=76, seed=301 [PENDING ]: No checkpoint found
# N=78, seed=301 [PENDING ]: No checkpoint found
# N=80, seed=301 [PENDING ]: No checkpoint found
# N=82, seed=301 [PENDING ]: No checkpoint found
# N=84, seed=301 [PENDING ]: No checkpoint found
# N=86, seed=301 [PENDING ]: No checkpoint found
# N=88, seed=301 [PENDING ]: No checkpoint found
# N=90, seed=301 [PENDING ]: No checkpoint found
# N=92, seed=301 [PENDING ]: No checkpoint found
# N=94, seed=301 [PENDING ]: No checkpoint found
# N=96, seed=301 [PENDING ]: No checkpoint found
# N=98, seed=301 [PENDING ]: No checkpoint found
# N=100, seed=301 [PENDING ]: No checkpoint found
# N=102, seed=301 [PENDING ]: No checkpoint found
# N=104, seed=301 [PENDING ]: No checkpoint found
# N=106, seed=301 [PENDING ]: No checkpoint found
# N=108, seed=301 [PENDING ]: No checkpoint found
# N=110, seed=301 [PENDING ]: No checkpoint found
# N=112, seed=301 [PENDING ]: No checkpoint found
# N=114, seed=301 [PENDING ]: No checkpoint found
# N=116, seed=301 [PENDING ]: No checkpoint found
# N=118, seed=301 [PENDING ]: No checkpoint found
# N=120, seed=301 [PENDING ]: No checkpoint found
# N=122, seed=301 [PENDING ]: No checkpoint found
# N=124, seed=301 [PENDING ]: No checkpoint found
# N=126, seed=301 [PENDING ]: No checkpoint found
# N=128, seed=301 [PENDING ]: No checkpoint found
# N=130, seed=301 [PENDING ]: No checkpoint found
# N=132, seed=301 [PENDING ]: No checkpoint found
# N=134, seed=301 [PENDING ]: No checkpoint found
# N=136, seed=301 [PENDING ]: No checkpoint found
# N=138, seed=301 [PENDING ]: No checkpoint found
# N=140, seed=301 [PENDING ]: No checkpoint found
# N=142, seed=301 [PENDING ]: No checkpoint found
# N=144, seed=301 [PENDING ]: No checkpoint found
# N=146, seed=301 [PENDING ]: No checkpoint found
# N=148, seed=301 [PENDING ]: No checkpoint found
# N=150, seed=301 [PENDING ]: No checkpoint found
# N=152, seed=301 [PENDING ]: No checkpoint found
# N=154, seed=301 [PENDING ]: No checkpoint found
# N=156, seed=301 [PENDING ]: No checkpoint found
# N=158, seed=301 [PENDING ]: No checkpoint found
# N=160, seed=301 [PENDING ]: No checkpoint found
# N=162, seed=301 [PENDING ]: No checkpoint found
# N=164, seed=301 [PENDING ]: No checkpoint found
# N=166, seed=301 [PENDING ]: No checkpoint found
# N=168, seed=301 [PENDING ]: No checkpoint found
# N=170, seed=301 [PENDING ]: No checkpoint found
# N=172, seed=301 [PENDING ]: No checkpoint found
# N=174, seed=301 [PENDING ]: No checkpoint found
# N=176, seed=301 [PENDING ]: No checkpoint found
# N=178, seed=301 [PENDING ]: No checkpoint found
# N=180, seed=301 [PENDING ]: No checkpoint found
# N=182, seed=301 [PENDING ]: No checkpoint found
# N=184, seed=301 [PENDING ]: No checkpoint found
# N=186, seed=301 [PENDING ]: No checkpoint found
# N=188, seed=301 [PENDING ]: No checkpoint found
# N=190, seed=301 [PENDING ]: No checkpoint found
# N=192, seed=301 [PENDING ]: No checkpoint found
# N=194, seed=301 [PENDING ]: No checkpoint found
# N=196, seed=301 [PENDING ]: No checkpoint found
# N=198, seed=301 [PENDING ]: No checkpoint found
# N=200, seed=301 [PENDING ]: No checkpoint found
# N=25, seed=302 [PENDING ]: No checkpoint found
# N=27, seed=302 [PENDING ]: No checkpoint found
# N=29, seed=302 [PENDING ]: No checkpoint found
# N=31, seed=302 [PENDING ]: No checkpoint found
# N=33, seed=302 [PENDING ]: No checkpoint found
# N=35, seed=302 [PENDING ]: No checkpoint found
# N=37, seed=302 [PENDING ]: No checkpoint found
# N=39, seed=302 [PENDING ]: No checkpoint found
# N=41, seed=302 [PENDING ]: No checkpoint found
# N=43, seed=302 [PENDING ]: No checkpoint found
# N=45, seed=302 [PENDING ]: No checkpoint found
# N=47, seed=302 [PENDING ]: No checkpoint found
# N=49, seed=302 [PENDING ]: No checkpoint found
# N=51, seed=302 [PENDING ]: No checkpoint found
# N=53, seed=302 [PENDING ]: No checkpoint found
# N=55, seed=302 [PENDING ]: No checkpoint found
# N=57, seed=302 [PENDING ]: No checkpoint found
# N=59, seed=302 [PENDING ]: No checkpoint found
# N=61, seed=302 [PENDING ]: No checkpoint found
# N=63, seed=302 [PENDING ]: No checkpoint found
# N=65, seed=302 [PENDING ]: No checkpoint found
# N=67, seed=302 [PENDING ]: No checkpoint found
# N=69, seed=302 [PENDING ]: No checkpoint found
# N=71, seed=302 [PENDING ]: No checkpoint found
# N=73, seed=302 [PENDING ]: No checkpoint found
# N=75, seed=302 [PENDING ]: No checkpoint found
# N=77, seed=302 [PENDING ]: No checkpoint found
# N=79, seed=302 [PENDING ]: No checkpoint found
# N=81, seed=302 [PENDING ]: No checkpoint found
# N=83, seed=302 [PENDING ]: No checkpoint found
# N=85, seed=302 [PENDING ]: No checkpoint found
# N=87, seed=302 [PENDING ]: No checkpoint found
# N=89, seed=302 [PENDING ]: No checkpoint found
# N=91, seed=302 [PENDING ]: No checkpoint found
# N=93, seed=302 [PENDING ]: No checkpoint found
# N=95, seed=302 [PENDING ]: No checkpoint found
# N=97, seed=302 [PENDING ]: No checkpoint found
# N=99, seed=302 [PENDING ]: No checkpoint found
# N=101, seed=302 [PENDING ]: No checkpoint found
# N=103, seed=302 [PENDING ]: No checkpoint found
# N=105, seed=302 [PENDING ]: No checkpoint found
# N=107, seed=302 [PENDING ]: No checkpoint found
# N=109, seed=302 [PENDING ]: No checkpoint found
# N=111, seed=302 [PENDING ]: No checkpoint found
# N=113, seed=302 [PENDING ]: No checkpoint found
# N=115, seed=302 [PENDING ]: No checkpoint found
# N=117, seed=302 [PENDING ]: No checkpoint found
# N=119, seed=302 [PENDING ]: No checkpoint found
# N=121, seed=302 [PENDING ]: No checkpoint found
# N=123, seed=302 [PENDING ]: No checkpoint found
# N=125, seed=302 [PENDING ]: No checkpoint found
# N=127, seed=302 [PENDING ]: No checkpoint found
# N=129, seed=302 [PENDING ]: No checkpoint found
# N=131, seed=302 [PENDING ]: No checkpoint found
# N=133, seed=302 [PENDING ]: No checkpoint found
# N=135, seed=302 [PENDING ]: No checkpoint found
# N=137, seed=302 [PENDING ]: No checkpoint found
# N=139, seed=302 [PENDING ]: No checkpoint found
# N=141, seed=302 [PENDING ]: No checkpoint found
# N=143, seed=302 [PENDING ]: No checkpoint found
# N=145, seed=302 [PENDING ]: No checkpoint found
# N=147, seed=302 [PENDING ]: No checkpoint found
# N=149, seed=302 [PENDING ]: No checkpoint found
# N=151, seed=302 [PENDING ]: No checkpoint found
# N=153, seed=302 [PENDING ]: No checkpoint found
# N=155, seed=302 [PENDING ]: No checkpoint found
# N=157, seed=302 [PENDING ]: No checkpoint found
# N=159, seed=302 [PENDING ]: No checkpoint found
# N=161, seed=302 [PENDING ]: No checkpoint found
# N=163, seed=302 [PENDING ]: No checkpoint found
# N=165, seed=302 [PENDING ]: No checkpoint found
# N=167, seed=302 [PENDING ]: No checkpoint found
# N=169, seed=302 [PENDING ]: No checkpoint found
# N=171, seed=302 [PENDING ]: No checkpoint found
# N=173, seed=302 [PENDING ]: No checkpoint found
# N=175, seed=302 [PENDING ]: No checkpoint found
# N=177, seed=302 [PENDING ]: No checkpoint found
# N=179, seed=302 [PENDING ]: No checkpoint found
# N=181, seed=302 [PENDING ]: No checkpoint found
# N=183, seed=302 [PENDING ]: No checkpoint found
# N=185, seed=302 [PENDING ]: No checkpoint found
# N=187, seed=302 [PENDING ]: No checkpoint found
# N=189, seed=302 [PENDING ]: No checkpoint found
# N=191, seed=302 [PENDING ]: No checkpoint found
# N=193, seed=302 [PENDING ]: No checkpoint found
# N=195, seed=302 [PENDING ]: No checkpoint found
# N=197, seed=302 [PENDING ]: No checkpoint found
# N=199, seed=302 [PENDING ]: No checkpoint found
# N=25, seed=303 [PENDING ]: No checkpoint found
# N=27, seed=303 [PENDING ]: No checkpoint found
# N=29, seed=303 [PENDING ]: No checkpoint found
# N=31, seed=303 [PENDING ]: No checkpoint found
# N=33, seed=303 [PENDING ]: No checkpoint found
# N=35, seed=303 [PENDING ]: No checkpoint found
# N=37, seed=303 [PENDING ]: No checkpoint found
# N=39, seed=303 [PENDING ]: No checkpoint found
# N=41, seed=303 [PENDING ]: No checkpoint found
# N=43, seed=303 [PENDING ]: No checkpoint found
# N=45, seed=303 [PENDING ]: No checkpoint found
# N=47, seed=303 [PENDING ]: No checkpoint found
# N=49, seed=303 [PENDING ]: No checkpoint found
# N=51, seed=303 [PENDING ]: No checkpoint found
# N=53, seed=303 [PENDING ]: No checkpoint found
# N=55, seed=303 [PENDING ]: No checkpoint found
# N=57, seed=303 [PENDING ]: No checkpoint found
# N=59, seed=303 [PENDING ]: No checkpoint found
# N=61, seed=303 [PENDING ]: No checkpoint found
# N=63, seed=303 [PENDING ]: No checkpoint found
# N=65, seed=303 [PENDING ]: No checkpoint found
# N=67, seed=303 [PENDING ]: No checkpoint found
# N=69, seed=303 [PENDING ]: No checkpoint found
# N=71, seed=303 [PENDING ]: No checkpoint found
# N=73, seed=303 [PENDING ]: No checkpoint found
# N=75, seed=303 [PENDING ]: No checkpoint found
# N=77, seed=303 [PENDING ]: No checkpoint found
# N=79, seed=303 [PENDING ]: No checkpoint found
# N=81, seed=303 [PENDING ]: No checkpoint found
# N=83, seed=303 [PENDING ]: No checkpoint found
# N=85, seed=303 [PENDING ]: No checkpoint found
# N=87, seed=303 [PENDING ]: No checkpoint found
# N=89, seed=303 [PENDING ]: No checkpoint found
# N=91, seed=303 [PENDING ]: No checkpoint found
# N=93, seed=303 [PENDING ]: No checkpoint found
# N=95, seed=303 [PENDING ]: No checkpoint found
# N=97, seed=303 [PENDING ]: No checkpoint found
# N=99, seed=303 [PENDING ]: No checkpoint found
# N=101, seed=303 [PENDING ]: No checkpoint found
# N=103, seed=303 [PENDING ]: No checkpoint found
# N=105, seed=303 [PENDING ]: No checkpoint found
# N=107, seed=303 [PENDING ]: No checkpoint found
# N=109, seed=303 [PENDING ]: No checkpoint found
# N=111, seed=303 [PENDING ]: No checkpoint found
# N=113, seed=303 [PENDING ]: No checkpoint found
# N=115, seed=303 [PENDING ]: No checkpoint found
# N=117, seed=303 [PENDING ]: No checkpoint found
# N=119, seed=303 [PENDING ]: No checkpoint found
# N=121, seed=303 [PENDING ]: No checkpoint found
# N=123, seed=303 [PENDING ]: No checkpoint found
# N=125, seed=303 [PENDING ]: No checkpoint found
# N=127, seed=303 [PENDING ]: No checkpoint found
# N=129, seed=303 [PENDING ]: No checkpoint found
# N=131, seed=303 [PENDING ]: No checkpoint found
# N=133, seed=303 [PENDING ]: No checkpoint found
# N=135, seed=303 [PENDING ]: No checkpoint found
# N=137, seed=303 [PENDING ]: No checkpoint found
# N=139, seed=303 [PENDING ]: No checkpoint found
# N=141, seed=303 [PENDING ]: No checkpoint found
# N=143, seed=303 [PENDING ]: No checkpoint found
# N=145, seed=303 [PENDING ]: No checkpoint found
# N=147, seed=303 [PENDING ]: No checkpoint found
# N=149, seed=303 [PENDING ]: No checkpoint found
# N=151, seed=303 [PENDING ]: No checkpoint found
# N=153, seed=303 [PENDING ]: No checkpoint found
# N=155, seed=303 [PENDING ]: No checkpoint found
# N=157, seed=303 [PENDING ]: No checkpoint found
# N=159, seed=303 [PENDING ]: No checkpoint found
# N=161, seed=303 [PENDING ]: No checkpoint found
# N=163, seed=303 [PENDING ]: No checkpoint found
# N=165, seed=303 [PENDING ]: No checkpoint found
# N=167, seed=303 [PENDING ]: No checkpoint found
# N=169, seed=303 [PENDING ]: No checkpoint found
# N=171, seed=303 [PENDING ]: No checkpoint found
# N=173, seed=303 [PENDING ]: No checkpoint found
# N=175, seed=303 [PENDING ]: No checkpoint found
# N=177, seed=303 [PENDING ]: No checkpoint found
# N=179, seed=303 [PENDING ]: No checkpoint found
# N=181, seed=303 [PENDING ]: No checkpoint found
# N=183, seed=303 [PENDING ]: No checkpoint found
# N=185, seed=303 [PENDING ]: No checkpoint found
# N=187, seed=303 [PENDING ]: No checkpoint found
# N=189, seed=303 [PENDING ]: No checkpoint found
# N=191, seed=303 [PENDING ]: No checkpoint found
# N=193, seed=303 [PENDING ]: No checkpoint found
# N=195, seed=303 [PENDING ]: No checkpoint found
# N=197, seed=303 [PENDING ]: No checkpoint found
# N=199, seed=303 [PENDING ]: No checkpoint found
#
# ============================================================
#
# init LAP CUDA
# Detected GPU compute capability: 12.0 (arch=sm_120)
# GPU max threads per block: 1024
# === Compiling LAP kernels ===
# Command: /usr/local/cuda/bin/nvcc -O3 -use_fast_math --extra-device-vectorization --ptxas-options=-v,--warn-on-spills -arch=sm_120 -cubin /packing/temp/lap_batch_saved.cu -o /packing/temp/lap_batch.cubin
# ptxas info    : 0 bytes gmem
# ptxas info    : Compiling entry function 'diversity_shortcut_kernel' for 'sm_120'
# ptxas info    : Function properties for diversity_shortcut_kernel
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 31 registers, used 1 barriers
# ptxas info    : Compile time = 13.734 ms
# ptxas info    : Compiling entry function 'compute_costs' for 'sm_120'
# ptxas info    : Function properties for compute_costs
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 37 registers, used 0 barriers
# ptxas info    : Compile time = 6.693 ms
# ptxas info    : Compiling entry function 'auction_kernel' for 'sm_120'
# ptxas info    : Function properties for auction_kernel
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 40 registers, used 0 barriers
# ptxas info    : Compile time = 11.808 ms
# ptxas info    : Compiling entry function 'hungarian_kernel' for 'sm_120'
# ptxas info    : Function properties for hungarian_kernel
#     1808 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 48 registers, used 0 barriers, 1808 bytes cumulative stack size
# ptxas info    : Compile time = 16.543 ms
#
#
# --- Kernel: hungarian_kernel ---
#   Max threads per block (kernel): 1024
#   Num registers: 48
#   Shared memory (bytes): 0
#   Const memory (bytes): 0
#   Local memory (bytes): 1808
#
# --- Kernel: auction_kernel ---
#   Max threads per block (kernel): 1024
#   Num registers: 40
#   Shared memory (bytes): 0
#   Const memory (bytes): 0
#   Local memory (bytes): 0
#
# --- Kernel: compute_costs ---
#   Max threads per block (kernel): 1024
#   Num registers: 37
#   Shared memory (bytes): 0
#   Const memory (bytes): 0
#   Local memory (bytes): 0
#
# --- Kernel: diversity_shortcut_kernel ---
#   Max threads per block (kernel): 1024
#   Num registers: 31
#   Shared memory (bytes): 0
#   Const memory (bytes): 0
#   Local memory (bytes): 0
# Status: Running: 4, Pending: 679, Completed: 151, Errored: 0

# %% [markdown]
# ## Post-Processing

# %%
# Load all completed runners for analysis
completed_runners = {}

for N_trees, seed in N_TREES_SEED_LIST:
    filename = f'ga_N{N_trees}_seed{seed}'
    pickle_path = kgs.temp_dir + CHECKPOINT_DIR + filename + '.pickle'
    
    if os.path.isfile(pickle_path):
        try:
            runner = kgs.dill_load(pickle_path)
            completed_runners[(N_trees, seed)] = runner
            print(f"Loaded N={N_trees}, seed={seed}: {runner._current_generation} generations")
        except Exception as e:
            print(f"Failed to load N={N_trees}, seed={seed}: {e}")

print(f"\nTotal loaded: {len(completed_runners)} runners")

# %%
# Extract best solutions
import pack_vis_sol

for (N_trees, seed), runner in completed_runners.items():
    best_costs = [[float(x) for x in s[-1].flatten()] 
                  for s in runner.ga.best_costs_per_generation]
    print(f"\nN={N_trees}, seed={seed}: Best costs = {best_costs}")
    
    # Visualize best solution
    # (Adjust based on your GA structure - GAMulti vs single GA)
    try:
        plt.figure()
        pack_vis_sol.pack_vis_sol(runner.ga.champions[-1].phenotype)
        plt.title(f"N={N_trees}, seed={seed}, Cost={runner.ga.champions[-1].fitness[0]}")
    except Exception as e:
        print(f"Could not visualize N={N_trees}, seed={seed}: {e}")
