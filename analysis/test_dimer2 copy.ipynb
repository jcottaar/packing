# %%
#%matplotlib widget
import sys
import os
sys.path.insert(0, os.path.join(os.getcwd(), '../core'))
import kaggle_support as kgs
import importlib
import pack_vis
import pack_dimer
import pack_vis_sol
import pack_cost
import pack_dynamics
import numpy as np
import matplotlib.pyplot as plt
import cupy as cp
import copy
kgs.set_float32(False)
# Out:
# local
# WARNING: CUDA MPS not active

# %%
def canonicize(sol):
    # Enforce angle <= 90 degrees
    if sol.h.shape[1]>=2:
        mask = sol.h[:, 2] > np.pi/2
        if cp.any(mask):
            sol.h[mask, 2] = np.pi - sol.h[mask, 2]
            sol.xyt[mask, :, 0] = -sol.xyt[mask, :, 0]
            sol.xyt[mask, :, 2] = -sol.xyt[mask, :, 2]

        sol.xyt[:,:,0] -= sol.xyt[:,0:1,0]
        sol.xyt[:,:,1] -= sol.xyt[:,0:1,1]

    # # shift tree 2 by the crystal axes such that it is just to the top right of tree 0
    # crystal_axes = sol.get_crystal_axes_allocate()
    # vec_a = crystal_axes[:,0,:2]
    # vec_b = crystal_axes[:,1,:2]
    # det = vec_a[:,0]*vec_b[:,1] - vec_a[:,1]*vec_b[:,0]
    # if cp.any(cp.abs(det) <= 1e-9):
    #     raise ValueError("Degenerate crystal axes detected")
    # pos_tree1 = sol.xyt[:,1,:2]
    # coeff_a = (vec_b[:,1]*pos_tree1[:,0] - vec_b[:,0]*pos_tree1[:,1]) / det
    # coeff_b = (-vec_a[:,1]*pos_tree1[:,0] + vec_a[:,0]*pos_tree1[:,1]) / det
    # coeff_a = cp.mod(coeff_a, 1.0)
    # coeff_b = cp.mod(coeff_b, 1.0)
    # pos_aligned = coeff_a[:,None]*vec_a + coeff_b[:,None]*vec_b
    # sol.xyt[:,1,:2] = pos_aligned

def find_optimal_tesselation(aspect_ratio, angle_degrees, N=20000, max_N =80000, check_val=10, show_plots=False):
    sol = kgs.SolutionCollectionLatticeFixed()
    sol.periodic = True
    sol.aspect_ratios = cp.array([aspect_ratio]*N, dtype=kgs.dtype_cp)
    sol.angles = cp.array([np.radians(angle_degrees)]*N, dtype=kgs.dtype_cp)
    sol = sol.create_empty(N, 2)
    sol.xyt[:,0,:2] = 0.
    generator = cp.random.default_rng(seed=42)
    sol.xyt[:,:,2] = generator.uniform(-np.pi/2, np.pi/2, size=(N,2), dtype=kgs.dtype_cp) # try to have tree 1 upright
    sol.xyt[:,1,2] = sol.xyt[:,0,2] + np.pi
    sol.xyt[:,1,:2] = generator.uniform(0, 2, size=(N,2), dtype=kgs.dtype_cp)
    sol.N_periodic = 4

    sol.h[:,0] = 1.
    sol.snap()

    sol_orig = copy.deepcopy(sol)    

    optimizer = pack_dynamics.OptimizerBFGS()
    optimizer.cost = pack_cost.CostCompound(costs = [pack_cost.AreaCost(scaling=1e-3), 
                            pack_cost.CollisionCostSeparation(scaling=1.)])
    optimizer.n_iterations *= 1
    sol = optimizer.run_simulation(sol)

    canonicize(sol)
    

    cost_vals = optimizer.cost.compute_cost_allocate(sol)[0].get()
    #plt.figure()
    #plt.semilogy(np.sort(cost_vals))

    inds = np.argsort(cost_vals)

    if not cost_vals[inds[check_val]]<=1.001*cost_vals[inds[0]] and 2*N<=max_N:
        #print('trying higher N')
        s = find_optimal_tesselation(aspect_ratio, angle_degrees, N=2*N)
        #print('ok now')
        return s
    
    
    sol.select_ids(inds[:1])
    sol_orig.select_ids(inds[:1])

    sol2 = kgs.SolutionCollectionLattice()
    sol2.periodic = True
    sol2.xyt = copy.deepcopy(sol.xyt)
    sol2.h = cp.zeros((sol.N_solutions, 3), dtype=kgs.dtype_cp)
    sol2.h[:,0] = sol.h[:,0]
    sol2.h[:,1] = sol.h[:,0] * sol.aspect_ratios        
    sol2.h[:,2] = sol._get_angles()

    optimizer = pack_dynamics.OptimizerBFGS()
    optimizer.cost = pack_cost.CostCompound(costs = [pack_cost.AreaCost(scaling=1e-3), 
                            pack_cost.CollisionCostSeparation(scaling=1.)])
    optimizer.max_step = 1e-2
    #optimizer.dt*=10
    optimizer.n_iterations *= 3
    optimizer.track_cost = show_plots
    optimizer.plot_cost = show_plots
    #optimizer.use_line_search = True
    #optimizer.plot_interval = optimizer.dt*10
    sol2 = optimizer.run_simulation(sol2)

    optimizer = pack_dynamics.OptimizerBFGS()
    optimizer.cost = pack_cost.CostCompound(costs = [pack_cost.AreaCost(scaling=1e-3), 
                            pack_cost.CollisionCostSeparation(scaling=1.)])
    optimizer.max_step = 1e-3
    #optimizer.dt*=10
    optimizer.n_iterations *= 3
    optimizer.track_cost = show_plots
    optimizer.plot_cost = show_plots
    #optimizer.use_line_search = True
    #optimizer.plot_interval = optimizer.dt*10
    sol2 = optimizer.run_simulation(sol2)
    canonicize(sol2)
    return sol, sol2, sol_orig

# %%
from tqdm.notebook import tqdm
aspect_ratios = np.linspace(0.35,0.65,31)
angles = np.linspace(60,90,31)
# sol_grid = [[None for _ in range(len(angles))] for _ in range(len(aspect_ratios))]
# sol_opt_grid = [[None for _ in range(len(angles))] for _ in range(len(aspect_ratios))]
# for ia, aspect_ratio in enumerate(tqdm(aspect_ratios, desc="Computing")):
#     for ib, angle in enumerate(tqdm(angles, desc="Angles", leave=False)):
#         sol, sol_opt, _ = find_optimal_tesselation(aspect_ratio, angle)
#         sol_grid[ia][ib] = sol
#         sol_opt_grid[ia][ib] = sol_opt
# kgs.dill_save(kgs.code_dir + '/../res/packings2.pickle', (sol_grid, sol_opt_grid))
sol_grid, sol_opt_grid = kgs.dill_load(kgs.code_dir + '/../res/packings2.pickle')

# %%
res1 = np.zeros((len(aspect_ratios), len(angles)))
res2 = np.zeros((len(aspect_ratios), len(angles)))
res3 = np.zeros((len(aspect_ratios), len(angles)))
res4 = np.zeros((len(aspect_ratios), len(angles)))
res_aspect_ratios = np.zeros((len(aspect_ratios), len(angles)))
res_angles = np.zeros((len(aspect_ratios), len(angles)))

for ia, aspect_ratio in enumerate(tqdm(aspect_ratios, desc="Recalculating")):
    for ib, angle in enumerate(angles):
        sol, sol_opt = sol_grid[ia][ib], sol_opt_grid[ia][ib]
        sol.xyt = sol.xyt.astype(kgs.dtype_cp)
        sol_opt.xyt = sol_opt.xyt.astype(kgs.dtype_cp)
        sol.h = sol.h.astype(kgs.dtype_cp)
        sol_opt.h = sol_opt.h.astype(kgs.dtype_cp)
        #canonicize(sol)
        canonicize(sol_opt)
        sol.N_periodic = 15
        sol_opt.N_periodic = 15
        res1[ia,ib] = pack_cost.AreaCost().compute_cost_allocate(sol)[0][0].get()
        res2[ia,ib] = pack_cost.AreaCost().compute_cost_allocate(sol_opt)[0][0].get()
        res3[ia,ib] = pack_cost.CollisionCostSeparation().compute_cost_allocate(sol)[0][0].get()
        res4[ia,ib] = pack_cost.CollisionCostSeparation().compute_cost_allocate(sol_opt)[0][0].get()
        res_angles[ia,ib] = np.degrees(sol_opt.h[0,2].get())
        res_aspect_ratios[ia,ib] = sol_opt.h[0,1].get() / sol_opt.h[0,0].get()

res1[res3>1e-3] = np.nan
res2[res4>1e-3] = np.nan
res_angles[res4>1e-3] = np.nan
res_aspect_ratios[res4>1e-3] = np.nan
# Out:
# Recalculating:   0%|          | 0/31 [00:00<?, ?it/s]
# init CUDA
# Detected GPU compute capability: 8.9 (arch=sm_89)
# GPU max threads per block: 1024
# === Compiling kernel variant: crystal ===
# Defines: ENABLE_CRYSTAL_AXES, ENABLE_OVERLAP_AREA, ENABLE_SEPARATION
# Command: /usr/local/cuda/bin/nvcc -O3 -use_fast_math --extra-device-vectorization --ptxas-options=-v,--warn-on-spills -arch=sm_89 -DENABLE_CRYSTAL_AXES -DENABLE_OVERLAP_AREA -DENABLE_SEPARATION -cubin /mnt/d//packing/temp/pack_cuda_saved.cu -o /mnt/d//packing/temp/pack_cuda_crystal.cubin
# ptxas info    : 144 bytes gmem, 2324 bytes cmem[3], 8 bytes cmem[4]
# ptxas info    : Compiling entry function 'multi_boundary_distance_list_total' for 'sm_89'
# ptxas info    : Function properties for multi_boundary_distance_list_total
#     88 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 38 registers, used 1 barriers, 88 bytes cumulative stack size, 404 bytes cmem[0], 120 bytes cmem[2]
# ptxas info    : Compile time = 31.614 ms
# ptxas info    : Function properties for __internal_trig_reduction_slowpathd
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Compiling entry function 'multi_boundary_list_total' for 'sm_89'
# ptxas info    : Function properties for multi_boundary_list_total
#     528 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 68 registers, used 1 barriers, 528 bytes cumulative stack size, 404 bytes cmem[0], 152 bytes cmem[2]
# ptxas info    : Compile time = 899.942 ms
# ptxas info    : Function properties for __internal_trig_reduction_slowpathd
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Compiling entry function 'multi_overlap_list_total' for 'sm_89'
# ptxas info    : Function properties for multi_overlap_list_total
#     2144 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 152 registers, used 1 barriers, 2144 bytes cumulative stack size, 424 bytes cmem[0], 136 bytes cmem[2]
# ptxas info    : Compile time = 601.081 ms
# ptxas info    : Function properties for __internal_trig_reduction_slowpathd
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
#
#
# --- Kernel: multi_overlap_list_total [crystal] ---
#   Max threads per block (kernel): 384
#   Num registers: 152
#   Shared memory (bytes): 0
#   Const memory (bytes): 2324
#   Local memory (bytes): 2144
# === Compiling kernel variant: no_sep ===
# Defines: ENABLE_OVERLAP_AREA
# Command: /usr/local/cuda/bin/nvcc -O3 -use_fast_math --extra-device-vectorization --ptxas-options=-v,--warn-on-spills -arch=sm_89 -DENABLE_OVERLAP_AREA -cubin /mnt/d//packing/temp/pack_cuda_saved.cu -o /mnt/d//packing/temp/pack_cuda_no_sep.cubin
# ptxas info    : 144 bytes gmem, 2324 bytes cmem[3], 8 bytes cmem[4]
# ptxas info    : Compiling entry function 'multi_boundary_distance_list_total' for 'sm_89'
# ptxas info    : Function properties for multi_boundary_distance_list_total
#     88 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 38 registers, used 1 barriers, 88 bytes cumulative stack size, 404 bytes cmem[0], 120 bytes cmem[2]
# ptxas info    : Compile time = 14.669 ms
# ptxas info    : Function properties for __internal_trig_reduction_slowpathd
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Compiling entry function 'multi_boundary_list_total' for 'sm_89'
# ptxas info    : Function properties for multi_boundary_list_total
#     528 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 68 registers, used 1 barriers, 528 bytes cumulative stack size, 404 bytes cmem[0], 152 bytes cmem[2]
# ptxas info    : Compile time = 891.939 ms
# ptxas info    : Function properties for __internal_trig_reduction_slowpathd
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Compiling entry function 'multi_overlap_list_total' for 'sm_89'
# ptxas info    : Function properties for multi_overlap_list_total
#     2080 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 126 registers, used 1 barriers, 2080 bytes cumulative stack size, 424 bytes cmem[0], 136 bytes cmem[2]
# ptxas info    : Compile time = 117.575 ms
# ptxas info    : Function properties for __internal_trig_reduction_slowpathd
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
#
#
# --- Kernel: multi_overlap_list_total [no_sep] ---
#   Max threads per block (kernel): 512
#   Num registers: 126
#   Shared memory (bytes): 0
#   Const memory (bytes): 2324
#   Local memory (bytes): 2080
# === Compiling kernel variant: sep ===
# Defines: ENABLE_SEPARATION
# Command: /usr/local/cuda/bin/nvcc -O3 -use_fast_math --extra-device-vectorization --ptxas-options=-v,--warn-on-spills -arch=sm_89 -DENABLE_SEPARATION -cubin /mnt/d//packing/temp/pack_cuda_saved.cu -o /mnt/d//packing/temp/pack_cuda_sep.cubin
# ptxas info    : 144 bytes gmem, 2324 bytes cmem[3], 8 bytes cmem[4]
# ptxas info    : Compiling entry function 'multi_boundary_distance_list_total' for 'sm_89'
# ptxas info    : Function properties for multi_boundary_distance_list_total
#     88 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 38 registers, used 1 barriers, 88 bytes cumulative stack size, 404 bytes cmem[0], 120 bytes cmem[2]
# ptxas info    : Compile time = 14.616 ms
# ptxas info    : Function properties for __internal_trig_reduction_slowpathd
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Compiling entry function 'multi_boundary_list_total' for 'sm_89'
# ptxas info    : Function properties for multi_boundary_list_total
#     528 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 68 registers, used 1 barriers, 528 bytes cumulative stack size, 404 bytes cmem[0], 152 bytes cmem[2]
# ptxas info    : Compile time = 866.950 ms
# ptxas info    : Function properties for __internal_trig_reduction_slowpathd
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Compiling entry function 'multi_overlap_list_total' for 'sm_89'
# ptxas info    : Function properties for multi_overlap_list_total
#     336 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 92 registers, used 1 barriers, 336 bytes cumulative stack size, 424 bytes cmem[0], 144 bytes cmem[2]
# ptxas info    : Compile time = 121.034 ms
# ptxas info    : Function properties for __internal_trig_reduction_slowpathd
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
#
#
# --- Kernel: multi_overlap_list_total [sep] ---
#   Max threads per block (kernel): 640
#   Num registers: 92
#   Shared memory (bytes): 0
#   Const memory (bytes): 2324
#   Local memory (bytes): 336
#
# --- Kernel: multi_boundary_list_total ---
#   Max threads per block (kernel): 896
#   Num registers: 68
#   Shared memory (bytes): 0
#   Const memory (bytes): 2324
#   Local memory (bytes): 528
#
# --- Kernel: multi_boundary_distance_list_total ---
#   Max threads per block (kernel): 1024
#   Num registers: 38
#   Shared memory (bytes): 0
#   Const memory (bytes): 2324
#   Local memory (bytes): 88

# %%
# make a function to plot heatmaps of res1 or res2, with proper axis labels
def plot_heatmaps(res, aspect_ratios, angles, title="Cost Heatmap", cbar_label="Area Cost", clim=None):
    aspect_ratios = np.asarray(aspect_ratios)
    angles = np.asarray(angles)
    if res.shape != (len(aspect_ratios), len(angles)):
        raise ValueError("res must have shape (len(aspect_ratios), len(angles))")

    fig, ax = plt.subplots(figsize=(6, 4))
    extent = [angles.min(), angles.max(), aspect_ratios.min(), aspect_ratios.max()]
    im = ax.imshow(res, origin='lower', extent=extent, aspect='auto', cmap='viridis', interpolation='none')

    if clim is not None:
        im.set_clim(*clim)

    ax.set_xlabel("Angle (degrees)")
    ax.set_ylabel("Aspect ratio (b/a)")
    ax.set_title(title)

    # Use at most ~8 tick labels to avoid clutter
    max_ticks = 8
    x_ticks = np.linspace(angles.min(), angles.max(), min(len(angles), max_ticks))
    y_ticks = np.linspace(aspect_ratios.min(), aspect_ratios.max(), min(len(aspect_ratios), max_ticks))
    ax.set_xticks(x_ticks)
    ax.set_yticks(y_ticks)

    cbar = fig.colorbar(im, ax=ax)
    cbar.set_label(cbar_label)

    plt.show()
    return fig, ax

# %%
def plot_cost_curves(res1, res2, aspect_ratios, angles, fixed_angle=90.0, title="Cost vs Aspect ratio"):
    aspect_ratios = np.asarray(aspect_ratios)
    angles = np.asarray(angles)
    expected_shape = (len(aspect_ratios), len(angles))
    if res1.shape != expected_shape or res2.shape != expected_shape:
        raise ValueError("res1/res2 must have shape (len(aspect_ratios), len(angles))")

    angle_idx = int(np.argmin(np.abs(angles - fixed_angle)))
    chosen_angle = angles[angle_idx]
    if not np.isclose(chosen_angle, fixed_angle):
        print(f"Using closest available angle: {chosen_angle:.3f} deg")

    fig, ax = plt.subplots(figsize=(6, 4))
    ax.plot(aspect_ratios, res1[:, angle_idx], label="Initial lattice", marker="o")
    ax.plot(aspect_ratios, res2[:, angle_idx], label="Optimized lattice", marker="s")
    ax.set_xlabel("Aspect ratio (b/a)")
    ax.set_ylabel("Area cost")
    ax.set_title(f"{title} (angle={chosen_angle:.1f} deg)")
    ax.grid(True, alpha=0.3)
    ax.legend()
    plt.show()
    return fig, ax

# %%
plot_cost_curves(res1, res2, aspect_ratios, angles, fixed_angle=90.0)
# Out:
# (<Figure size 600x400 with 1 Axes>,
#  <Axes: title={'center': 'Cost vs Aspect ratio (angle=90.0 deg)'}, xlabel='Aspect ratio (b/a)', ylabel='Area cost'>)

# %%
plot_heatmaps(res1, aspect_ratios, angles, title="Constrained Lattice Area Cost", cbar_label="Area Cost", clim=[0.605, 0.655])
plot_heatmaps(res2, aspect_ratios, angles, title="Optimized Lattice Area Cost", cbar_label="Area Cost", clim=[0.605, 0.635])
plot_heatmaps(res_aspect_ratios, aspect_ratios, angles, title="Optimized Lattice Aspect Ratio", cbar_label="Aspect Ratio (b/a)")
plot_heatmaps(90-np.abs(90-res_angles), aspect_ratios, angles, title="Optimized Lattice Angle", cbar_label="Angle (degrees)")
# Out:
# (<Figure size 600x400 with 2 Axes>,
#  <Axes: title={'center': 'Optimized Lattice Angle'}, xlabel='Angle (degrees)', ylabel='Aspect ratio (b/a)'>)

# %%
def plot_optimization_flow(res_cost, res_ar_opt, res_ang_opt, aspect_ratios, angles, title="Optimization Flow", clim=None):
    fig, ax = plt.subplots(figsize=(25, 16))
    
    # Plot heatmap
    extent = [angles.min(), angles.max(), aspect_ratios.min(), aspect_ratios.max()]
    im = ax.imshow(res_cost, origin='lower', extent=extent, aspect='auto', cmap='viridis', interpolation='none')
    
    if clim is not None:
        im.set_clim(*clim)

    cbar = fig.colorbar(im, ax=ax)
    cbar.set_label("Optimized Area Cost")
    
    # Plot lines with dots at start
    stride_a = 1
    stride_b = 1
    
    lines_x = []
    lines_y = []
    starts_x = []
    starts_y = []
    
    for ia in range(0, len(aspect_ratios), stride_a):
        for ib in range(0, len(angles), stride_b):
            start_ar = aspect_ratios[ia]
            start_ang = angles[ib]
            
            end_ar = res_ar_opt[ia, ib]
            end_ang = res_ang_opt[ia, ib]
            
            if np.isnan(end_ar) or np.isnan(end_ang):
                continue
            
            # Only draw if there is a visible change
            if abs(end_ar - start_ar) < 1e-3 and abs(end_ang - start_ang) < 1e-3:
                continue

            # Collect line segments
            lines_x.extend([start_ang, end_ang, None])
            lines_y.extend([start_ar, end_ar, None])
            
            # Collect start points for dots
            starts_x.append(end_ang)
            starts_y.append(end_ar)

    # Plot all lines at once
    ax.plot(lines_x, lines_y, color="red", lw=1.0, alpha=0.6)
    # Plot all start dots at once
    ax.scatter(starts_x, starts_y, color="red", s=10, alpha=0.6, zorder=3)
                        
    ax.set_xlabel("Angle (degrees)")
    ax.set_ylabel("Aspect ratio (b/a)")
    ax.set_title(title)
    
    #ax.set_xlim(angles.min(), angles.max())
    #ax.set_ylim(aspect_ratios.min(), aspect_ratios.max())
    
    plt.show()

plot_optimization_flow(res2, res_aspect_ratios, res_angles, aspect_ratios, angles, title="Optimized Lattice Area Cost with Optimization Flow", clim=[0.605, 0.635])

# %%
# def do_one(ia,ib, ref_h=None):
#     sol_opt1 = copy.deepcopy(sol_opt_grid[ia][ib])
#     canonicize(sol_opt1)
#     pack_vis_sol.pack_vis_sol(sol_opt1)
#     # recompute cost, AR, angle in place, using earlier rules
#     sol_opt1.N_periodic = 15
#     res2[ia,ib] = pack_cost.AreaCost().compute_cost_allocate(sol_opt1)[0][0].get()
#     res_angles[ia,ib] = np.degrees(sol_opt1.h[0,2].get())
#     res_aspect_ratios[ia,ib] = sol_opt1.h[0,1].get() / sol_opt1.h[0,0].get()

#     plt.title(f'Cost={res2[ia][ib]:.6f}, AR={res_aspect_ratios[ia][ib]:.4f}, Angle={res_angles[ia][ib]:.2f}°')
    
#     #if not ref_h is None:
#     sol_opt1=copy.deepcopy(sol_opt1)
#     #sol_opt1.h = copy.deepcopy(ref_h)
#     optimizer = pack_dynamics.OptimizerBFGS()
#     optimizer.cost = pack_cost.CostCompound(costs = [pack_cost.AreaCost(scaling=1e-3), 
#                             pack_cost.CollisionCostSeparation(scaling=1.)])
#     optimizer.max_step = 1e-4
#     #optimizer.dt*=10
#     optimizer.n_iterations *= 30
#     optimizer.track_cost = True
#     optimizer.plot_cost = True
#     #optimizer.use_line_search = True
#     #optimizer.plot_interval = optimizer.dt*10
#     solx = optimizer.run_simulation(sol_opt1)

#     pack_vis_sol.pack_vis_sol(solx)
#     # recompute cost, AR, angle in place, using earlier rules
#     solx.N_periodic = 15
#     res2[ia,ib] = pack_cost.AreaCost().compute_cost_allocate(solx)[0][0].get()
#     res_angles[ia,ib] = np.degrees(solx.h[0,2].get())
#     res_aspect_ratios[ia,ib] = solx.h[0,1].get() / solx.h[0,0].get()

#     plt.title(f'Reoptimized, Cost={res2[ia][ib]:.6f}, AR={res_aspect_ratios[ia][ib]:.4f}, Angle={res_angles[ia][ib]:.2f}°')
# do_one(-1,-1, ref_h = sol_opt_grid[-1][-2].h)
# do_one(-1,-2, ref_h = sol_opt_grid[-1][-2].h)

# %%
# Create a single solution object of all sol_opt. solutions that are within a tolerance aspect_ratio and angle of each other should be considered the same, with only one kept
all_sols = []
for ia in range(len(aspect_ratios)):
    for ib in range(len(angles)):
        if not np.isnan(res2[ia,ib]) and res2[ia,ib]<0.635:
            all_sols.append(sol_opt_grid[ia][ib])

# Combine all solutions into one large collection
combined_sol = all_sols[0].create_empty(0, all_sols[0].N_trees)
for s in all_sols:
    combined_sol.merge(s)
# Extract parameters for filtering
ar = combined_sol.h[:,1] / combined_sol.h[:,0]
ang = np.degrees(combined_sol.h[:,2])
cost = pack_cost.AreaCost().compute_cost_allocate(combined_sol)[0]

# Filter duplicates
tol_ar = 1e-3
tol_ang = 0.5 # degrees
tol_cost = 1e-5

keep_mask = cp.ones(combined_sol.N_solutions, dtype=bool)
# Sort by cost so we keep the best ones
sort_idx = cp.argsort(cost)

unique_indices = []

for i in range(combined_sol.N_solutions):
    idx = sort_idx[i]
    if not keep_mask[idx]:
        continue
    
    unique_indices.append(idx)
    
    # Find duplicates
    diff_ar = cp.abs(ar - ar[idx])
    diff_ang = cp.abs(ang - ang[idx])
    diff_cost = cp.abs(cost - cost[idx])
    
    is_duplicate = (diff_ar < tol_ar) & (diff_ang < tol_ang) & (diff_cost < tol_cost)
    keep_mask[is_duplicate] = False # Mark duplicates as removed (including self, but self is already added)

unique_indices = cp.array(unique_indices)
combined_sol.select_ids(unique_indices)

print(f"Reduced from {len(all_sols)} to {combined_sol.N_solutions} unique solutions")

# Visualize the unique solutions on the AR/Angle plane
plt.figure(figsize=(10, 6))
plt.scatter(np.degrees(combined_sol.h[:,2].get()), (combined_sol.h[:,1]/combined_sol.h[:,0]).get(), c=pack_cost.AreaCost().compute_cost_allocate(combined_sol)[0].get(), cmap='viridis')
plt.colorbar(label='Area Cost')
plt.xlabel('Angle (degrees)')
plt.ylabel('Aspect Ratio')
plt.title('Unique Optimized Solutions')
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Reduced from 958 to 221 unique solutions

# %%
def reoptimize(sol, show_plots= False, NN=3):
    optimizer = pack_dynamics.OptimizerBFGS()
    optimizer.cost = pack_cost.CostCompound(costs = [pack_cost.AreaCost(scaling=1e-3), 
                            pack_cost.CollisionCostSeparation(scaling=1.)])
    optimizer.max_step = 1e-3
    optimizer.n_iterations *= NN
    optimizer.track_cost = show_plots
    optimizer.plot_cost = show_plots
    optimizer.history_size = 20
    sol = optimizer.run_simulation(sol)

    optimizer = pack_dynamics.OptimizerBFGS()
    optimizer.cost = pack_cost.CostCompound(costs = [pack_cost.AreaCost(scaling=1e-3), 
                            pack_cost.CollisionCostSeparation(scaling=1.)])
    optimizer.max_step = 1e-3/np.sqrt(10)
    optimizer.n_iterations *= NN
    optimizer.track_cost = show_plots
    optimizer.plot_cost = show_plots
    sol = optimizer.run_simulation(sol)

    # optimizer = pack_dynamics.OptimizerBFGS()
    # optimizer.cost = pack_cost.CostCompound(costs = [pack_cost.AreaCost(scaling=1e-3), 
    #                         pack_cost.CollisionCostSeparation(scaling=1.)])
    # optimizer.max_step = 1e-4
    # optimizer.n_iterations *= NN
    # optimizer.track_cost = show_plots
    # optimizer.plot_cost = show_plots
    # sol = optimizer.run_simulation(sol)

    # optimizer = pack_dynamics.OptimizerBFGS()
    # optimizer.cost = pack_cost.CostCompound(costs = [pack_cost.AreaCost(scaling=1e-3), 
    #                         pack_cost.CollisionCostSeparation(scaling=1.)])
    # optimizer.max_step = 1e-4/np.sqrt(10)
    # optimizer.n_iterations *= NN
    # optimizer.track_cost = show_plots
    # optimizer.plot_cost = show_plots
    # sol = optimizer.run_simulation(sol)

    # optimizer = pack_dynamics.OptimizerBFGS()
    # optimizer.cost = pack_cost.CostCompound(costs = [pack_cost.AreaCost(scaling=1e-3), 
    #                         pack_cost.CollisionCostSeparation(scaling=1.)])
    # optimizer.max_step = 1e-5
    # optimizer.n_iterations *= NN
    # optimizer.track_cost = show_plots
    # optimizer.plot_cost = show_plots
    # sol = optimizer.run_simulation(sol)
    return sol
sol_reoptimized = reoptimize(copy.deepcopy(combined_sol), show_plots=True, NN=25)

cost1 = pack_cost.AreaCost().compute_cost_allocate(combined_sol)[0].get()
cost2 = pack_cost.AreaCost().compute_cost_allocate(sol_reoptimized)[0].get()
plt.figure()
plt.scatter(cost1,cost2)

# Visualize the unique solutions on the AR/Angle plane
plt.figure(figsize=(10, 6))
plt.scatter(np.degrees(sol_reoptimized.h[:,2].get()), (sol_reoptimized.h[:,1]/sol_reoptimized.h[:,0]).get(), c=pack_cost.AreaCost().compute_cost_allocate(sol_reoptimized)[0].get(), cmap='viridis')
plt.colorbar(label='Area Cost')
plt.xlabel('Angle (degrees)')
plt.ylabel('Aspect Ratio')
plt.title('Unique Optimized Solutions')
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# /mnt/d/packing/code/analysis/../core/pack_dynamics.py:60: VisibleDeprecationWarning: This function is deprecated and will be removed in a future release. Use the cupy.from_dlpack() array constructor instead.
#   x0 = from_dlpack(x0.toDlpack())
# /mnt/d/packing/code/analysis/../core/pack_dynamics.py:92: VisibleDeprecationWarning: This function is deprecated and will be removed in a future release. Use the cupy.from_dlpack() array constructor instead.
#   return from_dlpack(tmp_cost[:N].toDlpack()), from_dlpack(res.toDlpack())

# %%
ar = sol_reoptimized.h[:,1] / sol_reoptimized.h[:,0]
ang = np.degrees(sol_reoptimized.h[:,2])
cost = pack_cost.AreaCost().compute_cost_allocate(sol_reoptimized)[0]

keep_mask = cp.ones(sol_reoptimized.N_solutions, dtype=bool)
# Sort by cost so we keep the best ones
sort_idx = cp.argsort(cost)

unique_indices = []

for i in range(sol_reoptimized.N_solutions):
    idx = sort_idx[i]
    if not keep_mask[idx]:
        continue
    
    unique_indices.append(idx)
    
    # Find duplicates
    diff_ar = cp.abs(ar - ar[idx])
    diff_ang = cp.abs(ang - ang[idx])
    diff_cost = cp.abs(cost - cost[idx])
    
    is_duplicate = (diff_ar < tol_ar) & (diff_ang < tol_ang) & (diff_cost < tol_cost)
    keep_mask[is_duplicate] = False # Mark duplicates as removed (including self, but self is already added)

unique_indices = cp.array(unique_indices)
sol_reoptimized.select_ids(unique_indices)

print(f"Reduced from {len(all_sols)} to {sol_reoptimized.N_solutions} unique solutions")

# Visualize the unique solutions on the AR/Angle plane
plt.figure(figsize=(10, 6))
plt.scatter(np.degrees(sol_reoptimized.h[:,2].get()), (sol_reoptimized.h[:,1]/sol_reoptimized.h[:,0]).get(), c=pack_cost.AreaCost().compute_cost_allocate(sol_reoptimized)[0].get(), cmap='viridis')
plt.colorbar(label='Area Cost')
plt.xlabel('Angle (degrees)')
plt.ylabel('Aspect Ratio')
plt.title('Unique Optimized Solutions')
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Reduced from 958 to 53 unique solutions

# %%
plt.figure()
plt.plot(pack_cost.CollisionCostSeparation().compute_cost_allocate(sol_reoptimized)[0].get())

# %%
sol_fixed = kgs.SolutionCollectionLatticeFixed()
sol_fixed.periodic = True
sol_fixed.xyt = copy.deepcopy(sol_reoptimized.xyt)
# fill in h, aspect_ratios, angles
sol_fixed.h = sol_reoptimized.h[:,0:1].copy()  # (N_solutions, 1) - just a_length
sol_fixed.aspect_ratios = (sol_reoptimized.h[:,1] / sol_reoptimized.h[:,0]).copy()  # (N_solutions,)
sol_fixed.angles = sol_reoptimized.h[:,2].copy()  # (N_solutions,)

# Create one big NxN solution combining all aspect_ratio/angle parameters with all xyt configurations
N = sol_fixed.N_solutions
big_sol = sol_fixed.create_empty(N*N, sol_fixed.N_trees)

for i in range(N):
    for j in range(N):
        idx = i*N + j
        # Use aspect_ratio and angle from solution i, xyt from solution j
        big_sol.xyt[idx] = sol_fixed.xyt[j]
        big_sol.h[idx, 0] = sol_fixed.h[i, 0]
        big_sol.aspect_ratios[idx] = sol_fixed.aspect_ratios[i]
        big_sol.angles[idx] = sol_fixed.angles[i]

big_sol.check_constraints()
big_sol = reoptimize(big_sol, show_plots=True, NN=60)

# Extract costs and reshape into matrix
costs = pack_cost.AreaCost().compute_cost_allocate(big_sol)[0].get()
cost_mat = costs.reshape((N, N))

# %%
plt.figure()
plt.imshow(cost_mat)
plt.clim(0.605, 0.635)
plt.colorbar()
plt.figure()
plt.imshow(cost_mat/cost_mat.diagonal()[:,None])
plt.clim(1.,1.001)
plt.colorbar()

domination_matrix = cost_mat/cost_mat.diagonal()[:,None]<1.001
domination_matrix = domination_matrix - np.eye(domination_matrix.shape[0])

# Visualize the unique solutions on the AR/Angle plane
fig, ax = plt.subplots(figsize=(20, 12))
angles_deg = np.degrees(sol_reoptimized.h[:,2].get())
aspect_ratios = (sol_reoptimized.h[:,1]/sol_reoptimized.h[:,0]).get()
costs = pack_cost.AreaCost().compute_cost_allocate(sol_reoptimized)[0].get()

sc = ax.scatter(angles_deg, aspect_ratios, c=costs, cmap='viridis', zorder=2)
plt.colorbar(sc, label='Area Cost')

# Add arrows for domination
# domination_matrix[i,j] is true if i dominates j. So arrow from j to i.
for i in range(domination_matrix.shape[0]):
    for j in range(domination_matrix.shape[1]):
        if domination_matrix[j, i]:
            ax.annotate("",
                        xy=(angles_deg[i], aspect_ratios[i]),
                        xytext=(angles_deg[j], aspect_ratios[j]),
                        arrowprops=dict(arrowstyle="->", color='red', alpha=0.3, lw=1.5))

ax.set_xlabel('Angle (degrees)')
ax.set_ylabel('Aspect Ratio')
ax.set_title('Unique Optimized Solutions with Domination Arrows')
ax.grid(True, alpha=0.3)
plt.show()

# %%
plt.figure()
plt.plot(pack_cost.AreaCost().compute_cost_allocate(sol_fixed)[0].get())
plt.plot(cost_mat.diagonal())

# %%
sol_reduced = copy.deepcopy(sol_fixed)

domination_matrix = cost_mat/cost_mat.diagonal()[:,None]<1.001
domination_matrix = domination_matrix - np.eye(domination_matrix.shape[0])

plt.figure()
plt.imshow(domination_matrix)
plt.title(np.sum(domination_matrix))

plt.figure()
plt.imshow(domination_matrix[[0,16,42],:][:,[0,16,42]])
plt.title(np.sum(domination_matrix))

# Check for transitivity
domination_matrix_bool = ((domination_matrix.T + np.eye(domination_matrix.shape[0])).astype(bool))
D2 = domination_matrix_bool @ domination_matrix_bool

# A violation of transitivity occurs if there is a path of length 2 (A->B->C)
# but no direct path (A->C).
violations = D2 & ~domination_matrix_bool

num_violations = np.sum(violations)
if num_violations == 0:
    print("The domination_matrix is transitive.")
else:
    print(f"Found {num_violations} violations of transitivity.")
    violation_indices = np.argwhere(violations)
    print("Violations (A -> C -> B, but not A -> B):")
    for A, B in violation_indices:
        # Find all intermediate nodes C
        intermediate_nodes_C = np.where(domination_matrix_bool[A, :] & domination_matrix_bool[:, B])[0]
        for C in intermediate_nodes_C:
            print(f"  {A} -> {C} -> {B}")


while np.any(domination_matrix):
    to_remove = np.argmax(np.sum(domination_matrix,0))
    #print(to_remove)
    domination_matrix = np.delete(domination_matrix, to_remove, 0) 
    domination_matrix = np.delete(domination_matrix, to_remove, 1) 
    inds = np.arange(sol_reduced.N_solutions)
    inds = np.delete(inds, to_remove)
    sol_reduced.select_ids(inds)


# Visualize the unique solutions on the AR/Angle plane
plt.figure(figsize=(10, 6))
plt.scatter(np.degrees(sol_reduced.angles.get()), sol_reduced.aspect_ratios.get(), c=pack_cost.AreaCost().compute_cost_allocate(sol_reduced)[0].get(), cmap='viridis')
plt.colorbar(label='Area Cost')
plt.xlabel('Angle (degrees)')
plt.ylabel('Aspect Ratio')
plt.title('Unique Optimized Solutions')
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Found 162 violations of transitivity.
# Violations (A -> C -> B, but not A -> B):
#   0 -> 16 -> 42
#   0 -> 16 -> 43
#   0 -> 49 -> 46
#   0 -> 51 -> 46
#   2 -> 16 -> 42
#   2 -> 16 -> 43
#   2 -> 49 -> 46
#   2 -> 51 -> 46
#   4 -> 16 -> 42
#   4 -> 16 -> 43
#   4 -> 49 -> 46
#   4 -> 51 -> 46
#   7 -> 16 -> 42
#   7 -> 16 -> 43
#   7 -> 49 -> 46
#   7 -> 51 -> 46
#   10 -> 16 -> 42
#   10 -> 16 -> 43
#   10 -> 49 -> 46
#   10 -> 51 -> 46
#   12 -> 16 -> 42
#   12 -> 16 -> 43
#   12 -> 49 -> 46
#   12 -> 51 -> 46
#   14 -> 16 -> 42
#   14 -> 16 -> 43
#   14 -> 49 -> 46
#   14 -> 51 -> 46
#   15 -> 1 -> 38
#   15 -> 3 -> 38
#   15 -> 6 -> 38
#   15 -> 8 -> 38
#   15 -> 9 -> 38
#   15 -> 11 -> 38
#   15 -> 13 -> 38
#   15 -> 17 -> 38
#   15 -> 19 -> 38
#   15 -> 20 -> 38
#   15 -> 40 -> 38
#   15 -> 41 -> 38
#   15 -> 44 -> 38
#   15 -> 45 -> 38
#   16 -> 0 -> 49
#   16 -> 2 -> 49
#   16 -> 4 -> 49
#   16 -> 7 -> 49
#   16 -> 10 -> 49
#   16 -> 12 -> 49
#   16 -> 14 -> 49
#   16 -> 21 -> 49
#   16 -> 0 -> 51
#   16 -> 2 -> 51
#   16 -> 4 -> 51
#   16 -> 7 -> 51
#   16 -> 10 -> 51
#   16 -> 12 -> 51
#   16 -> 14 -> 51
#   16 -> 21 -> 51
#   16 -> 22 -> 51
#   18 -> 16 -> 42
#   18 -> 16 -> 43
#   18 -> 0 -> 49
#   18 -> 2 -> 49
#   18 -> 4 -> 49
#   18 -> 7 -> 49
#   18 -> 10 -> 49
#   18 -> 12 -> 49
#   18 -> 14 -> 49
#   18 -> 21 -> 49
#   18 -> 0 -> 51
#   18 -> 2 -> 51
#   18 -> 4 -> 51
#   18 -> 7 -> 51
#   18 -> 10 -> 51
#   18 -> 12 -> 51
#   18 -> 14 -> 51
#   18 -> 21 -> 51
#   18 -> 22 -> 51
#   21 -> 16 -> 42
#   21 -> 16 -> 43
#   21 -> 49 -> 46
#   21 -> 51 -> 46
#   22 -> 16 -> 42
#   22 -> 16 -> 43
#   22 -> 51 -> 46
#   22 -> 0 -> 49
#   22 -> 2 -> 49
#   22 -> 4 -> 49
#   22 -> 7 -> 49
#   22 -> 10 -> 49
#   22 -> 12 -> 49
#   22 -> 14 -> 49
#   22 -> 21 -> 49
#   22 -> 51 -> 49
#   23 -> 1 -> 38
#   23 -> 3 -> 38
#   23 -> 6 -> 38
#   23 -> 8 -> 38
#   23 -> 9 -> 38
#   23 -> 11 -> 38
#   23 -> 13 -> 38
#   23 -> 17 -> 38
#   23 -> 19 -> 38
#   23 -> 20 -> 38
#   23 -> 1 -> 40
#   23 -> 3 -> 40
#   23 -> 6 -> 40
#   23 -> 8 -> 40
#   23 -> 9 -> 40
#   23 -> 11 -> 40
#   23 -> 13 -> 40
#   23 -> 15 -> 40
#   23 -> 17 -> 40
#   23 -> 19 -> 40
#   23 -> 20 -> 40
#   23 -> 1 -> 41
#   23 -> 3 -> 41
#   23 -> 6 -> 41
#   23 -> 8 -> 41
#   23 -> 9 -> 41
#   23 -> 11 -> 41
#   23 -> 13 -> 41
#   23 -> 15 -> 41
#   23 -> 17 -> 41
#   23 -> 19 -> 41
#   23 -> 20 -> 41
#   23 -> 1 -> 44
#   23 -> 3 -> 44
#   23 -> 6 -> 44
#   23 -> 8 -> 44
#   23 -> 9 -> 44
#   23 -> 11 -> 44
#   23 -> 13 -> 44
#   23 -> 15 -> 44
#   23 -> 17 -> 44
#   23 -> 19 -> 44
#   23 -> 20 -> 44
#   23 -> 1 -> 45
#   23 -> 3 -> 45
#   23 -> 6 -> 45
#   23 -> 8 -> 45
#   23 -> 9 -> 45
#   23 -> 11 -> 45
#   23 -> 13 -> 45
#   23 -> 15 -> 45
#   23 -> 17 -> 45
#   23 -> 19 -> 45
#   23 -> 20 -> 45
#   24 -> 1 -> 38
#   24 -> 3 -> 38
#   24 -> 6 -> 38
#   24 -> 8 -> 38
#   24 -> 9 -> 38
#   24 -> 11 -> 38
#   24 -> 13 -> 38
#   24 -> 17 -> 38
#   24 -> 19 -> 38
#   24 -> 20 -> 38
#   24 -> 1 -> 40
#   24 -> 3 -> 40
#   24 -> 6 -> 40
#   24 -> 8 -> 40
#   24 -> 9 -> 40
#   24 -> 11 -> 40
#   24 -> 13 -> 40
#   24 -> 15 -> 40
#   24 -> 17 -> 40
#   24 -> 19 -> 40
#   24 -> 20 -> 40
#   24 -> 1 -> 41
#   24 -> 3 -> 41
#   24 -> 6 -> 41
#   24 -> 8 -> 41
#   24 -> 9 -> 41
#   24 -> 11 -> 41
#   24 -> 13 -> 41
#   24 -> 15 -> 41
#   24 -> 17 -> 41
#   24 -> 19 -> 41
#   24 -> 20 -> 41
#   24 -> 1 -> 44
#   24 -> 3 -> 44
#   24 -> 6 -> 44
#   24 -> 8 -> 44
#   24 -> 9 -> 44
#   24 -> 11 -> 44
#   24 -> 13 -> 44
#   24 -> 15 -> 44
#   24 -> 17 -> 44
#   24 -> 19 -> 44
#   24 -> 20 -> 44
#   24 -> 1 -> 45
#   24 -> 3 -> 45
#   24 -> 6 -> 45
#   24 -> 8 -> 45
#   24 -> 9 -> 45
#   24 -> 11 -> 45
#   24 -> 13 -> 45
#   24 -> 15 -> 45
#   24 -> 17 -> 45
#   24 -> 19 -> 45
#   24 -> 20 -> 45
#   25 -> 16 -> 42
#   25 -> 16 -> 43
#   25 -> 0 -> 49
#   25 -> 2 -> 49
#   25 -> 4 -> 49
#   25 -> 7 -> 49
#   25 -> 10 -> 49
#   25 -> 12 -> 49
#   25 -> 14 -> 49
#   25 -> 21 -> 49
#   25 -> 0 -> 51
#   25 -> 2 -> 51
#   25 -> 4 -> 51
#   25 -> 7 -> 51
#   25 -> 10 -> 51
#   25 -> 12 -> 51
#   25 -> 14 -> 51
#   25 -> 21 -> 51
#   25 -> 22 -> 51
#   26 -> 1 -> 38
#   26 -> 3 -> 38
#   26 -> 6 -> 38
#   26 -> 8 -> 38
#   26 -> 9 -> 38
#   26 -> 11 -> 38
#   26 -> 13 -> 38
#   26 -> 17 -> 38
#   26 -> 19 -> 38
#   26 -> 20 -> 38
#   26 -> 1 -> 40
#   26 -> 3 -> 40
#   26 -> 6 -> 40
#   26 -> 8 -> 40
#   26 -> 9 -> 40
#   26 -> 11 -> 40
#   26 -> 13 -> 40
#   26 -> 15 -> 40
#   26 -> 17 -> 40
#   26 -> 19 -> 40
#   26 -> 20 -> 40
#   26 -> 1 -> 41
#   26 -> 3 -> 41
#   26 -> 6 -> 41
#   26 -> 8 -> 41
#   26 -> 9 -> 41
#   26 -> 11 -> 41
#   26 -> 13 -> 41
#   26 -> 15 -> 41
#   26 -> 17 -> 41
#   26 -> 19 -> 41
#   26 -> 20 -> 41
#   26 -> 1 -> 44
#   26 -> 3 -> 44
#   26 -> 6 -> 44
#   26 -> 8 -> 44
#   26 -> 9 -> 44
#   26 -> 11 -> 44
#   26 -> 13 -> 44
#   26 -> 15 -> 44
#   26 -> 17 -> 44
#   26 -> 19 -> 44
#   26 -> 20 -> 44
#   26 -> 1 -> 45
#   26 -> 3 -> 45
#   26 -> 6 -> 45
#   26 -> 8 -> 45
#   26 -> 9 -> 45
#   26 -> 11 -> 45
#   26 -> 13 -> 45
#   26 -> 15 -> 45
#   26 -> 17 -> 45
#   26 -> 19 -> 45
#   26 -> 20 -> 45
#   27 -> 1 -> 38
#   27 -> 3 -> 38
#   27 -> 6 -> 38
#   27 -> 8 -> 38
#   27 -> 9 -> 38
#   27 -> 11 -> 38
#   27 -> 13 -> 38
#   27 -> 17 -> 38
#   27 -> 19 -> 38
#   27 -> 20 -> 38
#   27 -> 1 -> 40
#   27 -> 3 -> 40
#   27 -> 6 -> 40
#   27 -> 8 -> 40
#   27 -> 9 -> 40
#   27 -> 11 -> 40
#   27 -> 13 -> 40
#   27 -> 15 -> 40
#   27 -> 17 -> 40
#   27 -> 19 -> 40
#   27 -> 20 -> 40
#   27 -> 1 -> 41
#   27 -> 3 -> 41
#   27 -> 6 -> 41
#   27 -> 8 -> 41
#   27 -> 9 -> 41
#   27 -> 11 -> 41
#   27 -> 13 -> 41
#   27 -> 15 -> 41
#   27 -> 17 -> 41
#   27 -> 19 -> 41
#   27 -> 20 -> 41
#   27 -> 1 -> 44
#   27 -> 3 -> 44
#   27 -> 6 -> 44
#   27 -> 8 -> 44
#   27 -> 9 -> 44
#   27 -> 11 -> 44
#   27 -> 13 -> 44
#   27 -> 15 -> 44
#   27 -> 17 -> 44
#   27 -> 19 -> 44
#   27 -> 20 -> 44
#   27 -> 1 -> 45
#   27 -> 3 -> 45
#   27 -> 6 -> 45
#   27 -> 8 -> 45
#   27 -> 9 -> 45
#   27 -> 11 -> 45
#   27 -> 13 -> 45
#   27 -> 15 -> 45
#   27 -> 17 -> 45
#   27 -> 19 -> 45
#   27 -> 20 -> 45
#   28 -> 1 -> 38
#   28 -> 3 -> 38
#   28 -> 6 -> 38
#   28 -> 8 -> 38
#   28 -> 9 -> 38
#   28 -> 11 -> 38
#   28 -> 13 -> 38
#   28 -> 17 -> 38
#   28 -> 19 -> 38
#   28 -> 20 -> 38
#   28 -> 1 -> 40
#   28 -> 3 -> 40
#   28 -> 6 -> 40
#   28 -> 8 -> 40
#   28 -> 9 -> 40
#   28 -> 11 -> 40
#   28 -> 13 -> 40
#   28 -> 15 -> 40
#   28 -> 17 -> 40
#   28 -> 19 -> 40
#   28 -> 20 -> 40
#   28 -> 1 -> 41
#   28 -> 3 -> 41
#   28 -> 6 -> 41
#   28 -> 8 -> 41
#   28 -> 9 -> 41
#   28 -> 11 -> 41
#   28 -> 13 -> 41
#   28 -> 15 -> 41
#   28 -> 17 -> 41
#   28 -> 19 -> 41
#   28 -> 20 -> 41
#   28 -> 1 -> 44
#   28 -> 3 -> 44
#   28 -> 6 -> 44
#   28 -> 8 -> 44
#   28 -> 9 -> 44
#   28 -> 11 -> 44
#   28 -> 13 -> 44
#   28 -> 15 -> 44
#   28 -> 17 -> 44
#   28 -> 19 -> 44
#   28 -> 20 -> 44
#   28 -> 1 -> 45
#   28 -> 3 -> 45
#   28 -> 6 -> 45
#   28 -> 8 -> 45
#   28 -> 9 -> 45
#   28 -> 11 -> 45
#   28 -> 13 -> 45
#   28 -> 15 -> 45
#   28 -> 17 -> 45
#   28 -> 19 -> 45
#   28 -> 20 -> 45
#   29 -> 1 -> 38
#   29 -> 3 -> 38
#   29 -> 6 -> 38
#   29 -> 8 -> 38
#   29 -> 9 -> 38
#   29 -> 11 -> 38
#   29 -> 13 -> 38
#   29 -> 17 -> 38
#   29 -> 19 -> 38
#   29 -> 20 -> 38
#   29 -> 1 -> 40
#   29 -> 3 -> 40
#   29 -> 6 -> 40
#   29 -> 8 -> 40
#   29 -> 9 -> 40
#   29 -> 11 -> 40
#   29 -> 13 -> 40
#   29 -> 15 -> 40
#   29 -> 17 -> 40
#   29 -> 19 -> 40
#   29 -> 20 -> 40
#   29 -> 1 -> 41
#   29 -> 3 -> 41
#   29 -> 6 -> 41
#   29 -> 8 -> 41
#   29 -> 9 -> 41
#   29 -> 11 -> 41
#   29 -> 13 -> 41
#   29 -> 15 -> 41
#   29 -> 17 -> 41
#   29 -> 19 -> 41
#   29 -> 20 -> 41
#   29 -> 1 -> 44
#   29 -> 3 -> 44
#   29 -> 6 -> 44
#   29 -> 8 -> 44
#   29 -> 9 -> 44
#   29 -> 11 -> 44
#   29 -> 13 -> 44
#   29 -> 15 -> 44
#   29 -> 17 -> 44
#   29 -> 19 -> 44
#   29 -> 20 -> 44
#   29 -> 1 -> 45
#   29 -> 3 -> 45
#   29 -> 6 -> 45
#   29 -> 8 -> 45
#   29 -> 9 -> 45
#   29 -> 11 -> 45
#   29 -> 13 -> 45
#   29 -> 15 -> 45
#   29 -> 17 -> 45
#   29 -> 19 -> 45
#   29 -> 20 -> 45
#   30 -> 1 -> 38
#   30 -> 3 -> 38
#   30 -> 6 -> 38
#   30 -> 8 -> 38
#   30 -> 9 -> 38
#   30 -> 11 -> 38
#   30 -> 13 -> 38
#   30 -> 17 -> 38
#   30 -> 19 -> 38
#   30 -> 20 -> 38
#   30 -> 1 -> 40
#   30 -> 3 -> 40
#   30 -> 6 -> 40
#   30 -> 8 -> 40
#   30 -> 9 -> 40
#   30 -> 11 -> 40
#   30 -> 13 -> 40
#   30 -> 15 -> 40
#   30 -> 17 -> 40
#   30 -> 19 -> 40
#   30 -> 20 -> 40
#   30 -> 1 -> 41
#   30 -> 3 -> 41
#   30 -> 6 -> 41
#   30 -> 8 -> 41
#   30 -> 9 -> 41
#   30 -> 11 -> 41
#   30 -> 13 -> 41
#   30 -> 15 -> 41
#   30 -> 17 -> 41
#   30 -> 19 -> 41
#   30 -> 20 -> 41
#   30 -> 1 -> 44
#   30 -> 3 -> 44
#   30 -> 6 -> 44
#   30 -> 8 -> 44
#   30 -> 9 -> 44
#   30 -> 11 -> 44
#   30 -> 13 -> 44
#   30 -> 15 -> 44
#   30 -> 17 -> 44
#   30 -> 19 -> 44
#   30 -> 20 -> 44
#   30 -> 1 -> 45
#   30 -> 3 -> 45
#   30 -> 6 -> 45
#   30 -> 8 -> 45
#   30 -> 9 -> 45
#   30 -> 11 -> 45
#   30 -> 13 -> 45
#   30 -> 15 -> 45
#   30 -> 17 -> 45
#   30 -> 19 -> 45
#   30 -> 20 -> 45
#   31 -> 1 -> 38
#   31 -> 3 -> 38
#   31 -> 6 -> 38
#   31 -> 8 -> 38
#   31 -> 9 -> 38
#   31 -> 11 -> 38
#   31 -> 13 -> 38
#   31 -> 17 -> 38
#   31 -> 19 -> 38
#   31 -> 20 -> 38
#   31 -> 1 -> 40
#   31 -> 3 -> 40
#   31 -> 6 -> 40
#   31 -> 8 -> 40
#   31 -> 9 -> 40
#   31 -> 11 -> 40
#   31 -> 13 -> 40
#   31 -> 15 -> 40
#   31 -> 17 -> 40
#   31 -> 19 -> 40
#   31 -> 20 -> 40
#   31 -> 1 -> 41
#   31 -> 3 -> 41
#   31 -> 6 -> 41
#   31 -> 8 -> 41
#   31 -> 9 -> 41
#   31 -> 11 -> 41
#   31 -> 13 -> 41
#   31 -> 15 -> 41
#   31 -> 17 -> 41
#   31 -> 19 -> 41
#   31 -> 20 -> 41
#   31 -> 1 -> 44
#   31 -> 3 -> 44
#   31 -> 6 -> 44
#   31 -> 8 -> 44
#   31 -> 9 -> 44
#   31 -> 11 -> 44
#   31 -> 13 -> 44
#   31 -> 15 -> 44
#   31 -> 17 -> 44
#   31 -> 19 -> 44
#   31 -> 20 -> 44
#   31 -> 1 -> 45
#   31 -> 3 -> 45
#   31 -> 6 -> 45
#   31 -> 8 -> 45
#   31 -> 9 -> 45
#   31 -> 11 -> 45
#   31 -> 13 -> 45
#   31 -> 15 -> 45
#   31 -> 17 -> 45
#   31 -> 19 -> 45
#   31 -> 20 -> 45
#   32 -> 1 -> 38
#   32 -> 3 -> 38
#   32 -> 6 -> 38
#   32 -> 8 -> 38
#   32 -> 9 -> 38
#   32 -> 11 -> 38
#   32 -> 13 -> 38
#   32 -> 17 -> 38
#   32 -> 19 -> 38
#   32 -> 20 -> 38
#   32 -> 1 -> 40
#   32 -> 3 -> 40
#   32 -> 6 -> 40
#   32 -> 8 -> 40
#   32 -> 9 -> 40
#   32 -> 11 -> 40
#   32 -> 13 -> 40
#   32 -> 15 -> 40
#   32 -> 17 -> 40
#   32 -> 19 -> 40
#   32 -> 20 -> 40
#   32 -> 1 -> 41
#   32 -> 3 -> 41
#   32 -> 6 -> 41
#   32 -> 8 -> 41
#   32 -> 9 -> 41
#   32 -> 11 -> 41
#   32 -> 13 -> 41
#   32 -> 15 -> 41
#   32 -> 17 -> 41
#   32 -> 19 -> 41
#   32 -> 20 -> 41
#   32 -> 1 -> 44
#   32 -> 3 -> 44
#   32 -> 6 -> 44
#   32 -> 8 -> 44
#   32 -> 9 -> 44
#   32 -> 11 -> 44
#   32 -> 13 -> 44
#   32 -> 15 -> 44
#   32 -> 17 -> 44
#   32 -> 19 -> 44
#   32 -> 20 -> 44
#   32 -> 1 -> 45
#   32 -> 3 -> 45
#   32 -> 6 -> 45
#   32 -> 8 -> 45
#   32 -> 9 -> 45
#   32 -> 11 -> 45
#   32 -> 13 -> 45
#   32 -> 15 -> 45
#   32 -> 17 -> 45
#   32 -> 19 -> 45
#   32 -> 20 -> 45
#   33 -> 1 -> 38
#   33 -> 3 -> 38
#   33 -> 6 -> 38
#   33 -> 8 -> 38
#   33 -> 9 -> 38
#   33 -> 11 -> 38
#   33 -> 13 -> 38
#   33 -> 17 -> 38
#   33 -> 19 -> 38
#   33 -> 20 -> 38
#   33 -> 1 -> 40
#   33 -> 3 -> 40
#   33 -> 6 -> 40
#   33 -> 8 -> 40
#   33 -> 9 -> 40
#   33 -> 11 -> 40
#   33 -> 13 -> 40
#   33 -> 15 -> 40
#   33 -> 17 -> 40
#   33 -> 19 -> 40
#   33 -> 20 -> 40
#   33 -> 1 -> 41
#   33 -> 3 -> 41
#   33 -> 6 -> 41
#   33 -> 8 -> 41
#   33 -> 9 -> 41
#   33 -> 11 -> 41
#   33 -> 13 -> 41
#   33 -> 15 -> 41
#   33 -> 17 -> 41
#   33 -> 19 -> 41
#   33 -> 20 -> 41
#   33 -> 1 -> 44
#   33 -> 3 -> 44
#   33 -> 6 -> 44
#   33 -> 8 -> 44
#   33 -> 9 -> 44
#   33 -> 11 -> 44
#   33 -> 13 -> 44
#   33 -> 15 -> 44
#   33 -> 17 -> 44
#   33 -> 19 -> 44
#   33 -> 20 -> 44
#   33 -> 1 -> 45
#   33 -> 3 -> 45
#   33 -> 6 -> 45
#   33 -> 8 -> 45
#   33 -> 9 -> 45
#   33 -> 11 -> 45
#   33 -> 13 -> 45
#   33 -> 15 -> 45
#   33 -> 17 -> 45
#   33 -> 19 -> 45
#   33 -> 20 -> 45
#   34 -> 1 -> 38
#   34 -> 3 -> 38
#   34 -> 6 -> 38
#   34 -> 8 -> 38
#   34 -> 9 -> 38
#   34 -> 11 -> 38
#   34 -> 13 -> 38
#   34 -> 17 -> 38
#   34 -> 19 -> 38
#   34 -> 20 -> 38
#   34 -> 1 -> 40
#   34 -> 3 -> 40
#   34 -> 6 -> 40
#   34 -> 8 -> 40
#   34 -> 9 -> 40
#   34 -> 11 -> 40
#   34 -> 13 -> 40
#   34 -> 15 -> 40
#   34 -> 17 -> 40
#   34 -> 19 -> 40
#   34 -> 20 -> 40
#   34 -> 1 -> 41
#   34 -> 3 -> 41
#   34 -> 6 -> 41
#   34 -> 8 -> 41
#   34 -> 9 -> 41
#   34 -> 11 -> 41
#   34 -> 13 -> 41
#   34 -> 15 -> 41
#   34 -> 17 -> 41
#   34 -> 19 -> 41
#   34 -> 20 -> 41
#   34 -> 1 -> 44
#   34 -> 3 -> 44
#   34 -> 6 -> 44
#   34 -> 8 -> 44
#   34 -> 9 -> 44
#   34 -> 11 -> 44
#   34 -> 13 -> 44
#   34 -> 15 -> 44
#   34 -> 17 -> 44
#   34 -> 19 -> 44
#   34 -> 20 -> 44
#   34 -> 1 -> 45
#   34 -> 3 -> 45
#   34 -> 6 -> 45
#   34 -> 8 -> 45
#   34 -> 9 -> 45
#   34 -> 11 -> 45
#   34 -> 13 -> 45
#   34 -> 15 -> 45
#   34 -> 17 -> 45
#   34 -> 19 -> 45
#   34 -> 20 -> 45
#   35 -> 1 -> 38
#   35 -> 3 -> 38
#   35 -> 6 -> 38
#   35 -> 8 -> 38
#   35 -> 9 -> 38
#   35 -> 11 -> 38
#   35 -> 13 -> 38
#   35 -> 17 -> 38
#   35 -> 19 -> 38
#   35 -> 20 -> 38
#   35 -> 1 -> 40
#   35 -> 3 -> 40
#   35 -> 6 -> 40
#   35 -> 8 -> 40
#   35 -> 9 -> 40
#   35 -> 11 -> 40
#   35 -> 13 -> 40
#   35 -> 15 -> 40
#   35 -> 17 -> 40
#   35 -> 19 -> 40
#   35 -> 20 -> 40
#   35 -> 1 -> 41
#   35 -> 3 -> 41
#   35 -> 6 -> 41
#   35 -> 8 -> 41
#   35 -> 9 -> 41
#   35 -> 11 -> 41
#   35 -> 13 -> 41
#   35 -> 15 -> 41
#   35 -> 17 -> 41
#   35 -> 19 -> 41
#   35 -> 20 -> 41
#   35 -> 1 -> 44
#   35 -> 3 -> 44
#   35 -> 6 -> 44
#   35 -> 8 -> 44
#   35 -> 9 -> 44
#   35 -> 11 -> 44
#   35 -> 13 -> 44
#   35 -> 15 -> 44
#   35 -> 17 -> 44
#   35 -> 19 -> 44
#   35 -> 20 -> 44
#   35 -> 1 -> 45
#   35 -> 3 -> 45
#   35 -> 6 -> 45
#   35 -> 8 -> 45
#   35 -> 9 -> 45
#   35 -> 11 -> 45
#   35 -> 13 -> 45
#   35 -> 15 -> 45
#   35 -> 17 -> 45
#   35 -> 19 -> 45
#   35 -> 20 -> 45
#   36 -> 1 -> 38
#   36 -> 3 -> 38
#   36 -> 6 -> 38
#   36 -> 8 -> 38
#   36 -> 9 -> 38
#   36 -> 11 -> 38
#   36 -> 13 -> 38
#   36 -> 17 -> 38
#   36 -> 19 -> 38
#   36 -> 20 -> 38
#   36 -> 1 -> 40
#   36 -> 3 -> 40
#   36 -> 6 -> 40
#   36 -> 8 -> 40
#   36 -> 9 -> 40
#   36 -> 11 -> 40
#   36 -> 13 -> 40
#   36 -> 15 -> 40
#   36 -> 17 -> 40
#   36 -> 19 -> 40
#   36 -> 20 -> 40
#   36 -> 1 -> 41
#   36 -> 3 -> 41
#   36 -> 6 -> 41
#   36 -> 8 -> 41
#   36 -> 9 -> 41
#   36 -> 11 -> 41
#   36 -> 13 -> 41
#   36 -> 15 -> 41
#   36 -> 17 -> 41
#   36 -> 19 -> 41
#   36 -> 20 -> 41
#   36 -> 1 -> 44
#   36 -> 3 -> 44
#   36 -> 6 -> 44
#   36 -> 8 -> 44
#   36 -> 9 -> 44
#   36 -> 11 -> 44
#   36 -> 13 -> 44
#   36 -> 15 -> 44
#   36 -> 17 -> 44
#   36 -> 19 -> 44
#   36 -> 20 -> 44
#   36 -> 1 -> 45
#   36 -> 3 -> 45
#   36 -> 6 -> 45
#   36 -> 8 -> 45
#   36 -> 9 -> 45
#   36 -> 11 -> 45
#   36 -> 13 -> 45
#   36 -> 15 -> 45
#   36 -> 17 -> 45
#   36 -> 19 -> 45
#   36 -> 20 -> 45
#   37 -> 1 -> 38
#   37 -> 3 -> 38
#   37 -> 6 -> 38
#   37 -> 8 -> 38
#   37 -> 9 -> 38
#   37 -> 11 -> 38
#   37 -> 13 -> 38
#   37 -> 17 -> 38
#   37 -> 19 -> 38
#   37 -> 20 -> 38
#   37 -> 1 -> 40
#   37 -> 3 -> 40
#   37 -> 6 -> 40
#   37 -> 8 -> 40
#   37 -> 9 -> 40
#   37 -> 11 -> 40
#   37 -> 13 -> 40
#   37 -> 15 -> 40
#   37 -> 17 -> 40
#   37 -> 19 -> 40
#   37 -> 20 -> 40
#   37 -> 1 -> 41
#   37 -> 3 -> 41
#   37 -> 6 -> 41
#   37 -> 8 -> 41
#   37 -> 9 -> 41
#   37 -> 11 -> 41
#   37 -> 13 -> 41
#   37 -> 15 -> 41
#   37 -> 17 -> 41
#   37 -> 19 -> 41
#   37 -> 20 -> 41
#   37 -> 1 -> 44
#   37 -> 3 -> 44
#   37 -> 6 -> 44
#   37 -> 8 -> 44
#   37 -> 9 -> 44
#   37 -> 11 -> 44
#   37 -> 13 -> 44
#   37 -> 15 -> 44
#   37 -> 17 -> 44
#   37 -> 19 -> 44
#   37 -> 20 -> 44
#   37 -> 1 -> 45
#   37 -> 3 -> 45
#   37 -> 6 -> 45
#   37 -> 8 -> 45
#   37 -> 9 -> 45
#   37 -> 11 -> 45
#   37 -> 13 -> 45
#   37 -> 15 -> 45
#   37 -> 17 -> 45
#   37 -> 19 -> 45
#   37 -> 20 -> 45
#   39 -> 1 -> 38
#   39 -> 3 -> 38
#   39 -> 6 -> 38
#   39 -> 8 -> 38
#   39 -> 9 -> 38
#   39 -> 11 -> 38
#   39 -> 13 -> 38
#   39 -> 17 -> 38
#   39 -> 19 -> 38
#   39 -> 20 -> 38
#   39 -> 1 -> 40
#   39 -> 3 -> 40
#   39 -> 6 -> 40
#   39 -> 8 -> 40
#   39 -> 9 -> 40
#   39 -> 11 -> 40
#   39 -> 13 -> 40
#   39 -> 15 -> 40
#   39 -> 17 -> 40
#   39 -> 19 -> 40
#   39 -> 20 -> 40
#   39 -> 1 -> 41
#   39 -> 3 -> 41
#   39 -> 6 -> 41
#   39 -> 8 -> 41
#   39 -> 9 -> 41
#   39 -> 11 -> 41
#   39 -> 13 -> 41
#   39 -> 15 -> 41
#   39 -> 17 -> 41
#   39 -> 19 -> 41
#   39 -> 20 -> 41
#   39 -> 1 -> 44
#   39 -> 3 -> 44
#   39 -> 6 -> 44
#   39 -> 8 -> 44
#   39 -> 9 -> 44
#   39 -> 11 -> 44
#   39 -> 13 -> 44
#   39 -> 15 -> 44
#   39 -> 17 -> 44
#   39 -> 19 -> 44
#   39 -> 20 -> 44
#   39 -> 1 -> 45
#   39 -> 3 -> 45
#   39 -> 6 -> 45
#   39 -> 8 -> 45
#   39 -> 9 -> 45
#   39 -> 11 -> 45
#   39 -> 13 -> 45
#   39 -> 15 -> 45
#   39 -> 17 -> 45
#   39 -> 19 -> 45
#   39 -> 20 -> 45
#   42 -> 0 -> 49
#   42 -> 2 -> 49
#   42 -> 4 -> 49
#   42 -> 7 -> 49
#   42 -> 10 -> 49
#   42 -> 12 -> 49
#   42 -> 14 -> 49
#   42 -> 21 -> 49
#   42 -> 0 -> 51
#   42 -> 2 -> 51
#   42 -> 4 -> 51
#   42 -> 7 -> 51
#   42 -> 10 -> 51
#   42 -> 12 -> 51
#   42 -> 14 -> 51
#   42 -> 21 -> 51
#   42 -> 22 -> 51
#   43 -> 0 -> 49
#   43 -> 2 -> 49
#   43 -> 4 -> 49
#   43 -> 7 -> 49
#   43 -> 10 -> 49
#   43 -> 12 -> 49
#   43 -> 14 -> 49
#   43 -> 21 -> 49
#   43 -> 0 -> 51
#   43 -> 2 -> 51
#   43 -> 4 -> 51
#   43 -> 7 -> 51
#   43 -> 10 -> 51
#   43 -> 12 -> 51
#   43 -> 14 -> 51
#   43 -> 21 -> 51
#   43 -> 22 -> 51
#   50 -> 35 -> 1
#   50 -> 36 -> 1
#   50 -> 37 -> 1
#   50 -> 39 -> 1
#   50 -> 35 -> 3
#   50 -> 36 -> 3
#   50 -> 37 -> 3
#   50 -> 39 -> 3
#   50 -> 35 -> 6
#   50 -> 36 -> 6
#   50 -> 37 -> 6
#   50 -> 39 -> 6
#   50 -> 35 -> 8
#   50 -> 36 -> 8
#   50 -> 37 -> 8
#   50 -> 39 -> 8
#   50 -> 35 -> 9
#   50 -> 36 -> 9
#   50 -> 37 -> 9
#   50 -> 39 -> 9
#   50 -> 35 -> 11
#   50 -> 36 -> 11
#   50 -> 37 -> 11
#   50 -> 39 -> 11
#   50 -> 35 -> 13
#   50 -> 36 -> 13
#   50 -> 37 -> 13
#   50 -> 39 -> 13
#   50 -> 35 -> 15
#   50 -> 36 -> 15
#   50 -> 37 -> 15
#   50 -> 39 -> 15
#   50 -> 35 -> 17
#   50 -> 36 -> 17
#   50 -> 37 -> 17
#   50 -> 39 -> 17
#   50 -> 35 -> 19
#   50 -> 36 -> 19
#   50 -> 37 -> 19
#   50 -> 39 -> 19
#   50 -> 35 -> 20
#   50 -> 36 -> 20
#   50 -> 37 -> 20
#   50 -> 39 -> 20
#   50 -> 35 -> 23
#   50 -> 36 -> 23
#   50 -> 37 -> 23
#   50 -> 39 -> 23
#   50 -> 35 -> 24
#   50 -> 36 -> 24
#   50 -> 37 -> 24
#   50 -> 39 -> 24
#   50 -> 35 -> 26
#   50 -> 36 -> 26
#   50 -> 37 -> 26
#   50 -> 39 -> 26
#   50 -> 35 -> 27
#   50 -> 36 -> 27
#   50 -> 37 -> 27
#   50 -> 39 -> 27
#   50 -> 35 -> 28
#   50 -> 36 -> 28
#   50 -> 37 -> 28
#   50 -> 39 -> 28
#   50 -> 35 -> 29
#   50 -> 36 -> 29
#   50 -> 37 -> 29
#   50 -> 39 -> 29
#   50 -> 35 -> 30
#   50 -> 36 -> 30
#   50 -> 37 -> 30
#   50 -> 39 -> 30
#   50 -> 35 -> 31
#   50 -> 36 -> 31
#   50 -> 37 -> 31
#   50 -> 39 -> 31
#   50 -> 35 -> 32
#   50 -> 36 -> 32
#   50 -> 37 -> 32
#   50 -> 39 -> 32
#   50 -> 35 -> 33
#   50 -> 36 -> 33
#   50 -> 37 -> 33
#   50 -> 39 -> 33
#   50 -> 35 -> 34
#   50 -> 36 -> 34
#   50 -> 37 -> 34
#   50 -> 39 -> 34
#   52 -> 35 -> 1
#   52 -> 36 -> 1
#   52 -> 37 -> 1
#   52 -> 39 -> 1
#   52 -> 35 -> 3
#   52 -> 36 -> 3
#   52 -> 37 -> 3
#   52 -> 39 -> 3
#   52 -> 35 -> 6
#   52 -> 36 -> 6
#   52 -> 37 -> 6
#   52 -> 39 -> 6
#   52 -> 35 -> 8
#   52 -> 36 -> 8
#   52 -> 37 -> 8
#   52 -> 39 -> 8
#   52 -> 35 -> 9
#   52 -> 36 -> 9
#   52 -> 37 -> 9
#   52 -> 39 -> 9
#   52 -> 35 -> 11
#   52 -> 36 -> 11
#   52 -> 37 -> 11
#   52 -> 39 -> 11
#   52 -> 35 -> 13
#   52 -> 36 -> 13
#   52 -> 37 -> 13
#   52 -> 39 -> 13
#   52 -> 35 -> 15
#   52 -> 36 -> 15
#   52 -> 37 -> 15
#   52 -> 39 -> 15
#   52 -> 35 -> 17
#   52 -> 36 -> 17
#   52 -> 37 -> 17
#   52 -> 39 -> 17
#   52 -> 35 -> 19
#   52 -> 36 -> 19
#   52 -> 37 -> 19
#   52 -> 39 -> 19
#   52 -> 35 -> 20
#   52 -> 36 -> 20
#   52 -> 37 -> 20
#   52 -> 39 -> 20
#   52 -> 35 -> 23
#   52 -> 36 -> 23
#   52 -> 37 -> 23
#   52 -> 39 -> 23
#   52 -> 35 -> 24
#   52 -> 36 -> 24
#   52 -> 37 -> 24
#   52 -> 39 -> 24
#   52 -> 35 -> 26
#   52 -> 36 -> 26
#   52 -> 37 -> 26
#   52 -> 39 -> 26
#   52 -> 35 -> 27
#   52 -> 36 -> 27
#   52 -> 37 -> 27
#   52 -> 39 -> 27
#   52 -> 35 -> 28
#   52 -> 36 -> 28
#   52 -> 37 -> 28
#   52 -> 39 -> 28
#   52 -> 35 -> 29
#   52 -> 36 -> 29
#   52 -> 37 -> 29
#   52 -> 39 -> 29
#   52 -> 35 -> 30
#   52 -> 36 -> 30
#   52 -> 37 -> 30
#   52 -> 39 -> 30
#   52 -> 35 -> 31
#   52 -> 36 -> 31
#   52 -> 37 -> 31
#   52 -> 39 -> 31
#   52 -> 35 -> 32
#   52 -> 36 -> 32
#   52 -> 37 -> 32
#   52 -> 39 -> 32
#   52 -> 35 -> 33
#   52 -> 36 -> 33
#   52 -> 37 -> 33
#   52 -> 39 -> 33
#   52 -> 35 -> 34
#   52 -> 36 -> 34
#   52 -> 37 -> 34
#   52 -> 39 -> 34

# %%
# Out:
# The domination_matrix is transitive.

# %%
for i in range(sol_reduced.N_solutions):
    plt.figure()
    pack_vis_sol.pack_vis_sol(sol_reduced, solution_idx=i)
    plt.title(f'Cost={pack_cost.AreaCost().compute_cost_allocate(sol_reduced)[0][i].get():.6f}, AR={sol_reduced.aspect_ratios[i].get():.4f}, Angle={np.degrees(sol_reduced.angles[i].get()):.2f}°')
