# %%
import sys
import os
sys.path.insert(0, os.path.join(os.getcwd(), '../core'))
import kaggle_support as kgs
import importlib
import matplotlib.pyplot as plt
import numpy as np
import cupy as cp
from dataclasses import dataclass, field, fields
import pack_cuda
import pack_vis
import pack_cost
import copy
import time
import pack_ga
from IPython.display import HTML, display, clear_output
pack_cuda.USE_FLOAT32 = True
pack_cuda._ensure_initialized()
# Out:
# vast
# vast
# stop final relax at some point

# %%
## importlib.reload(pack_ga)
fastMode = False
runner = pack_ga.GA()
runner.N_trees_to_do = np.array([200])
if fastMode:
    runner.initializer.jiggler.duration_compact /= 10
    runner.initializer.jiggler.plot_interval = None
    runner.initializer.jiggler.n_rounds = 1
    runner.relaxers = runner.relaxers[:1]
    runner.relaxers[0].n_iterations= 10
    runner.n_generations = 100
    runner.population_size = 10
runner.run()
plt.plot(runner.best_cost_per_generation)
# Out:
# Generation 0, Trees 200, Best cost: 0.74867827, Est: 0.37433914, h: 8.610185
# Generation 1, Trees 200, Best cost: 0.74849421, Est: 0.37424709, h: 8.609218
# Generation 2, Trees 200, Best cost: 0.74863470, Est: 0.37431736, h: 8.609468
# Generation 3, Trees 200, Best cost: 0.74848950, Est: 0.37424477, h: 8.609003
# Generation 4, Trees 200, Best cost: 0.74849743, Est: 0.37424870, h: 8.608932
# Generation 5, Trees 200, Best cost: 0.74861872, Est: 0.37430935, h: 8.611010
# Generation 6, Trees 200, Best cost: 0.74850178, Est: 0.37425087, h: 8.608820
# Generation 7, Trees 200, Best cost: 0.74849772, Est: 0.37424885, h: 8.608792
# Generation 8, Trees 200, Best cost: 0.74850082, Est: 0.37425041, h: 8.608794
# Generation 9, Trees 200, Best cost: 0.74854684, Est: 0.37427341, h: 8.610973
# Generation 10, Trees 200, Best cost: 0.74849933, Est: 0.37424965, h: 8.608810
# Generation 11, Trees 200, Best cost: 0.74865931, Est: 0.37432964, h: 8.609210
# Generation 12, Trees 200, Best cost: 0.74849570, Est: 0.37424786, h: 8.608847
# Generation 13, Trees 200, Best cost: 0.74849808, Est: 0.37424904, h: 8.608800
# Generation 14, Trees 200, Best cost: 0.74850094, Est: 0.37425049, h: 8.608789
# Generation 15, Trees 200, Best cost: 0.74849689, Est: 0.37424843, h: 8.608792
# Generation 16, Trees 200, Best cost: 0.74850327, Est: 0.37425163, h: 8.608804
# Generation 17, Trees 200, Best cost: 0.74850214, Est: 0.37425106, h: 8.608789
# Generation 18, Trees 200, Best cost: 0.74857879, Est: 0.37428940, h: 8.611239
# Generation 19, Trees 200, Best cost: 0.74850017, Est: 0.37425007, h: 8.608790
# Generation 20, Trees 200, Best cost: 0.74753082, Est: 0.37376541, h: 8.605498
# Generation 21, Trees 200, Best cost: 0.74719846, Est: 0.37359924, h: 8.602822
# Generation 22, Trees 200, Best cost: 0.74719101, Est: 0.37359550, h: 8.602752
# Generation 23, Trees 200, Best cost: 0.74734646, Est: 0.37367325, h: 8.602743
# Generation 24, Trees 200, Best cost: 0.74722797, Est: 0.37361397, h: 8.602536
# Generation 25, Trees 200, Best cost: 0.74721783, Est: 0.37360893, h: 8.602630
# Generation 26, Trees 200, Best cost: 0.74730402, Est: 0.37365200, h: 8.604053
# Generation 27, Trees 200, Best cost: 0.74722368, Est: 0.37361183, h: 8.602652
# Generation 28, Trees 200, Best cost: 0.74564976, Est: 0.37282486, h: 8.592560
# Generation 29, Trees 200, Best cost: 0.74553889, Est: 0.37276943, h: 8.591696
# Generation 30, Trees 200, Best cost: 0.74552345, Est: 0.37276173, h: 8.591680
# Generation 31, Trees 200, Best cost: 0.74551779, Est: 0.37275890, h: 8.591694
# Generation 32, Trees 200, Best cost: 0.74550688, Est: 0.37275345, h: 8.591681
# Generation 33, Trees 200, Best cost: 0.74550158, Est: 0.37275078, h: 8.591677
# Generation 34, Trees 200, Best cost: 0.74544841, Est: 0.37272419, h: 8.591936
# Generation 35, Trees 200, Best cost: 0.74543601, Est: 0.37271801, h: 8.591880
# Generation 36, Trees 200, Best cost: 0.74554342, Est: 0.37277172, h: 8.591845
# Generation 37, Trees 200, Best cost: 0.74550617, Est: 0.37275307, h: 8.591683
# Generation 38, Trees 200, Best cost: 0.74551487, Est: 0.37275742, h: 8.591726
# Generation 39, Trees 200, Best cost: 0.74551052, Est: 0.37275524, h: 8.591715
# Generation 40, Trees 200, Best cost: 0.74545634, Est: 0.37272816, h: 8.591954
# Generation 41, Trees 200, Best cost: 0.74541008, Est: 0.37270504, h: 8.591723
# Generation 42, Trees 200, Best cost: 0.74548608, Est: 0.37274303, h: 8.592022
# Generation 43, Trees 200, Best cost: 0.74550933, Est: 0.37275467, h: 8.591708
# Generation 44, Trees 200, Best cost: 0.74544615, Est: 0.37272308, h: 8.591935
# Generation 45, Trees 200, Best cost: 0.74551547, Est: 0.37275772, h: 8.591739
# Generation 46, Trees 200, Best cost: 0.74544668, Est: 0.37272335, h: 8.591924
# Generation 47, Trees 200, Best cost: 0.74544209, Est: 0.37272106, h: 8.591917
# Generation 48, Trees 200, Best cost: 0.74543852, Est: 0.37271927, h: 8.591921
# Generation 49, Trees 200, Best cost: 0.74551469, Est: 0.37275734, h: 8.591767
# Generation 50, Trees 200, Best cost: 0.74544334, Est: 0.37272167, h: 8.591926
# Generation 51, Trees 200, Best cost: 0.74552590, Est: 0.37276295, h: 8.591809
# Generation 52, Trees 200, Best cost: 0.74550569, Est: 0.37275284, h: 8.591718
# Generation 53, Trees 200, Best cost: 0.74551153, Est: 0.37275578, h: 8.591723
# Generation 54, Trees 200, Best cost: 0.74544531, Est: 0.37272266, h: 8.591928
# Generation 55, Trees 200, Best cost: 0.74528921, Est: 0.37264462, h: 8.592110
# Generation 56, Trees 200, Best cost: 0.74531192, Est: 0.37265594, h: 8.591863
# Generation 57, Trees 200, Best cost: 0.74530494, Est: 0.37265247, h: 8.591587
# Generation 58, Trees 200, Best cost: 0.74490821, Est: 0.37245411, h: 8.590530
# Generation 59, Trees 200, Best cost: 0.74488688, Est: 0.37244343, h: 8.590455
# Generation 60, Trees 200, Best cost: 0.74485248, Est: 0.37242622, h: 8.590267
# Generation 61, Trees 200, Best cost: 0.74490929, Est: 0.37245464, h: 8.590626
# Generation 62, Trees 200, Best cost: 0.74494040, Est: 0.37247021, h: 8.590858
# Generation 63, Trees 200, Best cost: 0.74493307, Est: 0.37246655, h: 8.590844
# Generation 64, Trees 200, Best cost: 0.74489880, Est: 0.37244942, h: 8.590505
# Generation 65, Trees 200, Best cost: 0.74491507, Est: 0.37245754, h: 8.590725
# Generation 66, Trees 200, Best cost: 0.74494970, Est: 0.37247486, h: 8.591017
# Generation 67, Trees 200, Best cost: 0.74496996, Est: 0.37248497, h: 8.592048
# Generation 68, Trees 200, Best cost: 0.74491525, Est: 0.37245762, h: 8.590657
# Generation 69, Trees 200, Best cost: 0.74484605, Est: 0.37242302, h: 8.590183
# Generation 70, Trees 200, Best cost: 0.74484581, Est: 0.37242290, h: 8.590288
# Generation 71, Trees 200, Best cost: 0.74488622, Est: 0.37244312, h: 8.590504
# Generation 72, Trees 200, Best cost: 0.74491900, Est: 0.37245949, h: 8.590662
# Generation 73, Trees 200, Best cost: 0.74484479, Est: 0.37242241, h: 8.590225
# Generation 74, Trees 200, Best cost: 0.74448073, Est: 0.37224037, h: 8.588418
# Generation 75, Trees 200, Best cost: 0.74440700, Est: 0.37220348, h: 8.588081
# Generation 76, Trees 200, Best cost: 0.74443859, Est: 0.37221928, h: 8.588266
# Generation 77, Trees 200, Best cost: 0.74441832, Est: 0.37220917, h: 8.588228
# Generation 78, Trees 200, Best cost: 0.74434471, Est: 0.37217236, h: 8.587690
# Generation 79, Trees 200, Best cost: 0.74433136, Est: 0.37216568, h: 8.587310
# Generation 80, Trees 200, Best cost: 0.74428183, Est: 0.37214092, h: 8.587368
# Generation 81, Trees 200, Best cost: 0.74426597, Est: 0.37213299, h: 8.586956
# Generation 82, Trees 200, Best cost: 0.74423838, Est: 0.37211918, h: 8.586832
# Generation 83, Trees 200, Best cost: 0.74424130, Est: 0.37212067, h: 8.586802
# Generation 84, Trees 200, Best cost: 0.74429172, Est: 0.37214584, h: 8.588226
# Generation 85, Trees 200, Best cost: 0.74428803, Est: 0.37214401, h: 8.587103
# Generation 86, Trees 200, Best cost: 0.74423784, Est: 0.37211891, h: 8.586777
# Generation 87, Trees 200, Best cost: 0.74423915, Est: 0.37211956, h: 8.586826
# Generation 88, Trees 200, Best cost: 0.74429840, Est: 0.37214920, h: 8.587022
# Generation 89, Trees 200, Best cost: 0.74428433, Est: 0.37214218, h: 8.588186
# Generation 90, Trees 200, Best cost: 0.74431789, Est: 0.37215893, h: 8.586957
# Generation 91, Trees 200, Best cost: 0.74428129, Est: 0.37214066, h: 8.588251
# Generation 92, Trees 200, Best cost: 0.74429792, Est: 0.37214897, h: 8.587030
# Generation 93, Trees 200, Best cost: 0.74427414, Est: 0.37213707, h: 8.586967
# Generation 94, Trees 200, Best cost: 0.74431467, Est: 0.37215733, h: 8.587215
# Generation 95, Trees 200, Best cost: 0.74427378, Est: 0.37213688, h: 8.586962
# Generation 96, Trees 200, Best cost: 0.74425226, Est: 0.37212612, h: 8.586916
# Generation 97, Trees 200, Best cost: 0.74423593, Est: 0.37211796, h: 8.586782
# Generation 98, Trees 200, Best cost: 0.74431318, Est: 0.37215660, h: 8.586892
# Generation 99, Trees 200, Best cost: 0.74426252, Est: 0.37213127, h: 8.586957
# Generation 100, Trees 200, Best cost: 0.74423826, Est: 0.37211914, h: 8.586719
# Generation 101, Trees 200, Best cost: 0.74428797, Est: 0.37214397, h: 8.588199
# Generation 102, Trees 200, Best cost: 0.74425918, Est: 0.37212959, h: 8.586931
# Generation 103, Trees 200, Best cost: 0.74429905, Est: 0.37214954, h: 8.587029
# Generation 104, Trees 200, Best cost: 0.74429584, Est: 0.37214790, h: 8.587015
# Generation 105, Trees 200, Best cost: 0.74429750, Est: 0.37214874, h: 8.586942
# Generation 106, Trees 200, Best cost: 0.74425030, Est: 0.37212517, h: 8.586910
# Generation 107, Trees 200, Best cost: 0.74427688, Est: 0.37213844, h: 8.587027
# Generation 108, Trees 200, Best cost: 0.74425721, Est: 0.37212860, h: 8.586934
# Generation 109, Trees 200, Best cost: 0.74423808, Est: 0.37211903, h: 8.588019
# Generation 110, Trees 200, Best cost: 0.74428350, Est: 0.37214176, h: 8.587078
# Generation 111, Trees 200, Best cost: 0.74427056, Est: 0.37213528, h: 8.587021
# Generation 112, Trees 200, Best cost: 0.74425215, Est: 0.37212608, h: 8.586632
# Generation 113, Trees 200, Best cost: 0.74424136, Est: 0.37212067, h: 8.586802
# Generation 114, Trees 200, Best cost: 0.74429929, Est: 0.37214966, h: 8.587016
# Generation 115, Trees 200, Best cost: 0.74427289, Est: 0.37213646, h: 8.587021
# Generation 116, Trees 200, Best cost: 0.74423915, Est: 0.37211956, h: 8.586775
# Generation 117, Trees 200, Best cost: 0.74410427, Est: 0.37205212, h: 8.585987
# Generation 118, Trees 200, Best cost: 0.74408847, Est: 0.37204422, h: 8.585924
# Generation 119, Trees 200, Best cost: 0.74408782, Est: 0.37204391, h: 8.585933
# Generation 120, Trees 200, Best cost: 0.74418461, Est: 0.37209232, h: 8.585469
# Generation 121, Trees 200, Best cost: 0.74415070, Est: 0.37207535, h: 8.586312
# Generation 122, Trees 200, Best cost: 0.74415141, Est: 0.37207569, h: 8.586300
# Generation 123, Trees 200, Best cost: 0.74415296, Est: 0.37207649, h: 8.586304
# Generation 124, Trees 200, Best cost: 0.74415171, Est: 0.37207584, h: 8.586312
# Generation 125, Trees 200, Best cost: 0.74415195, Est: 0.37207596, h: 8.586313
# Generation 126, Trees 200, Best cost: 0.74414384, Est: 0.37207191, h: 8.586302
# Generation 127, Trees 200, Best cost: 0.74415106, Est: 0.37207554, h: 8.586315
# Generation 128, Trees 200, Best cost: 0.74413407, Est: 0.37206703, h: 8.586635
# Generation 129, Trees 200, Best cost: 0.74410915, Est: 0.37205460, h: 8.586695
# Generation 130, Trees 200, Best cost: 0.74365097, Est: 0.37182549, h: 8.584137
# Generation 131, Trees 200, Best cost: 0.74338108, Est: 0.37169056, h: 8.581393
# Generation 132, Trees 200, Best cost: 0.74341160, Est: 0.37170582, h: 8.583039
# Generation 133, Trees 200, Best cost: 0.74311835, Est: 0.37155918, h: 8.580368
# Generation 134, Trees 200, Best cost: 0.74298865, Est: 0.37149433, h: 8.579507
# Generation 135, Trees 200, Best cost: 0.74310642, Est: 0.37155323, h: 8.579765
# Generation 136, Trees 200, Best cost: 0.74296463, Est: 0.37148232, h: 8.579537
# Generation 137, Trees 200, Best cost: 0.74295938, Est: 0.37147968, h: 8.579515
# Generation 138, Trees 200, Best cost: 0.74294895, Est: 0.37147446, h: 8.579374
# Generation 139, Trees 200, Best cost: 0.74293399, Est: 0.37146698, h: 8.579417
# Generation 140, Trees 200, Best cost: 0.74284124, Est: 0.37142063, h: 8.579249
# Generation 141, Trees 200, Best cost: 0.74294859, Est: 0.37147430, h: 8.579247
# Generation 142, Trees 200, Best cost: 0.74292636, Est: 0.37146317, h: 8.579162
# Generation 143, Trees 200, Best cost: 0.74294835, Est: 0.37147419, h: 8.579383
# Generation 144, Trees 200, Best cost: 0.74286574, Est: 0.37143288, h: 8.578917
# Generation 145, Trees 200, Best cost: 0.74214685, Est: 0.37107342, h: 8.573612
# Generation 146, Trees 200, Best cost: 0.74193752, Est: 0.37096874, h: 8.572535
# Generation 147, Trees 200, Best cost: 0.74190301, Est: 0.37095150, h: 8.572416
# Generation 148, Trees 200, Best cost: 0.74203229, Est: 0.37101616, h: 8.572538
# Generation 149, Trees 200, Best cost: 0.74188739, Est: 0.37094368, h: 8.572564
# Generation 150, Trees 200, Best cost: 0.74201810, Est: 0.37100906, h: 8.572627
# Generation 151, Trees 200, Best cost: 0.74185240, Est: 0.37092621, h: 8.572494
# Generation 152, Trees 200, Best cost: 0.74203295, Est: 0.37101646, h: 8.572734
# Generation 153, Trees 200, Best cost: 0.74202478, Est: 0.37101238, h: 8.572682
# Generation 154, Trees 200, Best cost: 0.74187839, Est: 0.37093918, h: 8.572481
# Generation 155, Trees 200, Best cost: 0.74203038, Est: 0.37101521, h: 8.572703
# Generation 156, Trees 200, Best cost: 0.74185449, Est: 0.37092724, h: 8.572487
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 13
#      11     runner.n_generations = 100
#      12     runner.population_size = 10
# ---> 13 runner.run()
#      14 plt.plot(runner.best_cost_per_generation)
#
# File /packing/code/analysis/../core/pack_ga.py:185, in GA.run(self)
#     182 current_pop.configuration.h = cp.array(new_h, dtype=np.float32)
#     184 # Relax and score the population
# --> 185 self._relax_and_score(current_pop)
#
# File /packing/code/analysis/../core/pack_ga.py:116, in GA._relax_and_score(self, population)
#     114 sol = population.configuration
#     115 for relaxer in self.relaxers:
# --> 116     sol = relaxer.run_simulation(sol)
#     117 costs = self.fitness_cost.compute_cost_allocate(sol)[0]
#     118 population.configuration = sol
#
# File /packing/code/analysis/../core/pack_dynamics.py:67, in run_simulation(self, sol)
#      65 dt = self.dt
#      66 # Reuse pre-allocated arrays
# ---> 67 self.cost.compute_cost(sol, total_cost, total_grad, bound_grad)
#      69 # Clip gradients per tree to prevent violent repulsion
#      70 # if self.max_grad_norm is not None:
#      71 #     grad_norms = cp.sqrt(cp.sum(total_grad**2, axis=2))  # (n_ensembles, n_trees)
#      72 #     grad_norms = cp.maximum(grad_norms, 1e-8)  # Avoid division by zero
#      73 #     clip_factor = cp.minimum(1.0, self.max_grad_norm / grad_norms)  # (n_ensembles, n_trees)
#      74 #     total_grad = total_grad * clip_factor[:, :, None]  # Apply to each component
#      76 xyt -= dt * total_grad
#
# File /packing/code/analysis/../core/pack_cost.py:46, in Cost.compute_cost(self, sol, cost, grad_xyt, grad_bound)
#      44 def compute_cost(self, sol:kgs.SolutionCollection, cost:cp.ndarray, grad_xyt:cp.ndarray, grad_bound:cp.ndarray):
#      45     # Subclass can implement faster version with preallocated gradients
# ---> 46     self._compute_cost(sol, cost, grad_xyt, grad_bound)
#      47     cost *= self.scaling
#      48     grad_xyt *= self.scaling
#
# File /packing/code/analysis/../core/pack_cost.py:86, in CostCompound._compute_cost(self, sol, cost, grad_xyt, grad_bound)
#      82 grad_bound[:] = 0
#      84 # Check if we need to allocate or reallocate temporary arrays
#      85 # Use dtype matching the output arrays to ensure consistency
# ---> 86 current_shape = (sol.N_solutions, sol.xyt.shape, sol.h.shape)
#      87 if self._temp_shape != current_shape:
#      88     self._temp_cost = cp.zeros(sol.N_solutions, dtype=cost.dtype)
#
# File /packing/code/analysis/../core/kaggle_support.py:340, in SolutionCollection.N_solutions(self)
#     338 if self.xyt is None:
#     339     return 0
# --> 340 arr = to_cpu(self.xyt)
#     341 return int(np.asarray(arr).shape[0])
#
# File /packing/code/analysis/../core/kaggle_support.py:176, in to_cpu(array)
#     174 def to_cpu(array):
#     175     if isinstance(array, cp.ndarray):
# --> 176         return array.get()
#     177     else:
#     178         return array
#
# KeyboardInterrupt:

# %%
plt.plot(runner.best_cost_per_generation[:156])
