# %%
import sys
import os
sys.path.insert(0, os.path.join(os.getcwd(), '../core'))
import kaggle_support as kgs
import importlib
import matplotlib.pyplot as plt
import numpy as np
import cupy as cp
from dataclasses import dataclass, field, fields
import pack_cuda
import pack_vis
import pack_cost
import copy
import time
import pack_ga
from IPython.display import HTML, display, clear_output
pack_cuda.USE_FLOAT32 = True
pack_cuda._ensure_initialized()
# Out:
# local
# stop final relax at some point
# init CUDA
# Detected GPU compute capability: 8.9 (arch=sm_89)
# GPU max threads per block: 1024
# === Compiling kernel variant: crystal ===
# Defines: ENABLE_CRYSTAL_AXES, ENABLE_OVERLAP_AREA, ENABLE_SEPARATION
# Command: /usr/local/cuda/bin/nvcc -O3 -use_fast_math --extra-device-vectorization --ptxas-options=-v,--warn-on-spills -arch=sm_89 -DENABLE_CRYSTAL_AXES -DENABLE_OVERLAP_AREA -DENABLE_SEPARATION -cubin /mnt/d//packing/temp/pack_cuda_saved.cu -o /mnt/d//packing/temp/pack_cuda_crystal.cubin
# ptxas info    : 0 bytes gmem, 1172 bytes cmem[3]
# ptxas info    : Compiling entry function 'multi_boundary_distance_list_total' for 'sm_89'
# ptxas info    : Function properties for multi_boundary_distance_list_total
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 36 registers, 404 bytes cmem[0], 16 bytes cmem[2]
# ptxas info    : Compiling entry function 'multi_boundary_list_total' for 'sm_89'
# ptxas info    : Function properties for multi_boundary_list_total
#     240 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 43 registers, 240 bytes cumulative stack size, 404 bytes cmem[0], 32 bytes cmem[2]
# ptxas info    : Compiling entry function 'multi_overlap_list_total' for 'sm_89'
# ptxas info    : Function properties for multi_overlap_list_total
#     1264 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 78 registers, 1264 bytes cumulative stack size, 420 bytes cmem[0], 24 bytes cmem[2]
#
#
# --- Kernel: multi_overlap_list_total [crystal] ---
#   Max threads per block (kernel): 768
#   Num registers: 78
#   Shared memory (bytes): 0
#   Const memory (bytes): 1172
#   Local memory (bytes): 1264
# === Compiling kernel variant: no_sep ===
# Defines: ENABLE_OVERLAP_AREA
# Command: /usr/local/cuda/bin/nvcc -O3 -use_fast_math --extra-device-vectorization --ptxas-options=-v,--warn-on-spills -arch=sm_89 -DENABLE_OVERLAP_AREA -cubin /mnt/d//packing/temp/pack_cuda_saved.cu -o /mnt/d//packing/temp/pack_cuda_no_sep.cubin

# %%
# %%time
importlib.reload(pack_ga)
runner = pack_ga.GA()
runner.N_trees_to_do = np.array([40])
runner.plot_fitness_predictors = True
runner.plot_diversity_matrix = True
runner.n_generations = 5
runner.initializer.jiggler.duration_compact /= 10
kgs.profiling=True
runner.run()
# Out:
# stop final relax at some point
# Timer unit: 1e-09 s
#
# Total time: 2.90302 s
# File: /mnt/d/packing/code/analysis/../core/pack_dynamics.py
# Function: Optimizer.run_simulation at line 40
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     40                                               @typechecked
#     41                                               @kgs.profile_each_line
#     42                                               def run_simulation(self, sol:kgs.SolutionCollectionSquare):
#     43                                                   # Initial configuration
#     44
#     45         1     109435.0 109435.0      0.0          sol.check_constraints()
#     46         1     152954.0 152954.0      0.0          sol = copy.deepcopy(sol)
#     47         1     543458.0 543458.0      0.0          sol.snap()
#     48
#     49         1        469.0    469.0      0.0          xyt = sol.xyt
#     50         1        239.0    239.0      0.0          h = sol.h
#     51
#     52         1        606.0    606.0      0.0          n_ensembles = xyt.shape[0]
#     53         1        375.0    375.0      0.0          n_trees = xyt.shape[1]
#     54
#     55         1        943.0    943.0      0.0          if self.plot_interval is not None:
#     56                                                       fig, ax = plt.subplots(figsize=(8, 8))
#     57                                                       tree_list = kgs.TreeList()
#     58
#     59                                                   # Pre-allocate gradient arrays once (float32 for efficiency)
#     60         1      13876.0  13876.0      0.0          total_cost = cp.zeros(n_ensembles, dtype=cp.float32)
#     61         1      31134.0  31134.0      0.0          total_grad = cp.zeros_like(xyt, dtype=cp.float32)
#     62         1      16438.0  16438.0      0.0          bound_grad = cp.zeros_like(h, dtype=cp.float32)
#     63
#     64         1       2169.0   2169.0      0.0          t_total0 = np.float32(0.)
#     65         1       1208.0   1208.0      0.0          t_last_plot = np.float32(-np.inf)
#     66
#     67                                                   # For second-order lookahead, store previous gradients
#     68         1        649.0    649.0      0.0          if self.use_lookahead:
#     69                                                       prev_grad = cp.zeros_like(xyt, dtype=cp.float32)
#     70                                                       prev_bound_grad = cp.zeros_like(h, dtype=cp.float32)
#     71
#     72      2401    1022578.0    425.9      0.0          for i_iteration in range(self.n_iterations):
#     73      2400     640787.0    267.0      0.0              dt = self.dt
#     74                                                       # Reuse pre-allocated arrays
#     75      2400 2741882876.0 1.14e+06     94.4              self.cost.compute_cost(sol, total_cost, total_grad, bound_grad)
#     76
#     77                                                       # Clip gradients per tree to prevent violent repulsion
#     78                                                       # if self.max_grad_norm is not None:
#     79                                                       #     grad_norms = cp.sqrt(cp.sum(total_grad**2, axis=2))  # (n_ensembles, n_trees)
#     80                                                       #     grad_norms = cp.maximum(grad_norms, 1e-8)  # Avoid division by zero
#     81                                                       #     clip_factor = cp.minimum(1.0, self.max_grad_norm / grad_norms)  # (n_ensembles, n_trees)
#     82                                                       #     total_grad = total_grad * clip_factor[:, :, None]  # Apply to each component
#     83
#     84      2400    1252392.0    521.8      0.0              if self.use_lookahead and i_iteration > 0:
#     85                                                           # Second-order lookahead: use gradient + 0.5 * (gradient - prev_gradient)
#     86                                                           # This is a predictor-corrector scheme: x_{n+1} = x_n - dt * (1.5*g_n - 0.5*g_{n-1})
#     87                                                           # Equivalent to Adams-Bashforth 2-step method
#     88                                                           effective_grad = 1.5 * total_grad - 0.5 * prev_grad
#     89                                                           effective_bound_grad = 1.5 * bound_grad - 0.5 * prev_bound_grad
#     90                                                           xyt -= dt * effective_grad
#     91                                                           h -= dt * effective_bound_grad
#     92                                                       else:
#     93      2400   77221020.0  32175.4      2.7                  xyt -= dt * total_grad
#     94      2400   75289973.0  31370.8      2.6                  h -= dt * bound_grad
#     95
#     96      2400    1098920.0    457.9      0.0              if self.use_lookahead:
#     97                                                           # Store current gradients for next iteration
#     98                                                           prev_grad[:] = total_grad
#     99                                                           prev_bound_grad[:] = bound_grad
#    100
#    101      2400    2720039.0   1133.3      0.1              t_total0 += dt
#    102
#    103      2400    1020480.0    425.2      0.0              if self.plot_interval is not None and t_total0 - t_last_plot >= self.plot_interval*0.999:
#    104                                                           t_last_plot = t_total0+0
#    105                                                           ax.clear()
#    106                                                           ax.set_aspect('equal', adjustable='box')
#    107                                                           tree_list.xyt = cp.asnumpy(xyt[0])
#    108                                                           pack_vis.visualize_tree_list(tree_list, ax=ax, h=cp.asnumpy(h[0]))
#    109                                                           ax.set_title(f'Time: {t_total0:.2f}')
#    110                                                           display(fig)
#    111                                                           clear_output(wait=True)
#    112         1        489.0    489.0      0.0          return sol
#
# Timer unit: 1e-09 s
#
# Total time: 3.02601 s
# File: /mnt/d/packing/code/analysis/../core/pack_dynamics.py
# Function: Optimizer.run_simulation at line 40
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     40                                               @typechecked
#     41                                               @kgs.profile_each_line
#     42                                               def run_simulation(self, sol:kgs.SolutionCollectionSquare):
#     43                                                   # Initial configuration
#     44
#     45         1      76507.0  76507.0      0.0          sol.check_constraints()
#     46         1     137927.0 137927.0      0.0          sol = copy.deepcopy(sol)
#     47         1     562759.0 562759.0      0.0          sol.snap()
#     48
#     49         1        395.0    395.0      0.0          xyt = sol.xyt
#     50         1        249.0    249.0      0.0          h = sol.h
#     51
#     52         1        701.0    701.0      0.0          n_ensembles = xyt.shape[0]
#     53         1        327.0    327.0      0.0          n_trees = xyt.shape[1]
#     54
#     55         1        975.0    975.0      0.0          if self.plot_interval is not None:
#     56                                                       fig, ax = plt.subplots(figsize=(8, 8))
#     57                                                       tree_list = kgs.TreeList()
#     58
#     59                                                   # Pre-allocate gradient arrays once (float32 for efficiency)
#     60         1      17542.0  17542.0      0.0          total_cost = cp.zeros(n_ensembles, dtype=cp.float32)
#     61         1      25390.0  25390.0      0.0          total_grad = cp.zeros_like(xyt, dtype=cp.float32)
#     62         1      16020.0  16020.0      0.0          bound_grad = cp.zeros_like(h, dtype=cp.float32)
#     63
#     64         1       2095.0   2095.0      0.0          t_total0 = np.float32(0.)
#     65         1       1512.0   1512.0      0.0          t_last_plot = np.float32(-np.inf)
#     66
#     67                                                   # For second-order lookahead, store previous gradients
#     68         1        398.0    398.0      0.0          if self.use_lookahead:
#     69                                                       prev_grad = cp.zeros_like(xyt, dtype=cp.float32)
#     70                                                       prev_bound_grad = cp.zeros_like(h, dtype=cp.float32)
#     71
#     72      2401     972395.0    405.0      0.0          for i_iteration in range(self.n_iterations):
#     73      2400     599676.0    249.9      0.0              dt = self.dt
#     74                                                       # Reuse pre-allocated arrays
#     75      2400 2882262645.0  1.2e+06     95.2              self.cost.compute_cost(sol, total_cost, total_grad, bound_grad)
#     76
#     77                                                       # Clip gradients per tree to prevent violent repulsion
#     78                                                       # if self.max_grad_norm is not None:
#     79                                                       #     grad_norms = cp.sqrt(cp.sum(total_grad**2, axis=2))  # (n_ensembles, n_trees)
#     80                                                       #     grad_norms = cp.maximum(grad_norms, 1e-8)  # Avoid division by zero
#     81                                                       #     clip_factor = cp.minimum(1.0, self.max_grad_norm / grad_norms)  # (n_ensembles, n_trees)
#     82                                                       #     total_grad = total_grad * clip_factor[:, :, None]  # Apply to each component
#     83
#     84      2400    1181763.0    492.4      0.0              if self.use_lookahead and i_iteration > 0:
#     85                                                           # Second-order lookahead: use gradient + 0.5 * (gradient - prev_gradient)
#     86                                                           # This is a predictor-corrector scheme: x_{n+1} = x_n - dt * (1.5*g_n - 0.5*g_{n-1})
#     87                                                           # Equivalent to Adams-Bashforth 2-step method
#     88                                                           effective_grad = 1.5 * total_grad - 0.5 * prev_grad
#     89                                                           effective_bound_grad = 1.5 * bound_grad - 0.5 * prev_bound_grad
#     90                                                           xyt -= dt * effective_grad
#     91                                                           h -= dt * effective_bound_grad
#     92                                                       else:
#     93      2400   71064763.0  29610.3      2.3                  xyt -= dt * total_grad
#     94      2400   64660292.0  26941.8      2.1                  h -= dt * bound_grad
#     95
#     96      2400    1198597.0    499.4      0.0              if self.use_lookahead:
#     97                                                           # Store current gradients for next iteration
#     98                                                           prev_grad[:] = total_grad
#     99                                                           prev_bound_grad[:] = bound_grad
#    100
#    101      2400    2412381.0   1005.2      0.1              t_total0 += dt
#    102
#    103      2400     811871.0    338.3      0.0              if self.plot_interval is not None and t_total0 - t_last_plot >= self.plot_interval*0.999:
#    104                                                           t_last_plot = t_total0+0
#    105                                                           ax.clear()
#    106                                                           ax.set_aspect('equal', adjustable='box')
#    107                                                           tree_list.xyt = cp.asnumpy(xyt[0])
#    108                                                           pack_vis.visualize_tree_list(tree_list, ax=ax, h=cp.asnumpy(h[0]))
#    109                                                           ax.set_title(f'Time: {t_total0:.2f}')
#    110                                                           display(fig)
#    111                                                           clear_output(wait=True)
#    112         1        446.0    446.0      0.0          return sol
# Generation 0, Trees 40, Best cost: 0.67439735, Est: 1.68599339, h: 8.201933
# Timer unit: 1e-09 s
#
# Total time: 6.37592 s
# File: /mnt/d/packing/code/analysis/../core/pack_dynamics.py
# Function: Optimizer.run_simulation at line 40
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     40                                               @typechecked
#     41                                               @kgs.profile_each_line
#     42                                               def run_simulation(self, sol:kgs.SolutionCollectionSquare):
#     43                                                   # Initial configuration
#     44
#     45         1      83159.0  83159.0      0.0          sol.check_constraints()
#     46         1     141962.0 141962.0      0.0          sol = copy.deepcopy(sol)
#     47         1     557822.0 557822.0      0.0          sol.snap()
#     48
#     49         1        475.0    475.0      0.0          xyt = sol.xyt
#     50         1        231.0    231.0      0.0          h = sol.h
#     51
#     52         1        605.0    605.0      0.0          n_ensembles = xyt.shape[0]
#     53         1        365.0    365.0      0.0          n_trees = xyt.shape[1]
#     54
#     55         1        790.0    790.0      0.0          if self.plot_interval is not None:
#     56                                                       fig, ax = plt.subplots(figsize=(8, 8))
#     57                                                       tree_list = kgs.TreeList()
#     58
#     59                                                   # Pre-allocate gradient arrays once (float32 for efficiency)
#     60         1      18712.0  18712.0      0.0          total_cost = cp.zeros(n_ensembles, dtype=cp.float32)
#     61         1      25759.0  25759.0      0.0          total_grad = cp.zeros_like(xyt, dtype=cp.float32)
#     62         1      16444.0  16444.0      0.0          bound_grad = cp.zeros_like(h, dtype=cp.float32)
#     63
#     64         1       2278.0   2278.0      0.0          t_total0 = np.float32(0.)
#     65         1       1390.0   1390.0      0.0          t_last_plot = np.float32(-np.inf)
#     66
#     67                                                   # For second-order lookahead, store previous gradients
#     68         1        523.0    523.0      0.0          if self.use_lookahead:
#     69                                                       prev_grad = cp.zeros_like(xyt, dtype=cp.float32)
#     70                                                       prev_bound_grad = cp.zeros_like(h, dtype=cp.float32)
#     71
#     72      2401    1046193.0    435.7      0.0          for i_iteration in range(self.n_iterations):
#     73      2400     600764.0    250.3      0.0              dt = self.dt
#     74                                                       # Reuse pre-allocated arrays
#     75      2400 6219238822.0 2.59e+06     97.5              self.cost.compute_cost(sol, total_cost, total_grad, bound_grad)
#     76
#     77                                                       # Clip gradients per tree to prevent violent repulsion
#     78                                                       # if self.max_grad_norm is not None:
#     79                                                       #     grad_norms = cp.sqrt(cp.sum(total_grad**2, axis=2))  # (n_ensembles, n_trees)
#     80                                                       #     grad_norms = cp.maximum(grad_norms, 1e-8)  # Avoid division by zero
#     81                                                       #     clip_factor = cp.minimum(1.0, self.max_grad_norm / grad_norms)  # (n_ensembles, n_trees)
#     82                                                       #     total_grad = total_grad * clip_factor[:, :, None]  # Apply to each component
#     83
#     84      2400    1561527.0    650.6      0.0              if self.use_lookahead and i_iteration > 0:
#     85                                                           # Second-order lookahead: use gradient + 0.5 * (gradient - prev_gradient)
#     86                                                           # This is a predictor-corrector scheme: x_{n+1} = x_n - dt * (1.5*g_n - 0.5*g_{n-1})
#     87                                                           # Equivalent to Adams-Bashforth 2-step method
#     88                                                           effective_grad = 1.5 * total_grad - 0.5 * prev_grad
#     89                                                           effective_bound_grad = 1.5 * bound_grad - 0.5 * prev_bound_grad
#     90                                                           xyt -= dt * effective_grad
#     91                                                           h -= dt * effective_bound_grad
#     92                                                       else:
#     93      2400   80100908.0  33375.4      1.3                  xyt -= dt * total_grad
#     94      2400   67914151.0  28297.6      1.1                  h -= dt * bound_grad
#     95
#     96      2400    1058205.0    440.9      0.0              if self.use_lookahead:
#     97                                                           # Store current gradients for next iteration
#     98                                                           prev_grad[:] = total_grad
#     99                                                           prev_bound_grad[:] = bound_grad
#    100
#    101      2400    2686882.0   1119.5      0.0              t_total0 += dt
#    102
#    103      2400     858277.0    357.6      0.0              if self.plot_interval is not None and t_total0 - t_last_plot >= self.plot_interval*0.999:
#    104                                                           t_last_plot = t_total0+0
#    105                                                           ax.clear()
#    106                                                           ax.set_aspect('equal', adjustable='box')
#    107                                                           tree_list.xyt = cp.asnumpy(xyt[0])
#    108                                                           pack_vis.visualize_tree_list(tree_list, ax=ax, h=cp.asnumpy(h[0]))
#    109                                                           ax.set_title(f'Time: {t_total0:.2f}')
#    110                                                           display(fig)
#    111                                                           clear_output(wait=True)
#    112         1        405.0    405.0      0.0          return sol
#
# Timer unit: 1e-09 s
#
# Total time: 4.21722 s
# File: /mnt/d/packing/code/analysis/../core/pack_dynamics.py
# Function: Optimizer.run_simulation at line 40
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     40                                               @typechecked
#     41                                               @kgs.profile_each_line
#     42                                               def run_simulation(self, sol:kgs.SolutionCollectionSquare):
#     43                                                   # Initial configuration
#     44
#     45         1      78247.0  78247.0      0.0          sol.check_constraints()
#     46         1     371780.0 371780.0      0.0          sol = copy.deepcopy(sol)
#     47         1     877493.0 877493.0      0.0          sol.snap()
#     48
#     49         1        449.0    449.0      0.0          xyt = sol.xyt
#     50         1        228.0    228.0      0.0          h = sol.h
#     51
#     52         1        667.0    667.0      0.0          n_ensembles = xyt.shape[0]
#     53         1        359.0    359.0      0.0          n_trees = xyt.shape[1]
#     54
#     55         1        538.0    538.0      0.0          if self.plot_interval is not None:
#     56                                                       fig, ax = plt.subplots(figsize=(8, 8))
#     57                                                       tree_list = kgs.TreeList()
#     58
#     59                                                   # Pre-allocate gradient arrays once (float32 for efficiency)
#     60         1      18648.0  18648.0      0.0          total_cost = cp.zeros(n_ensembles, dtype=cp.float32)
#     61         1      28138.0  28138.0      0.0          total_grad = cp.zeros_like(xyt, dtype=cp.float32)
#     62         1      19332.0  19332.0      0.0          bound_grad = cp.zeros_like(h, dtype=cp.float32)
#     63
#     64         1       3143.0   3143.0      0.0          t_total0 = np.float32(0.)
#     65         1       1377.0   1377.0      0.0          t_last_plot = np.float32(-np.inf)
#     66
#     67                                                   # For second-order lookahead, store previous gradients
#     68         1        461.0    461.0      0.0          if self.use_lookahead:
#     69                                                       prev_grad = cp.zeros_like(xyt, dtype=cp.float32)
#     70                                                       prev_bound_grad = cp.zeros_like(h, dtype=cp.float32)
#     71
#     72      2401     975495.0    406.3      0.0          for i_iteration in range(self.n_iterations):
#     73      2400     628314.0    261.8      0.0              dt = self.dt
#     74                                                       # Reuse pre-allocated arrays
#     75      2400 4057547327.0 1.69e+06     96.2              self.cost.compute_cost(sol, total_cost, total_grad, bound_grad)
#     76
#     77                                                       # Clip gradients per tree to prevent violent repulsion
#     78                                                       # if self.max_grad_norm is not None:
#     79                                                       #     grad_norms = cp.sqrt(cp.sum(total_grad**2, axis=2))  # (n_ensembles, n_trees)
#     80                                                       #     grad_norms = cp.maximum(grad_norms, 1e-8)  # Avoid division by zero
#     81                                                       #     clip_factor = cp.minimum(1.0, self.max_grad_norm / grad_norms)  # (n_ensembles, n_trees)
#     82                                                       #     total_grad = total_grad * clip_factor[:, :, None]  # Apply to each component
#     83
#     84      2400    1753965.0    730.8      0.0              if self.use_lookahead and i_iteration > 0:
#     85                                                           # Second-order lookahead: use gradient + 0.5 * (gradient - prev_gradient)
#     86                                                           # This is a predictor-corrector scheme: x_{n+1} = x_n - dt * (1.5*g_n - 0.5*g_{n-1})
#     87                                                           # Equivalent to Adams-Bashforth 2-step method
#     88                                                           effective_grad = 1.5 * total_grad - 0.5 * prev_grad
#     89                                                           effective_bound_grad = 1.5 * bound_grad - 0.5 * prev_bound_grad
#     90                                                           xyt -= dt * effective_grad
#     91                                                           h -= dt * effective_bound_grad
#     92                                                       else:
#     93      2400   81133701.0  33805.7      1.9                  xyt -= dt * total_grad
#     94      2400   68940558.0  28725.2      1.6                  h -= dt * bound_grad
#     95
#     96      2400    1211911.0    505.0      0.0              if self.use_lookahead:
#     97                                                           # Store current gradients for next iteration
#     98                                                           prev_grad[:] = total_grad
#     99                                                           prev_bound_grad[:] = bound_grad
#    100
#    101      2400    2673966.0   1114.2      0.1              t_total0 += dt
#    102
#    103      2400     954736.0    397.8      0.0              if self.plot_interval is not None and t_total0 - t_last_plot >= self.plot_interval*0.999:
#    104                                                           t_last_plot = t_total0+0
#    105                                                           ax.clear()
#    106                                                           ax.set_aspect('equal', adjustable='box')
#    107                                                           tree_list.xyt = cp.asnumpy(xyt[0])
#    108                                                           pack_vis.visualize_tree_list(tree_list, ax=ax, h=cp.asnumpy(h[0]))
#    109                                                           ax.set_title(f'Time: {t_total0:.2f}')
#    110                                                           display(fig)
#    111                                                           clear_output(wait=True)
#    112         1        525.0    525.0      0.0          return sol
# Generation 1, Trees 40, Best cost: 0.21162589, Est: 0.52906470, h: 4.546253
# Timer unit: 1e-09 s
#
# Total time: 10.7703 s
# File: /mnt/d/packing/code/analysis/../core/pack_dynamics.py
# Function: Optimizer.run_simulation at line 40
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     40                                               @typechecked
#     41                                               @kgs.profile_each_line
#     42                                               def run_simulation(self, sol:kgs.SolutionCollectionSquare):
#     43                                                   # Initial configuration
#     44
#     45         1     146787.0 146787.0      0.0          sol.check_constraints()
#     46         1     303954.0 303954.0      0.0          sol = copy.deepcopy(sol)
#     47         1    1321107.0 1.32e+06      0.0          sol.snap()
#     48
#     49         1        800.0    800.0      0.0          xyt = sol.xyt
#     50         1        443.0    443.0      0.0          h = sol.h
#     51
#     52         1       1271.0   1271.0      0.0          n_ensembles = xyt.shape[0]
#     53         1        784.0    784.0      0.0          n_trees = xyt.shape[1]
#     54
#     55         1       1911.0   1911.0      0.0          if self.plot_interval is not None:
#     56                                                       fig, ax = plt.subplots(figsize=(8, 8))
#     57                                                       tree_list = kgs.TreeList()
#     58
#     59                                                   # Pre-allocate gradient arrays once (float32 for efficiency)
#     60         1      38155.0  38155.0      0.0          total_cost = cp.zeros(n_ensembles, dtype=cp.float32)
#     61         1      51745.0  51745.0      0.0          total_grad = cp.zeros_like(xyt, dtype=cp.float32)
#     62         1      39010.0  39010.0      0.0          bound_grad = cp.zeros_like(h, dtype=cp.float32)
#     63
#     64         1       5162.0   5162.0      0.0          t_total0 = np.float32(0.)
#     65         1       3524.0   3524.0      0.0          t_last_plot = np.float32(-np.inf)
#     66
#     67                                                   # For second-order lookahead, store previous gradients
#     68         1       1374.0   1374.0      0.0          if self.use_lookahead:
#     69                                                       prev_grad = cp.zeros_like(xyt, dtype=cp.float32)
#     70                                                       prev_bound_grad = cp.zeros_like(h, dtype=cp.float32)
#     71
#     72      2401     863258.0    359.5      0.0          for i_iteration in range(self.n_iterations):
#     73      2400     600437.0    250.2      0.0              dt = self.dt
#     74                                                       # Reuse pre-allocated arrays
#     75      2400     1.06e+10 4.43e+06     98.6              self.cost.compute_cost(sol, total_cost, total_grad, bound_grad)
#     76
#     77                                                       # Clip gradients per tree to prevent violent repulsion
#     78                                                       # if self.max_grad_norm is not None:
#     79                                                       #     grad_norms = cp.sqrt(cp.sum(total_grad**2, axis=2))  # (n_ensembles, n_trees)
#     80                                                       #     grad_norms = cp.maximum(grad_norms, 1e-8)  # Avoid division by zero
#     81                                                       #     clip_factor = cp.minimum(1.0, self.max_grad_norm / grad_norms)  # (n_ensembles, n_trees)
#     82                                                       #     total_grad = total_grad * clip_factor[:, :, None]  # Apply to each component
#     83
#     84      2400    1368331.0    570.1      0.0              if self.use_lookahead and i_iteration > 0:
#     85                                                           # Second-order lookahead: use gradient + 0.5 * (gradient - prev_gradient)
#     86                                                           # This is a predictor-corrector scheme: x_{n+1} = x_n - dt * (1.5*g_n - 0.5*g_{n-1})
#     87                                                           # Equivalent to Adams-Bashforth 2-step method
#     88                                                           effective_grad = 1.5 * total_grad - 0.5 * prev_grad
#     89                                                           effective_bound_grad = 1.5 * bound_grad - 0.5 * prev_bound_grad
#     90                                                           xyt -= dt * effective_grad
#     91                                                           h -= dt * effective_bound_grad
#     92                                                       else:
#     93      2400   75271490.0  31363.1      0.7                  xyt -= dt * total_grad
#     94      2400   63744779.0  26560.3      0.6                  h -= dt * bound_grad
#     95
#     96      2400    1034173.0    430.9      0.0              if self.use_lookahead:
#     97                                                           # Store current gradients for next iteration
#     98                                                           prev_grad[:] = total_grad
#     99                                                           prev_bound_grad[:] = bound_grad
#    100
#    101      2400    2510743.0   1046.1      0.0              t_total0 += dt
#    102
#    103      2400     917884.0    382.5      0.0              if self.plot_interval is not None and t_total0 - t_last_plot >= self.plot_interval*0.999:
#    104                                                           t_last_plot = t_total0+0
#    105                                                           ax.clear()
#    106                                                           ax.set_aspect('equal', adjustable='box')
#    107                                                           tree_list.xyt = cp.asnumpy(xyt[0])
#    108                                                           pack_vis.visualize_tree_list(tree_list, ax=ax, h=cp.asnumpy(h[0]))
#    109                                                           ax.set_title(f'Time: {t_total0:.2f}')
#    110                                                           display(fig)
#    111                                                           clear_output(wait=True)
#    112         1        462.0    462.0      0.0          return sol
#
# Timer unit: 1e-09 s
#
# Total time: 5.33131 s
# File: /mnt/d/packing/code/analysis/../core/pack_dynamics.py
# Function: Optimizer.run_simulation at line 40
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     40                                               @typechecked
#     41                                               @kgs.profile_each_line
#     42                                               def run_simulation(self, sol:kgs.SolutionCollectionSquare):
#     43                                                   # Initial configuration
#     44
#     45         1     489433.0 489433.0      0.0          sol.check_constraints()
#     46         1     213196.0 213196.0      0.0          sol = copy.deepcopy(sol)
#     47         1    1488638.0 1.49e+06      0.0          sol.snap()
#     48
#     49         1        522.0    522.0      0.0          xyt = sol.xyt
#     50         1        320.0    320.0      0.0          h = sol.h
#     51
#     52         1        919.0    919.0      0.0          n_ensembles = xyt.shape[0]
#     53         1        384.0    384.0      0.0          n_trees = xyt.shape[1]
#     54
#     55         1        843.0    843.0      0.0          if self.plot_interval is not None:
#     56                                                       fig, ax = plt.subplots(figsize=(8, 8))
#     57                                                       tree_list = kgs.TreeList()
#     58
#     59                                                   # Pre-allocate gradient arrays once (float32 for efficiency)
#     60         1      44401.0  44401.0      0.0          total_cost = cp.zeros(n_ensembles, dtype=cp.float32)
#     61         1      28953.0  28953.0      0.0          total_grad = cp.zeros_like(xyt, dtype=cp.float32)
#     62         1      63270.0  63270.0      0.0          bound_grad = cp.zeros_like(h, dtype=cp.float32)
#     63
#     64         1      77333.0  77333.0      0.0          t_total0 = np.float32(0.)
#     65         1       2306.0   2306.0      0.0          t_last_plot = np.float32(-np.inf)
#     66
#     67                                                   # For second-order lookahead, store previous gradients
#     68         1        907.0    907.0      0.0          if self.use_lookahead:
#     69                                                       prev_grad = cp.zeros_like(xyt, dtype=cp.float32)
#     70                                                       prev_bound_grad = cp.zeros_like(h, dtype=cp.float32)
#     71
#     72      2401     954708.0    397.6      0.0          for i_iteration in range(self.n_iterations):
#     73      2400     671441.0    279.8      0.0              dt = self.dt
#     74                                                       # Reuse pre-allocated arrays
#     75      2400 5189605171.0 2.16e+06     97.3              self.cost.compute_cost(sol, total_cost, total_grad, bound_grad)
#     76
#     77                                                       # Clip gradients per tree to prevent violent repulsion
#     78                                                       # if self.max_grad_norm is not None:
#     79                                                       #     grad_norms = cp.sqrt(cp.sum(total_grad**2, axis=2))  # (n_ensembles, n_trees)
#     80                                                       #     grad_norms = cp.maximum(grad_norms, 1e-8)  # Avoid division by zero
#     81                                                       #     clip_factor = cp.minimum(1.0, self.max_grad_norm / grad_norms)  # (n_ensembles, n_trees)
#     82                                                       #     total_grad = total_grad * clip_factor[:, :, None]  # Apply to each component
#     83
#     84      2400    1369503.0    570.6      0.0              if self.use_lookahead and i_iteration > 0:
#     85                                                           # Second-order lookahead: use gradient + 0.5 * (gradient - prev_gradient)
#     86                                                           # This is a predictor-corrector scheme: x_{n+1} = x_n - dt * (1.5*g_n - 0.5*g_{n-1})
#     87                                                           # Equivalent to Adams-Bashforth 2-step method
#     88                                                           effective_grad = 1.5 * total_grad - 0.5 * prev_grad
#     89                                                           effective_bound_grad = 1.5 * bound_grad - 0.5 * prev_bound_grad
#     90                                                           xyt -= dt * effective_grad
#     91                                                           h -= dt * effective_bound_grad
#     92                                                       else:
#     93      2400   69953347.0  29147.2      1.3                  xyt -= dt * total_grad
#     94      2400   62225272.0  25927.2      1.2                  h -= dt * bound_grad
#     95
#     96      2400    1007143.0    419.6      0.0              if self.use_lookahead:
#     97                                                           # Store current gradients for next iteration
#     98                                                           prev_grad[:] = total_grad
#     99                                                           prev_bound_grad[:] = bound_grad
#    100
#    101      2400    2309216.0    962.2      0.0              t_total0 += dt
#    102
#    103      2400     799774.0    333.2      0.0              if self.plot_interval is not None and t_total0 - t_last_plot >= self.plot_interval*0.999:
#    104                                                           t_last_plot = t_total0+0
#    105                                                           ax.clear()
#    106                                                           ax.set_aspect('equal', adjustable='box')
#    107                                                           tree_list.xyt = cp.asnumpy(xyt[0])
#    108                                                           pack_vis.visualize_tree_list(tree_list, ax=ax, h=cp.asnumpy(h[0]))
#    109                                                           ax.set_title(f'Time: {t_total0:.2f}')
#    110                                                           display(fig)
#    111                                                           clear_output(wait=True)
#    112         1        417.0    417.0      0.0          return sol
# Generation 2, Trees 40, Best cost: 0.17692325, Est: 0.44230809, h: 4.164514
# Timer unit: 1e-09 s
#
# Total time: 12.7079 s
# File: /mnt/d/packing/code/analysis/../core/pack_dynamics.py
# Function: Optimizer.run_simulation at line 40
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     40                                               @typechecked
#     41                                               @kgs.profile_each_line
#     42                                               def run_simulation(self, sol:kgs.SolutionCollectionSquare):
#     43                                                   # Initial configuration
#     44
#     45         1      79396.0  79396.0      0.0          sol.check_constraints()
#     46         1     129828.0 129828.0      0.0          sol = copy.deepcopy(sol)
#     47         1     518867.0 518867.0      0.0          sol.snap()
#     48
#     49         1        443.0    443.0      0.0          xyt = sol.xyt
#     50         1        277.0    277.0      0.0          h = sol.h
#     51
#     52         1        547.0    547.0      0.0          n_ensembles = xyt.shape[0]
#     53         1        355.0    355.0      0.0          n_trees = xyt.shape[1]
#     54
#     55         1       1053.0   1053.0      0.0          if self.plot_interval is not None:
#     56                                                       fig, ax = plt.subplots(figsize=(8, 8))
#     57                                                       tree_list = kgs.TreeList()
#     58
#     59                                                   # Pre-allocate gradient arrays once (float32 for efficiency)
#     60         1      15844.0  15844.0      0.0          total_cost = cp.zeros(n_ensembles, dtype=cp.float32)
#     61         1      22466.0  22466.0      0.0          total_grad = cp.zeros_like(xyt, dtype=cp.float32)
#     62         1      14786.0  14786.0      0.0          bound_grad = cp.zeros_like(h, dtype=cp.float32)
#     63
#     64         1       2020.0   2020.0      0.0          t_total0 = np.float32(0.)
#     65         1       1168.0   1168.0      0.0          t_last_plot = np.float32(-np.inf)
#     66
#     67                                                   # For second-order lookahead, store previous gradients
#     68         1        520.0    520.0      0.0          if self.use_lookahead:
#     69                                                       prev_grad = cp.zeros_like(xyt, dtype=cp.float32)
#     70                                                       prev_bound_grad = cp.zeros_like(h, dtype=cp.float32)
#     71
#     72      2401    1017257.0    423.7      0.0          for i_iteration in range(self.n_iterations):
#     73      2400     566965.0    236.2      0.0              dt = self.dt
#     74                                                       # Reuse pre-allocated arrays
#     75      2400     1.26e+10 5.23e+06     98.9              self.cost.compute_cost(sol, total_cost, total_grad, bound_grad)
#     76
#     77                                                       # Clip gradients per tree to prevent violent repulsion
#     78                                                       # if self.max_grad_norm is not None:
#     79                                                       #     grad_norms = cp.sqrt(cp.sum(total_grad**2, axis=2))  # (n_ensembles, n_trees)
#     80                                                       #     grad_norms = cp.maximum(grad_norms, 1e-8)  # Avoid division by zero
#     81                                                       #     clip_factor = cp.minimum(1.0, self.max_grad_norm / grad_norms)  # (n_ensembles, n_trees)
#     82                                                       #     total_grad = total_grad * clip_factor[:, :, None]  # Apply to each component
#     83
#     84      2400    1356754.0    565.3      0.0              if self.use_lookahead and i_iteration > 0:
#     85                                                           # Second-order lookahead: use gradient + 0.5 * (gradient - prev_gradient)
#     86                                                           # This is a predictor-corrector scheme: x_{n+1} = x_n - dt * (1.5*g_n - 0.5*g_{n-1})
#     87                                                           # Equivalent to Adams-Bashforth 2-step method
#     88                                                           effective_grad = 1.5 * total_grad - 0.5 * prev_grad
#     89                                                           effective_bound_grad = 1.5 * bound_grad - 0.5 * prev_bound_grad
#     90                                                           xyt -= dt * effective_grad
#     91                                                           h -= dt * effective_bound_grad
#     92                                                       else:
#     93      2400   74196893.0  30915.4      0.6                  xyt -= dt * total_grad
#     94      2400   62815745.0  26173.2      0.5                  h -= dt * bound_grad
# ...
#     95
#     96      2400     974349.0    406.0      0.0              if self.use_lookahead:
#     97                                                           # Store current gradients for next iteration
#     98                                                           prev_grad[:] = total_grad
#     99                                                           prev_bound_grad[:] = bound_grad
#    100
#    101      2400    2272303.0    946.8      0.0              t_total0 += dt
#    102
#    103      2400     810651.0    337.8      0.0              if self.plot_interval is not None and t_total0 - t_last_plot >= self.plot_interval*0.999:
#    104                                                           t_last_plot = t_total0+0
#    105                                                           ax.clear()
#    106                                                           ax.set_aspect('equal', adjustable='box')
#    107                                                           tree_list.xyt = cp.asnumpy(xyt[0])
#    108                                                           pack_vis.visualize_tree_list(tree_list, ax=ax, h=cp.asnumpy(h[0]))
#    109                                                           ax.set_title(f'Time: {t_total0:.2f}')
#    110                                                           display(fig)
#    111                                                           clear_output(wait=True)
#    112         1        420.0    420.0      0.0          return sol
# Generation 4, Trees 40, Best cost: 0.16223913, Est: 0.40559783, h: 4.007023
# Timer unit: 1e-09 s
#
# Total time: 13.7736 s
# File: /mnt/d/packing/code/analysis/../core/pack_dynamics.py
# Function: Optimizer.run_simulation at line 40
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     40                                               @typechecked
#     41                                               @kgs.profile_each_line
#     42                                               def run_simulation(self, sol:kgs.SolutionCollectionSquare):
#     43                                                   # Initial configuration
#     44
#     45         1      81381.0  81381.0      0.0          sol.check_constraints()
#     46         1     162051.0 162051.0      0.0          sol = copy.deepcopy(sol)
#     47         1     647204.0 647204.0      0.0          sol.snap()
#     48
#     49         1        454.0    454.0      0.0          xyt = sol.xyt
#     50         1        222.0    222.0      0.0          h = sol.h
#     51
#     52         1        627.0    627.0      0.0          n_ensembles = xyt.shape[0]
#     53         1        351.0    351.0      0.0          n_trees = xyt.shape[1]
#     54
#     55         1        895.0    895.0      0.0          if self.plot_interval is not None:
#     56                                                       fig, ax = plt.subplots(figsize=(8, 8))
#     57                                                       tree_list = kgs.TreeList()
#     58
#     59                                                   # Pre-allocate gradient arrays once (float32 for efficiency)
#     60         1      16808.0  16808.0      0.0          total_cost = cp.zeros(n_ensembles, dtype=cp.float32)
#     61         1      22173.0  22173.0      0.0          total_grad = cp.zeros_like(xyt, dtype=cp.float32)
#     62         1      15827.0  15827.0      0.0          bound_grad = cp.zeros_like(h, dtype=cp.float32)
#     63
#     64         1       2291.0   2291.0      0.0          t_total0 = np.float32(0.)
#     65         1       1538.0   1538.0      0.0          t_last_plot = np.float32(-np.inf)
#     66
#     67                                                   # For second-order lookahead, store previous gradients
#     68         1        594.0    594.0      0.0          if self.use_lookahead:
#     69                                                       prev_grad = cp.zeros_like(xyt, dtype=cp.float32)
#     70                                                       prev_bound_grad = cp.zeros_like(h, dtype=cp.float32)
#     71
#     72      2401     881035.0    366.9      0.0          for i_iteration in range(self.n_iterations):
#     73      2400     622111.0    259.2      0.0              dt = self.dt
#     74                                                       # Reuse pre-allocated arrays
#     75      2400     1.36e+10 5.68e+06     98.9              self.cost.compute_cost(sol, total_cost, total_grad, bound_grad)
#     76
#     77                                                       # Clip gradients per tree to prevent violent repulsion
#     78                                                       # if self.max_grad_norm is not None:
#     79                                                       #     grad_norms = cp.sqrt(cp.sum(total_grad**2, axis=2))  # (n_ensembles, n_trees)
#     80                                                       #     grad_norms = cp.maximum(grad_norms, 1e-8)  # Avoid division by zero
#     81                                                       #     clip_factor = cp.minimum(1.0, self.max_grad_norm / grad_norms)  # (n_ensembles, n_trees)
#     82                                                       #     total_grad = total_grad * clip_factor[:, :, None]  # Apply to each component
#     83
#     84      2400    1596837.0    665.3      0.0              if self.use_lookahead and i_iteration > 0:
#     85                                                           # Second-order lookahead: use gradient + 0.5 * (gradient - prev_gradient)
#     86                                                           # This is a predictor-corrector scheme: x_{n+1} = x_n - dt * (1.5*g_n - 0.5*g_{n-1})
#     87                                                           # Equivalent to Adams-Bashforth 2-step method
#     88                                                           effective_grad = 1.5 * total_grad - 0.5 * prev_grad
#     89                                                           effective_bound_grad = 1.5 * bound_grad - 0.5 * prev_bound_grad
#     90                                                           xyt -= dt * effective_grad
#     91                                                           h -= dt * effective_bound_grad
#     92                                                       else:
#     93      2400   77840532.0  32433.6      0.6                  xyt -= dt * total_grad
#     94      2400   65250130.0  27187.6      0.5                  h -= dt * bound_grad
#     95
#     96      2400     953719.0    397.4      0.0              if self.use_lookahead:
#     97                                                           # Store current gradients for next iteration
#     98                                                           prev_grad[:] = total_grad
#     99                                                           prev_bound_grad[:] = bound_grad
#    100
#    101      2400    2687273.0   1119.7      0.0              t_total0 += dt
#    102
#    103      2400     891463.0    371.4      0.0              if self.plot_interval is not None and t_total0 - t_last_plot >= self.plot_interval*0.999:
#    104                                                           t_last_plot = t_total0+0
#    105                                                           ax.clear()
#    106                                                           ax.set_aspect('equal', adjustable='box')
#    107                                                           tree_list.xyt = cp.asnumpy(xyt[0])
#    108                                                           pack_vis.visualize_tree_list(tree_list, ax=ax, h=cp.asnumpy(h[0]))
#    109                                                           ax.set_title(f'Time: {t_total0:.2f}')
#    110                                                           display(fig)
#    111                                                           clear_output(wait=True)
#    112         1        499.0    499.0      0.0          return sol
#
# Timer unit: 1e-09 s
#
# Total time: 5.98776 s
# File: /mnt/d/packing/code/analysis/../core/pack_dynamics.py
# Function: Optimizer.run_simulation at line 40
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     40                                               @typechecked
#     41                                               @kgs.profile_each_line
#     42                                               def run_simulation(self, sol:kgs.SolutionCollectionSquare):
#     43                                                   # Initial configuration
#     44
#     45         1      75246.0  75246.0      0.0          sol.check_constraints()
#     46         1     151106.0 151106.0      0.0          sol = copy.deepcopy(sol)
#     47         1     867671.0 867671.0      0.0          sol.snap()
#     48
#     49         1        676.0    676.0      0.0          xyt = sol.xyt
#     50         1        362.0    362.0      0.0          h = sol.h
#     51
#     52         1        800.0    800.0      0.0          n_ensembles = xyt.shape[0]
#     53         1        371.0    371.0      0.0          n_trees = xyt.shape[1]
#     54
#     55         1       1081.0   1081.0      0.0          if self.plot_interval is not None:
#     56                                                       fig, ax = plt.subplots(figsize=(8, 8))
#     57                                                       tree_list = kgs.TreeList()
#     58
#     59                                                   # Pre-allocate gradient arrays once (float32 for efficiency)
#     60         1      19566.0  19566.0      0.0          total_cost = cp.zeros(n_ensembles, dtype=cp.float32)
#     61         1      27668.0  27668.0      0.0          total_grad = cp.zeros_like(xyt, dtype=cp.float32)
#     62         1      17721.0  17721.0      0.0          bound_grad = cp.zeros_like(h, dtype=cp.float32)
#     63
#     64         1       2643.0   2643.0      0.0          t_total0 = np.float32(0.)
#     65         1       1229.0   1229.0      0.0          t_last_plot = np.float32(-np.inf)
#     66
#     67                                                   # For second-order lookahead, store previous gradients
#     68         1        460.0    460.0      0.0          if self.use_lookahead:
#     69                                                       prev_grad = cp.zeros_like(xyt, dtype=cp.float32)
#     70                                                       prev_bound_grad = cp.zeros_like(h, dtype=cp.float32)
#     71
#     72      2401     937631.0    390.5      0.0          for i_iteration in range(self.n_iterations):
#     73      2400     620622.0    258.6      0.0              dt = self.dt
#     74                                                       # Reuse pre-allocated arrays
#     75      2400 5840291722.0 2.43e+06     97.5              self.cost.compute_cost(sol, total_cost, total_grad, bound_grad)
#     76
#     77                                                       # Clip gradients per tree to prevent violent repulsion
#     78                                                       # if self.max_grad_norm is not None:
#     79                                                       #     grad_norms = cp.sqrt(cp.sum(total_grad**2, axis=2))  # (n_ensembles, n_trees)
#     80                                                       #     grad_norms = cp.maximum(grad_norms, 1e-8)  # Avoid division by zero
#     81                                                       #     clip_factor = cp.minimum(1.0, self.max_grad_norm / grad_norms)  # (n_ensembles, n_trees)
#     82                                                       #     total_grad = total_grad * clip_factor[:, :, None]  # Apply to each component
#     83
#     84      2400    1383892.0    576.6      0.0              if self.use_lookahead and i_iteration > 0:
#     85                                                           # Second-order lookahead: use gradient + 0.5 * (gradient - prev_gradient)
#     86                                                           # This is a predictor-corrector scheme: x_{n+1} = x_n - dt * (1.5*g_n - 0.5*g_{n-1})
#     87                                                           # Equivalent to Adams-Bashforth 2-step method
#     88                                                           effective_grad = 1.5 * total_grad - 0.5 * prev_grad
#     89                                                           effective_bound_grad = 1.5 * bound_grad - 0.5 * prev_bound_grad
#     90                                                           xyt -= dt * effective_grad
#     91                                                           h -= dt * effective_bound_grad
#     92                                                       else:
#     93      2400   74110400.0  30879.3      1.2                  xyt -= dt * total_grad
#     94      2400   64840572.0  27016.9      1.1                  h -= dt * bound_grad
#     95
#     96      2400    1090925.0    454.6      0.0              if self.use_lookahead:
#     97                                                           # Store current gradients for next iteration
#     98                                                           prev_grad[:] = total_grad
#     99                                                           prev_bound_grad[:] = bound_grad
#    100
#    101      2400    2412922.0   1005.4      0.0              t_total0 += dt
#    102
#    103      2400     902520.0    376.1      0.0              if self.plot_interval is not None and t_total0 - t_last_plot >= self.plot_interval*0.999:
#    104                                                           t_last_plot = t_total0+0
#    105                                                           ax.clear()
#    106                                                           ax.set_aspect('equal', adjustable='box')
#    107                                                           tree_list.xyt = cp.asnumpy(xyt[0])
#    108                                                           pack_vis.visualize_tree_list(tree_list, ax=ax, h=cp.asnumpy(h[0]))
#    109                                                           ax.set_title(f'Time: {t_total0:.2f}')
#    110                                                           display(fig)
#    111                                                           clear_output(wait=True)
#    112         1        520.0    520.0      0.0          return sol
# CPU times: user 1min 39s, sys: 5.9 s, total: 1min 45s
# Wall time: 1min 46s
