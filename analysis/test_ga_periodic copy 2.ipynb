# %%
import sys
import os
sys.path.insert(0, os.path.join(os.getcwd(), '../core'))
import kaggle_support as kgs
import importlib
import matplotlib.pyplot as plt
import numpy as np
import cupy as cp
from dataclasses import dataclass, field, fields
import pack_cuda
import pack_vis
import pack_cost
import copy
import time
import pack_ga
from IPython.display import HTML, display, clear_output
pack_cuda.USE_FLOAT32 = False
pack_cuda._ensure_initialized()
# Out:
# local
# local
# stop final relax at some point

# %%
importlib.reload(pack_ga)
fastMode = False
runner = pack_ga.GA()

# fast for now
#runner.population_size = 1
#runner.selection_size = [0]
#runner.n_generations = 500

# structural
runner.N_trees_to_do = np.array([2])
runner.population_size = 10000
runner.plot_fitness_predictors = True
runner.plot_diversity_matrix = True
runner.initializer.base_solution = kgs.SolutionCollectionLatticeRectangle()
runner.initializer.jiggler.duration_init = 0.
runner.initializer.jiggler.duration_compact /= 100000
runner.initializer.jiggler.duration_final = 0.
runner.initializer.jiggler.plot_interval = None
runner.initializer.jiggler.n_rounds = 1
runner.rough_relaxers[0].plot_interval =None
runner.rough_relaxers[0].n_iterations//=5
runner.fine_relaxers[0].plot_interval=None
runner.rough_relaxers[0].cost.costs.pop(1)
runner.fine_relaxers[0].cost.costs.pop(1)
runner.fine_relaxers[0].n_iterations//=5
runner.fitness_cost.costs.pop(1)
kgs.debugging_mode = 1
kgs.profiling=False
#print(runner.move.moves)
new_moves = []
for i in [1,2]:
    new_moves.append(runner.move.moves[i])
runner.move.moves = new_moves
#runner.rough_relaxers = []
#runner.fine_relaxers = []
runner.run()
# Out:
# stop final relax at some point
# Generation 0, Trees 2, Best cost: 0.00620377, Est: 0.31018868, h: 1.019445
# [[1.0194447 0.6066861]]
# Generation 1, Trees 2, Best cost: 0.00616882, Est: 0.30844092, h: 1.026947
# [[1.0269475 0.5989587]]
# Generation 2, Trees 2, Best cost: 0.00616882, Est: 0.30844092, h: 1.026947
# [[1.0269475 0.5989587]]
# Generation 3, Trees 2, Best cost: 0.00616882, Est: 0.30844092, h: 1.026947
# [[1.0269475 0.5989587]]
# Generation 4, Trees 2, Best cost: 0.00616882, Est: 0.30844092, h: 1.026947
# [[1.0269475 0.5989587]]
# Generation 5, Trees 2, Best cost: 0.00616882, Est: 0.30844092, h: 1.026947
# [[1.0269475 0.5989587]]
# Generation 6, Trees 2, Best cost: 0.00616882, Est: 0.30844092, h: 1.026947
# [[1.0269475 0.5989587]]
# Generation 7, Trees 2, Best cost: 0.00616882, Est: 0.30844092, h: 1.026947
# [[1.0269475 0.5989587]]
# Generation 8, Trees 2, Best cost: 0.00616882, Est: 0.30844092, h: 1.026947
# [[1.0269475 0.5989587]]
# Generation 9, Trees 2, Best cost: 0.00616882, Est: 0.30844092, h: 1.026947
# [[1.0269475 0.5989587]]
# Generation 10, Trees 2, Best cost: 0.00616882, Est: 0.30844092, h: 1.026947
# [[1.0269475 0.5989587]]
# Generation 11, Trees 2, Best cost: 0.00616882, Est: 0.30844092, h: 1.026947
# [[1.0269475 0.5989587]]
# Generation 12, Trees 2, Best cost: 0.00616882, Est: 0.30844092, h: 1.026947
# [[1.0269475 0.5989587]]
# Generation 13, Trees 2, Best cost: 0.00616882, Est: 0.30844092, h: 1.026947
# [[1.0269475 0.5989587]]

# %%
runner.rough_relaxers[0].cost
# Out:
# CostCompound(comment='', scaling=1.0, costs=[AreaCost(comment='', scaling=0.01), CollisionCostOverlappingArea(comment='', scaling=1.0)])
